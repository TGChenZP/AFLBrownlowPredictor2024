# %% [markdown]
# # 8. Make Predictions

# %%
import pandas as pd
import pickle
import json
import os
from collections import defaultdict as dd

# %%
with open(f'../models/final_models/fixed_mlp.pickle', 'rb') as f:
    model = pickle.load(f)

with open('../models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %%
manip_type = 'NormalisedData'

csv_list = os.listdir(f'../data/curated/{manip_type}')
csv_list.sort()

# %%
def predict_brownlow(csv_list, year):
    json_dict = dict()

    tally = dd(int)

    data = pd.DataFrame()
    for file in csv_list:
        if file[-4:] != '.csv':
            continue

        game_dict = dict()
        if str(year) in file:

            round = file.split()[2]
            team1 = file.split()[3]
            team2 = file.split()[5]
            game = team1 + ' v ' + team2

            data = pd.read_csv(f'../data/curated/{manip_type}/{file}')

            player = data['Player']
            player = data['Player']
            pred = model.predict(
                data[list(list(feature_importance_ordering.keys())[36])])
            pred = pd.DataFrame({'player': player, 'predicted_score': pred})

            three_votes = list(pred.sort_values(
                'predicted_score', ascending=False)['player'])[0]

            two_votes = list(pred.sort_values(
                'predicted_score', ascending=False)['player'])[1]

            one_vote = list(pred.sort_values(
                'predicted_score', ascending=False)['player'])[2]

            game_dict[3] = three_votes
            game_dict[2] = two_votes
            game_dict[1] = one_vote

            if f'Round {round}' in json_dict:
                json_dict[f'Round {round}'][game] = game_dict
            else:
                json_dict[f'Round {round}'] = dict()
                json_dict[f'Round {round}'][game] = game_dict

            tally[three_votes] += 3
            tally[two_votes] += 2
            tally[one_vote] += 1

    return json_dict, tally

# %%
json_dict, tally = predict_brownlow(csv_list, 2023)

# %%
# with open('../presentables/game_by_game_prediction.json', 'w') as f:
#     json.dump(json_dict, f, indent=2)

# %%
tally_list = list(tally.items())
tally_list.sort(key=lambda x: x[1], reverse=True)

# %%
tally_df = pd.DataFrame(tally_list, columns=['Player', 'Votes'], index=[
                        i+1 for i in range(len(tally_list))])
tally_df['Ranking'] = tally_df.index
tally_df = tally_df[['Ranking', 'Player', 'Votes']]
tally_df.head(60)
# Out:
#     Ranking              Player  Votes
# 1         1         Nick Daicos     29
# 2         2  Christian Petracca     28
# 3         3         Zak Butters     27
# 4         4  Marcus Bontempelli     27
# 5         5     Andrew Brayshaw     26
# 6         6          Rory Laird     24
# 7         7        Errol Gulden     24
# 8         8      Rowan Marshall     22
# 9         9        James Sicily     21
# 10       10        Lachie Neale     21
# 11       11       Jordan Dawson     20
# 12       12        Caleb Serong     19
# 13       13       Noah Anderson     19
# 14       14         Tim Taranto     18
# 15       15        Connor Rozee     18
# 16       16           Tom Green     17
# 17       17     Zachary Merrett     17
# 18       18      Thomas Stewart     17
# 19       19     Timothy English     17
# 20       20      Charlie Curnow     16
# 21       21        Josh Dunkley     16
# 22       22          Jack Viney     16
# 23       23      Clayton Oliver     15
# 24       24      Luke D-Uniacke     15
# 25       25         Nick Blakey     15
# 26       26          Adam Cerra     15
# 27       27   Thomas Liberatore     15
# 28       28    Stephen Coniglio     14
# 29       29           Luke Ryan     14
# 30       30       Jack Sinclair     14
# 31       31       Taylor Walker     14
# 32       32         Brad Crouch     14
# 33       33      Patrick Cripps     14
# 34       34       Dustin Martin     13
# 35       35      Jordan De Goey     12
# 36       36        Darcy Parish     12
# 37       37         Shai Bolton     12
# 38       38         Matt Rowell     12
# 39       39     Nicholas Martin     12
# 40       40          Nic Newman     12
# 41       41            Max Gawn     11
# 42       42         Dan Houston     11
# 43       43        Joshua Kelly     11
# 44       44         Toby Greene     10
# 45       45        Luke Jackson     10
# 46       46        Jai Newcombe      9
# 47       47           Tim Kelly      9
# 48       48         Chad Warner      8
# 49       49         Luke Parker      8
# 50       50      Jackson Macrae      8
# 51       51        James Worpel      8
# 52       52        Tom Mitchell      8
# 53       53          Jake Lloyd      7
# 54       54       Harry Sheezel      7
# 55       55        Caleb Daniel      7
# 56       56         Dylan Moore      7
# 57       57        Mason Redman      7
# 58       58        Jack Ziebell      7
# 59       59        Adam Treloar      7
# 60       60         Josh Daicos      7

# %%
# tally_df.to_csv('../presentables/leaderboard.csv', index=False)
