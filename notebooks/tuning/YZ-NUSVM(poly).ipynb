# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nusvm(poly)'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML==0.2.8
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML==0.2.8
#   Downloading JXAutoML-0.2.8-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.8-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.8

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import NuSVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto'),
    'nu': (0.1, 0.3, 0.5, 0.7, 0.9)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.NuSVR'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 2289 rows, for 2289.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (4, 8, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 4, 1, 0, 4, 36), which had val score of -285.1323
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 2, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 1, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 1, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 1, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 4, 0, 1, 4, 36), which had val score of -257.2476
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 1, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 4, 0, 0, 4, 35), which had val score of -318.4905
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 1, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 1, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 3, 35), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 4, 34), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 112 of 864
#
# Cruising Coordrdinate 113 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 47
#
# 	round 47 iteration:  0
#
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 114 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 48
#
# 	round 48 iteration:  0
#
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 115 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 49
#
# 	round 49 iteration:  0
#
# Already Trained and Tested combination (1, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 4, 0, 0, 4, 5), which had val score of -3.3742
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 3, 5), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# 	round 49 iteration:  1
#
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (2, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 7, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 4, 0, 0, 4, 5), which had val score of -306.0825
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 1, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 0, 1, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 0, 0, 3, 5), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 0, 0, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 0, 0, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 7, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 6, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 4, 0, 0, 4, 5), which had val score of -8.9577
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 1, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 1, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 0, 3, 5), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 0, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 0, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 1, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 1, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 4, 1, 0, 4, 5), which had val score of -10.7943
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 2, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 1, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 0, 3, 5), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 0, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 0, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 0, 1, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 1, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 4, 0, 1, 4, 5), which had val score of -2.002
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 1, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 3, 5), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 0, 0, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 0, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 4, 0, 0, 4, 4), which had val score of -995.7432
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 0, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 4, 4), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 3, 4), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 3), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 8, 5, 0, 0, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 5, 0, 0, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 4, 0, 0, 4, 6), which had val score of -4.1435
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 1, 0, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 1, 4, 6), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 3, 6), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 5), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 5, 0, 0, 4, 7), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 116 of 864
#
# Cruising Coordrdinate 117 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 50
#
# 	round 50 iteration:  0
#
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 118 of 864
#
# Cruising Coordrdinate 119 of 864
#
# Cruising Coordrdinate 120 of 864
#
# Cruising Coordrdinate 121 of 864
#
# Cruising Coordrdinate 122 of 864
#
# Cruising Coordrdinate 123 of 864
#
# Cruising Coordrdinate 124 of 864
#
# Cruising Coordrdinate 125 of 864
#
# Cruising Coordrdinate 126 of 864
#
# Cruising Coordrdinate 127 of 864
#
# Cruising Coordrdinate 128 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 51
#
# 	round 51 iteration:  0
#
# Already Trained and Tested combination (1, 8, 0, 0, 1, 0, 5), which had val score of -3719.9431
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 0, 0, 1, 0, 5), which had val score of -0.672
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 1, 0, 1, 0, 5), which had val score of -0.2955
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 0, 1, 1, 0, 5), which had val score of -27.6249
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 0, 0, 5), which had val score of -134.9222
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 1, 5), which had val score of -1.1172
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 0, 4), which had val score of -14.7616
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 0, 6), which had val score of -1.6132
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# 	round 51 iteration:  1
#
# Already Trained and Tested combination (1, 8, 1, 0, 1, 0, 5), which had val score of -3719.9431
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 7, 1, 0, 1, 0, 5), which had val score of -0.672
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 0, 0, 1, 0, 5), which had val score of -0.2955
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 2, 0, 1, 0, 5), which had val score of -0.2955
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 1, 1, 1, 0, 5), which had val score of -27.6249
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 1, 0, 0, 0, 5), which had val score of -134.9222
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 1, 0, 1, 1, 5), which had val score of -1.1172
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 1, 0, 1, 0, 4), which had val score of -14.7616
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 8, 1, 0, 1, 0, 6), which had val score of -1.6132
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 129 of 864
#
# Cruising Coordrdinate 130 of 864
#
# Cruising Coordrdinate 131 of 864
#
# Cruising Coordrdinate 132 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 52
#
# 	round 52 iteration:  0
#
# Already Trained and Tested combination (1, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 0, 0, 4, 36), which had val score of -0.1086
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# 	round 52 iteration:  1
#
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (2, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 3, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 5, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 4, 0, 0, 4, 36), which had val score of -0.0606
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 5, 0, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 3, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 2, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 4, 36), which had val score of -0.1118
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 0, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 5, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 6, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 4, 0, 0, 4, 36), which had val score of -0.1035
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 0, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 4, 0, 0, 4, 36), which had val score of -0.0606
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 4, 36), which had val score of -0.1118
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 4, 0, 0, 4, 36), which had val score of -0.1035
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 3, 0, 0, 4, 36), which had val score of -0.1086
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 1, 0, 4, 36), which had val score of -0.1083
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 0, 1, 4, 36), which had val score of -0.1091
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 0, 0, 3, 36), which had val score of -1.7205
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 0, 0, 4, 35), which had val score of -0.1078
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 1, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 1, 0, 4, 36), which had val score of -0.1083
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 2, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 1, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 1, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 1, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 0, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 0, 1, 4, 36), which had val score of -0.1091
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 1, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (1, 4, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 3, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 5, 5, 0, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 4, 0, 0, 4, 35), which had val score of -0.1078
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 1, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 1, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 3, 35), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 34), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (0, 4, 5, 0, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 133 of 864
#
# Cruising Coordrdinate 134 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 53
#
# 	round 53 iteration:  0
#
# % Combos Checked Thus Far: 2289 out of 719280 which is 0.318235%
# Cruising Coordrdinate 135 of 864
#
# Cruising Coordrdinate 136 of 864
#
# Cruising Coordrdinate 137 of 864
#
# Cruise suspended due to suspicious case
# Guidance: round 54
#
# 	round 54 iteration:  0
#
# Already Trained and Tested combination (4, 8, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 4, 5, 0, 4, 36), which had val score of -5605.8175
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 4, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# 	round 54 iteration:  1
#
# Already Trained and Tested combination (3, 8, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 7, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 4, 5, 0, 4, 36), which had val score of -2937.9931
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 4, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 5, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 5, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 5, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 7, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 6, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 4, 5, 0, 4, 36), which had val score of -421.6504
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 4, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 5, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 5, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 5, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 4, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 4, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 4, 4, 0, 4, 36), which had val score of -1719.9985
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 3, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 4, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 4, 0, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 4, 0, 4, 35), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (4, 8, 5, 5, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 7, 5, 5, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 4, 5, 1, 4, 36), which had val score of -1928.4766
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 4, 1, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 0, 4, 36), which had val score of -0.1147
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1, 3, 36), which had val score of -1.735
#         Current best combo: (5, 0, 0, 5, 1, 4, 20) with val score 0.7151.
#         Has trained 2289 of 719280 combinations so far
# Already Trained and Tested combination (5, 8, 5, 5, 1, 4, 35), which had val score of -0.1147
# ...
#
# Cruising Coordrdinate 590 of 864
#
# Cruising Coordrdinate 591 of 864
#
# Cruising Coordrdinate 592 of 864
#
# Cruising Coordrdinate 593 of 864
#
# Cruising Coordrdinate 594 of 864
#
# Cruising Coordrdinate 595 of 864
#
# Cruising Coordrdinate 596 of 864
#
# Cruising Coordrdinate 597 of 864
#
# Cruising Coordrdinate 598 of 864
#
# Cruising Coordrdinate 599 of 864
#
# Cruising Coordrdinate 600 of 864
#
# Cruising Coordrdinate 601 of 864
#
# Cruising Coordrdinate 602 of 864
#
# Cruising Coordrdinate 603 of 864
#
# Cruising Coordrdinate 604 of 864
#
# Cruising Coordrdinate 605 of 864
#
# Cruising Coordrdinate 606 of 864
#
# Cruising Coordrdinate 607 of 864
#
# Cruising Coordrdinate 608 of 864
#
# Cruising Coordrdinate 609 of 864
#
# Cruising Coordrdinate 610 of 864
#
# Cruising Coordrdinate 611 of 864
#
# Cruising Coordrdinate 612 of 864
#
# Cruising Coordrdinate 613 of 864
#
# Cruising Coordrdinate 614 of 864
#
# Cruising Coordrdinate 615 of 864
#
# Cruising Coordrdinate 616 of 864
#
# Cruising Coordrdinate 617 of 864
#
# Cruising Coordrdinate 618 of 864
#
# Cruising Coordrdinate 619 of 864
#
# Cruising Coordrdinate 620 of 864
#
# Cruising Coordrdinate 621 of 864
#
# Cruising Coordrdinate 622 of 864
#
# Cruising Coordrdinate 623 of 864
#
# Cruising Coordrdinate 624 of 864
#
# Cruising Coordrdinate 625 of 864
#
# Cruising Coordrdinate 626 of 864
#
# Cruising Coordrdinate 627 of 864
#
# Cruising Coordrdinate 628 of 864
#
# Cruising Coordrdinate 629 of 864
#
# Cruising Coordrdinate 630 of 864
#
# Cruising Coordrdinate 631 of 864
#
# Cruising Coordrdinate 632 of 864
#
# Cruising Coordrdinate 633 of 864
#
# Cruising Coordrdinate 634 of 864
#
# Cruising Coordrdinate 635 of 864
#
# Cruising Coordrdinate 636 of 864
#
# Cruising Coordrdinate 637 of 864
#
# Cruising Coordrdinate 638 of 864
#
# Cruising Coordrdinate 639 of 864
#
# Cruising Coordrdinate 640 of 864
#
# Cruising Coordrdinate 641 of 864
#
# Cruising Coordrdinate 642 of 864
#
# Cruising Coordrdinate 643 of 864
#
# Cruising Coordrdinate 644 of 864
#
# Cruising Coordrdinate 645 of 864
#
# Cruising Coordrdinate 646 of 864
#
# Cruising Coordrdinate 647 of 864
#
# Cruising Coordrdinate 648 of 864
#
# Cruising Coordrdinate 649 of 864
#
# Cruising Coordrdinate 650 of 864
#
# Cruising Coordrdinate 651 of 864
#
# Cruising Coordrdinate 652 of 864
#
# Cruising Coordrdinate 653 of 864
#
# Cruising Coordrdinate 654 of 864
#
# Cruising Coordrdinate 655 of 864
#
# Cruising Coordrdinate 656 of 864
#
# Cruising Coordrdinate 657 of 864
#
# Cruising Coordrdinate 658 of 864
#
# Cruising Coordrdinate 659 of 864
#
# Cruising Coordrdinate 660 of 864
#
# Cruising Coordrdinate 661 of 864
#
# Cruising Coordrdinate 662 of 864
#
# Cruising Coordrdinate 663 of 864
#
# Cruising Coordrdinate 664 of 864
#
# Cruising Coordrdinate 665 of 864
#
# Cruising Coordrdinate 666 of 864
#
# Cruising Coordrdinate 667 of 864
#
# Cruising Coordrdinate 668 of 864
#
# Cruising Coordrdinate 669 of 864
#
# Cruising Coordrdinate 670 of 864
#
# Cruising Coordrdinate 671 of 864
#
# Cruising Coordrdinate 672 of 864
#
# Cruising Coordrdinate 673 of 864
#
# Cruising Coordrdinate 674 of 864
#
# Cruising Coordrdinate 675 of 864
#
# Cruising Coordrdinate 676 of 864
#
# Cruising Coordrdinate 677 of 864
#
# Cruising Coordrdinate 678 of 864
#
# Cruising Coordrdinate 679 of 864
#
# Cruising Coordrdinate 680 of 864
#
# Cruising Coordrdinate 681 of 864
#
# Cruising Coordrdinate 682 of 864
#
# Cruising Coordrdinate 683 of 864
#
# Cruising Coordrdinate 684 of 864
#
# Cruising Coordrdinate 685 of 864
#
# Cruising Coordrdinate 686 of 864
#
# Cruising Coordrdinate 687 of 864
#
# Cruising Coordrdinate 688 of 864
#
# Cruising Coordrdinate 689 of 864
#
# Cruising Coordrdinate 690 of 864
#
# Cruising Coordrdinate 691 of 864
#
# Cruising Coordrdinate 692 of 864
#
# Cruising Coordrdinate 693 of 864
#
# Cruising Coordrdinate 694 of 864
#
# Cruising Coordrdinate 695 of 864
#
# Cruising Coordrdinate 696 of 864
#
# Cruising Coordrdinate 697 of 864
#
# Cruising Coordrdinate 698 of 864
#
# Cruising Coordrdinate 699 of 864
#
# Cruising Coordrdinate 700 of 864
#
# Cruising Coordrdinate 701 of 864
#
# Cruising Coordrdinate 702 of 864
#
# Cruising Coordrdinate 703 of 864
#
# Cruising Coordrdinate 704 of 864
#
# Cruising Coordrdinate 705 of 864
#
# Cruising Coordrdinate 706 of 864
#
# Cruising Coordrdinate 707 of 864
#
# Cruising Coordrdinate 708 of 864
#
# Cruising Coordrdinate 709 of 864
#
# Cruising Coordrdinate 710 of 864
#
# Cruising Coordrdinate 711 of 864
#
# Cruising Coordrdinate 712 of 864
#
# Cruising Coordrdinate 713 of 864
#
# Cruising Coordrdinate 714 of 864
#
# Cruising Coordrdinate 715 of 864
#
# Cruising Coordrdinate 716 of 864
#
# Cruising Coordrdinate 717 of 864
#
# Cruising Coordrdinate 718 of 864
#
# Cruising Coordrdinate 719 of 864
#
# Cruising Coordrdinate 720 of 864
#
# Cruising Coordrdinate 721 of 864
#
# Cruising Coordrdinate 722 of 864
#
# Cruising Coordrdinate 723 of 864
#
# Cruising Coordrdinate 724 of 864
#
# Cruising Coordrdinate 725 of 864
#
# Cruising Coordrdinate 726 of 864
#
# Cruising Coordrdinate 727 of 864
#
# Cruising Coordrdinate 728 of 864
#
# Cruising Coordrdinate 729 of 864
#
# Cruising Coordrdinate 730 of 864
#
# Cruising Coordrdinate 731 of 864
#
# Cruising Coordrdinate 732 of 864
#
# Cruising Coordrdinate 733 of 864
#
# Cruising Coordrdinate 734 of 864
#
# Cruising Coordrdinate 735 of 864
#
# Cruising Coordrdinate 736 of 864
#
# Cruising Coordrdinate 737 of 864
#
# Cruising Coordrdinate 738 of 864
#
# Cruising Coordrdinate 739 of 864
#
# Cruising Coordrdinate 740 of 864
#
# Cruising Coordrdinate 741 of 864
#
# Cruising Coordrdinate 742 of 864
#
# Cruising Coordrdinate 743 of 864
#
# Cruising Coordrdinate 744 of 864
#
# Cruising Coordrdinate 745 of 864
#
# Cruising Coordrdinate 746 of 864
#
# Cruising Coordrdinate 747 of 864
#
# Cruising Coordrdinate 748 of 864
#
# Cruising Coordrdinate 749 of 864
#
# Cruising Coordrdinate 750 of 864
#
# Cruising Coordrdinate 751 of 864
#
# Cruising Coordrdinate 752 of 864
#
# Cruising Coordrdinate 753 of 864
#
# Cruising Coordrdinate 754 of 864
#
# Cruising Coordrdinate 755 of 864
#
# Cruising Coordrdinate 756 of 864
#
# Cruising Coordrdinate 757 of 864
#
# Cruising Coordrdinate 758 of 864
#
# Cruising Coordrdinate 759 of 864
#
# Cruising Coordrdinate 760 of 864
#
# Cruising Coordrdinate 761 of 864
#
# Cruising Coordrdinate 762 of 864
#
# Cruising Coordrdinate 763 of 864
#
# Cruising Coordrdinate 764 of 864
#
# Cruising Coordrdinate 765 of 864
#
# Cruising Coordrdinate 766 of 864
#
# Cruising Coordrdinate 767 of 864
#
# Cruising Coordrdinate 768 of 864
#
# Cruising Coordrdinate 769 of 864
#
# Cruising Coordrdinate 770 of 864
#
# Cruising Coordrdinate 771 of 864
#
# Cruising Coordrdinate 772 of 864
#
# Cruising Coordrdinate 773 of 864
#
# Cruising Coordrdinate 774 of 864
#
# Cruising Coordrdinate 775 of 864
#
# Cruising Coordrdinate 776 of 864
#
# Cruising Coordrdinate 777 of 864
#
# Cruising Coordrdinate 778 of 864
#
# Cruising Coordrdinate 779 of 864
#
# Cruising Coordrdinate 780 of 864
#
# Cruising Coordrdinate 781 of 864
#
# Cruising Coordrdinate 782 of 864
#
# Cruising Coordrdinate 783 of 864
#
# Cruising Coordrdinate 784 of 864
#
# Cruising Coordrdinate 785 of 864
#
# Cruising Coordrdinate 786 of 864
#
# Cruising Coordrdinate 787 of 864
#
# Cruising Coordrdinate 788 of 864
#
# Cruising Coordrdinate 789 of 864
#
# Cruising Coordrdinate 790 of 864
#
# Cruising Coordrdinate 791 of 864
#
# Cruising Coordrdinate 792 of 864
#
# Cruising Coordrdinate 793 of 864
#
# Cruising Coordrdinate 794 of 864
#
# Cruising Coordrdinate 795 of 864
#
# Cruising Coordrdinate 796 of 864
#
# Cruising Coordrdinate 797 of 864
#
# Cruising Coordrdinate 798 of 864
#
# Cruising Coordrdinate 799 of 864
#
# Cruising Coordrdinate 800 of 864
#
# Cruising Coordrdinate 801 of 864
#
# Cruising Coordrdinate 802 of 864
#
# Cruising Coordrdinate 803 of 864
#
# Cruising Coordrdinate 804 of 864
#
# Cruising Coordrdinate 805 of 864
#
# Cruising Coordrdinate 806 of 864
#
# Cruising Coordrdinate 807 of 864
#
# Cruising Coordrdinate 808 of 864
#
# Cruising Coordrdinate 809 of 864
#
# Cruising Coordrdinate 810 of 864
#
# Cruising Coordrdinate 811 of 864
#
# Cruising Coordrdinate 812 of 864
#
# Cruising Coordrdinate 813 of 864
#
# Cruising Coordrdinate 814 of 864
#
# Cruising Coordrdinate 815 of 864
#
# Cruising Coordrdinate 816 of 864
#
# Cruising Coordrdinate 817 of 864
#
# Cruising Coordrdinate 818 of 864
#
# Cruising Coordrdinate 819 of 864
#
# Cruising Coordrdinate 820 of 864
#
# Cruising Coordrdinate 821 of 864
#
# Cruising Coordrdinate 822 of 864
#
# Cruising Coordrdinate 823 of 864
#
# Cruising Coordrdinate 824 of 864
#
# Cruising Coordrdinate 825 of 864
#
# Cruising Coordrdinate 826 of 864
#
# Cruising Coordrdinate 827 of 864
#
# Cruising Coordrdinate 828 of 864
#
# Cruising Coordrdinate 829 of 864
#
# Cruising Coordrdinate 830 of 864
#
# Cruising Coordrdinate 831 of 864
#
# Cruising Coordrdinate 832 of 864
#
# Cruising Coordrdinate 833 of 864
#
# Cruising Coordrdinate 834 of 864
#
# Cruising Coordrdinate 835 of 864
#
# Cruising Coordrdinate 836 of 864
#
# Cruising Coordrdinate 837 of 864
#
# Cruising Coordrdinate 838 of 864
#
# Cruising Coordrdinate 839 of 864
#
# Cruising Coordrdinate 840 of 864
#
# Cruising Coordrdinate 841 of 864
#
# Cruising Coordrdinate 842 of 864
#
# Cruising Coordrdinate 843 of 864
#
# Cruising Coordrdinate 844 of 864
#
# Cruising Coordrdinate 845 of 864
#
# Cruising Coordrdinate 846 of 864
#
# Cruising Coordrdinate 847 of 864
#
# Cruising Coordrdinate 848 of 864
#
# Cruising Coordrdinate 849 of 864
#
# Cruising Coordrdinate 850 of 864
#
# Cruising Coordrdinate 851 of 864
#
# Cruising Coordrdinate 852 of 864
#
# Cruising Coordrdinate 853 of 864
#
# Cruising Coordrdinate 854 of 864
#
# Cruising Coordrdinate 855 of 864
#
# Cruising Coordrdinate 856 of 864
#
# Cruising Coordrdinate 857 of 864
#
# Cruising Coordrdinate 858 of 864
#
# Cruising Coordrdinate 859 of 864
#
# Cruising Coordrdinate 860 of 864
#
# Cruising Coordrdinate 861 of 864
#
# Cruising Coordrdinate 862 of 864
#
# Cruising Coordrdinate 863 of 864
#
# Cruising Coordrdinate 864 of 864
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (1, 0, 0, 5, 1, 0, 36), which had val score of 0.7658
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# Already Trained and Tested combination (3, 0, 0, 5, 1, 0, 36), which had val score of 0.8466
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# Already Trained and Tested combination (2, 1, 0, 5, 1, 0, 36), which had val score of 0.1942
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# Already Trained and Tested combination (2, 0, 1, 5, 1, 0, 36), which had val score of 0.8596
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# Already Trained and Tested combination (2, 0, 0, 4, 1, 0, 36), which had val score of 0.8511
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# Already Trained and Tested combination (2, 0, 0, 5, 0, 0, 36), which had val score of 0.823
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# Already Trained and Tested combination (2, 0, 0, 5, 1, 1, 36), which had val score of 0.675
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# Already Trained and Tested combination (2, 0, 0, 5, 1, 0, 35), which had val score of 0.8567
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2446 of 719280 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 2447 of 719280: (1, 0, 1, 5, 1, 0, 36), taking 24.63 seconds to get val score of 0.7658
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2448 of 719280: (3, 0, 1, 5, 1, 0, 36), taking 25.24 seconds to get val score of 0.8466
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2449 of 719280: (2, 1, 1, 5, 1, 0, 36), taking 24.81 seconds to get val score of 0.1942
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Already Trained and Tested combination (2, 0, 0, 5, 1, 0, 36), which had val score of 0.8596
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2449 of 719280 combinations so far
# Trained and Tested combination 2450 of 719280: (2, 0, 2, 5, 1, 0, 36), taking 27.06 seconds to get val score of 0.8596
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2451 of 719280: (2, 0, 1, 4, 1, 0, 36), taking 20.71 seconds to get val score of 0.8511
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Already Trained and Tested combination (2, 0, 1, 5, 0, 0, 36), which had val score of 0.823
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2451 of 719280 combinations so far
# Trained and Tested combination 2452 of 719280: (2, 0, 1, 5, 1, 1, 36), taking 53.54 seconds to get val score of 0.675
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2453 of 719280: (2, 0, 1, 5, 1, 0, 35), taking 24.42 seconds to get val score of 0.8567
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2454 of 719280: (1, 0, 0, 5, 1, 0, 35), taking 24.29 seconds to get val score of 0.7681
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2455 of 719280: (3, 0, 0, 5, 1, 0, 35), taking 26.62 seconds to get val score of 0.8532
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2456 of 719280: (2, 1, 0, 5, 1, 0, 35), taking 23.86 seconds to get val score of 0.2418
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Already Trained and Tested combination (2, 0, 1, 5, 1, 0, 35), which had val score of 0.8567
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2456 of 719280 combinations so far
# Trained and Tested combination 2457 of 719280: (2, 0, 0, 4, 1, 0, 35), taking 18.51 seconds to get val score of 0.8365
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Already Trained and Tested combination (2, 0, 0, 5, 0, 0, 35), which had val score of 0.8506
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2457 of 719280 combinations so far
# Trained and Tested combination 2458 of 719280: (2, 0, 0, 5, 1, 1, 35), taking 51.43 seconds to get val score of 0.8249
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Trained and Tested combination 2459 of 719280: (2, 0, 0, 5, 1, 0, 34), taking 23.08 seconds to get val score of 0.8529
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596
# Already Trained and Tested combination (2, 0, 0, 5, 1, 0, 36), which had val score of 0.8596
#         Current best combo: (2, 0, 0, 5, 1, 0, 36) with val score 0.8596.
#         Has trained 2459 of 719280 combinations so far
# % Combos Checked Thus Far: 2459 out of 719280 which is 0.34187%
# Max Val Score:
#  0.8596411540185157
# Best Combo Test Score:
#  0.86062
# Best Combo Train Score:
#  0.859621
# Max Combo Index:
#  (2, 0, 0, 5, 1, 0, 36) out of [6, 9, 6, 6, 2, 5, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.01, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'scale', 'nu': 0.1, 'features': 36}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Rebound 50s', 'Disposal Efficiency %', 'Uncontested Marks', 'Frees For', 'Clearances', 'Inside 50s', 'Turnovers', 'Bounces', 'Uncontested Possessions', 'Centre Clearances', 'Behinds', 'Stoppage Clearances', 'Ineffective Disposals', 'Winloss')
# % Combos Checked: 2459 out of 719280 which is 0.34187%
