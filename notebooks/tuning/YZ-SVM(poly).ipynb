# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'svm(poly)'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Requirement already satisfied: JXAutoML in /usr/local/lib/python3.10/dist-packages (0.2.6)

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import SVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'degree': list(range(1, 10)),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    'kernel': 'poly'
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.SVR'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1192 of 143856 combinations so far
# Trained and Tested combination 1193 of 143856: (2, 0, 5, 0, 1, 36), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1194 of 143856: (1, 1, 5, 0, 1, 36), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1195 of 143856: (1, 0, 4, 0, 1, 36), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1196 of 143856: (1, 0, 5, 1, 1, 36), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1197 of 143856: (1, 0, 5, 0, 0, 36), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1198 of 143856: (1, 0, 5, 0, 1, 35), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (1, 1, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1198 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1198 of 143856 combinations so far
# Already Trained and Tested combination (0, 2, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1198 of 143856 combinations so far
# Trained and Tested combination 1199 of 143856: (0, 1, 4, 0, 1, 36), taking 0.05 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1200 of 143856: (0, 1, 5, 1, 1, 36), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1201 of 143856: (0, 1, 5, 0, 0, 36), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1202 of 143856: (0, 1, 5, 0, 1, 35), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (1, 0, 4, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1202 of 143856 combinations so far
# Already Trained and Tested combination (0, 1, 4, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1202 of 143856 combinations so far
# Trained and Tested combination 1203 of 143856: (0, 0, 3, 0, 1, 36), taking 0.52 seconds to get val score of 0.0061
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (0, 0, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1203 of 143856 combinations so far
# Trained and Tested combination 1204 of 143856: (0, 0, 4, 1, 1, 36), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1205 of 143856: (0, 0, 4, 0, 0, 36), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1206 of 143856: (0, 0, 4, 0, 1, 35), taking 0.04 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (1, 0, 5, 1, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1206 of 143856 combinations so far
# Already Trained and Tested combination (0, 1, 5, 1, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1206 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 4, 1, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1206 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1206 of 143856 combinations so far
# Trained and Tested combination 1207 of 143856: (0, 0, 5, 2, 1, 36), taking 0.05 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1208 of 143856: (0, 0, 5, 1, 0, 36), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1209 of 143856: (0, 0, 5, 1, 1, 35), taking 0.05 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (1, 0, 5, 0, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1209 of 143856 combinations so far
# Already Trained and Tested combination (0, 1, 5, 0, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1209 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1209 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 5, 1, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1209 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1209 of 143856 combinations so far
# Trained and Tested combination 1210 of 143856: (0, 0, 5, 0, 0, 35), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (1, 0, 5, 0, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1210 of 143856 combinations so far
# Already Trained and Tested combination (0, 1, 5, 0, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1210 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1210 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 5, 1, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1210 of 143856 combinations so far
# Already Trained and Tested combination (0, 0, 5, 0, 0, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1210 of 143856 combinations so far
# Trained and Tested combination 1211 of 143856: (0, 0, 5, 0, 1, 34), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (0, 0, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1211 of 143856 combinations so far
# % Combos Checked Thus Far: 1211 out of 143856 which is 0.841814%
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 52
#
# 	round 52 iteration:  0
#
# % Combos Checked Thus Far: 1211 out of 143856 which is 0.841814%
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 53
#
# 	round 53 iteration:  0
#
# Trained and Tested combination 1212 of 143856: (1, 4, 0, 0, 1, 36), taking 0.36 seconds to get val score of 0.0216
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1213 of 143856: (0, 3, 0, 0, 1, 36), taking 0.35 seconds to get val score of 0.0022
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1214 of 143856: (0, 5, 0, 0, 1, 36), taking 0.34 seconds to get val score of -1.6696
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1215 of 143856: (0, 4, 1, 0, 1, 36), taking 0.36 seconds to get val score of 0.0023
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1216 of 143856: (0, 4, 0, 1, 1, 36), taking 0.68 seconds to get val score of 0.0048
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (0, 4, 0, 0, 0, 36), which had val score of 0.0019
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1216 of 143856 combinations so far
# Trained and Tested combination 1217 of 143856: (0, 4, 0, 0, 1, 35), taking 0.35 seconds to get val score of 0.0029
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# 	round 53 iteration:  1
#
# Already Trained and Tested combination (0, 4, 0, 0, 1, 36), which had val score of 0.0023
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1217 of 143856 combinations so far
# Trained and Tested combination 1218 of 143856: (2, 4, 0, 0, 1, 36), taking 0.35 seconds to get val score of -0.3906
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1219 of 143856: (1, 3, 0, 0, 1, 36), taking 0.36 seconds to get val score of 0.0202
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1220 of 143856: (1, 5, 0, 0, 1, 36), taking 0.34 seconds to get val score of -1.6557
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 
 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1299 of 143856 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1299 of 143856 combinations so far
# Trained and Tested combination 1300 of 143856: (5, 4, 5, 2, 1, 36), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1301 of 143856: (5, 4, 5, 1, 0, 36), taking 0.02 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1302 of 143856: (5, 4, 5, 1, 1, 35), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (4, 4, 5, 0, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1302 of 143856 combinations so far
# Already Trained and Tested combination (5, 3, 5, 0, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1302 of 143856 combinations so far
# Already Trained and Tested combination (5, 5, 5, 0, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1302 of 143856 combinations so far
# Already Trained and Tested combination (5, 4, 4, 0, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1302 of 143856 combinations so far
# Already Trained and Tested combination (5, 4, 5, 1, 0, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1302 of 143856 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1302 of 143856 combinations so far
# Trained and Tested combination 1303 of 143856: (5, 4, 5, 0, 0, 35), taking 0.02 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (4, 4, 5, 0, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1303 of 143856 combinations so far
# Already Trained and Tested combination (5, 3, 5, 0, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1303 of 143856 combinations so far
# Already Trained and Tested combination (5, 5, 5, 0, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1303 of 143856 combinations so far
# Already Trained and Tested combination (5, 4, 4, 0, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1303 of 143856 combinations so far
# Already Trained and Tested combination (5, 4, 5, 1, 1, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1303 of 143856 combinations so far
# Already Trained and Tested combination (5, 4, 5, 0, 0, 35), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1303 of 143856 combinations so far
# Trained and Tested combination 1304 of 143856: (5, 4, 5, 0, 1, 34), taking 0.03 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (5, 4, 5, 0, 1, 36), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1304 of 143856 combinations so far
# % Combos Checked Thus Far: 1304 out of 143856 which is 0.9064620000000001%
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 56
#
# 	round 56 iteration:  0
#
# % Combos Checked Thus Far: 1304 out of 143856 which is 0.9064620000000001%
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 57
#
# 	round 57 iteration:  0
#
# % Combos Checked Thus Far: 1304 out of 143856 which is 0.9064620000000001%
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 58
#
# 	round 58 iteration:  0
#
# % Combos Checked Thus Far: 1304 out of 143856 which is 0.9064620000000001%
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 59
#
# 	round 59 iteration:  0
#
# Trained and Tested combination 1305 of 143856: (1, 4, 5, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1306 of 143856: (0, 3, 5, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1307 of 143856: (0, 5, 5, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1308 of 143856: (0, 4, 4, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1309 of 143856: (0, 4, 5, 1, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (0, 4, 5, 0, 0, 5), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1309 of 143856 combinations so far
# Trained and Tested combination 1310 of 143856: (0, 4, 5, 0, 1, 4), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1311 of 143856: (0, 4, 5, 0, 1, 6), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# 	round 59 iteration:  1
#
# Already Trained and Tested combination (0, 4, 5, 0, 1, 5), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1311 of 143856 combinations so far
# Trained and Tested combination 1312 of 143856: (2, 4, 5, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1313 of 143856: (1, 3, 5, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1314 of 143856: (1, 5, 5, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1315 of 143856: (1, 4, 4, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1316 of 143856: (1, 4, 5, 1, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1317 of 143856: (1, 4, 5, 0, 0, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1318 of 143856: (1, 4, 5, 0, 1, 4), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Trained and Tested combination 1319 of 143856: (1, 4, 5, 0, 1, 6), taking 0.02 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (1, 3, 5, 0, 1, 5), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1319 of 143856 combinations so far
# Trained and Tested combination 1320 of 143856: (0, 2, 5, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# Already Trained and Tested combination (0, 4, 5, 0, 1, 5), which had val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027.
#         Has trained 1320 of 143856 combinations so far
# Trained and Tested combination 1321 of 143856: (0, 3, 4, 0, 1, 5), taking 0.01 seconds to get val score of 0.0
#         Current best combo: (5, 0, 0, 5, 0, 20) with val score 0.8027
# ...
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2034 of 143856: (5, 0, 1, 5, 0, 27), taking 4.08 seconds to get val score of 0.4424
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2035 of 143856: (5, 0, 1, 5, 0, 29), taking 4.16 seconds to get val score of 0.7269
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# % Combos Checked Thus Far: 2035 out of 143856 which is 1.414609%
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 108
#
# 	round 108 iteration:  0
#
# Trained and Tested combination 2036 of 143856: (4, 0, 0, 0, 1, 32), taking 0.27 seconds to get val score of 0.6755
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2037 of 143856: (5, 1, 0, 0, 1, 32), taking 0.3 seconds to get val score of -0.7222
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2038 of 143856: (5, 0, 1, 0, 1, 32), taking 0.28 seconds to get val score of 0.7158
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2039 of 143856: (5, 0, 0, 1, 1, 32), taking 0.44 seconds to get val score of 0.3942
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 0, 0, 0, 32), which had val score of 0.7158
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2039 of 143856 combinations so far
# Trained and Tested combination 2040 of 143856: (5, 0, 0, 0, 1, 31), taking 0.38 seconds to get val score of 0.6635
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2041 of 143856: (5, 0, 0, 0, 1, 33), taking 0.44 seconds to get val score of 0.6975
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# 	round 108 iteration:  1
#
# Trained and Tested combination 2042 of 143856: (4, 0, 1, 0, 1, 32), taking 0.4 seconds to get val score of 0.6755
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2043 of 143856: (5, 1, 1, 0, 1, 32), taking 0.46 seconds to get val score of -0.7222
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 0, 0, 1, 32), which had val score of 0.7158
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2043 of 143856 combinations so far
# Trained and Tested combination 2044 of 143856: (5, 0, 2, 0, 1, 32), taking 0.39 seconds to get val score of 0.7158
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2045 of 143856: (5, 0, 1, 1, 1, 32), taking 0.44 seconds to get val score of 0.3942
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2046 of 143856: (5, 0, 1, 0, 0, 32), taking 0.24 seconds to get val score of 0.7158
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2047 of 143856: (5, 0, 1, 0, 1, 31), taking 0.25 seconds to get val score of 0.6635
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2048 of 143856: (5, 0, 1, 0, 1, 33), taking 0.26 seconds to get val score of 0.6975
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2049 of 143856: (4, 0, 0, 0, 0, 32), taking 0.27 seconds to get val score of 0.7054
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2050 of 143856: (5, 1, 0, 0, 0, 32), taking 0.28 seconds to get val score of -0.7222
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 1, 0, 0, 32), which had val score of 0.7158
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2050 of 143856 combinations so far
# Trained and Tested combination 2051 of 143856: (5, 0, 0, 1, 0, 32), taking 0.46 seconds to get val score of 0.3942
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 0, 0, 1, 32), which had val score of 0.7158
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2051 of 143856 combinations so far
# Trained and Tested combination 2052 of 143856: (5, 0, 0, 0, 0, 31), taking 0.26 seconds to get val score of 0.6635
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2053 of 143856: (5, 0, 0, 0, 0, 33), taking 0.26 seconds to get val score of 0.6975
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# % Combos Checked Thus Far: 2053 out of 143856 which is 1.427122%
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 109
#
# 	round 109 iteration:  0
#
# % Combos Checked Thus Far: 2053 out of 143856 which is 1.427122%
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 110
#
# 	round 110 iteration:  0
#
# Trained and Tested combination 2054 of 143856: (4, 0, 0, 5, 1, 32), taking 7.37 seconds to get val score of 0.6943
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2055 of 143856: (5, 1, 0, 5, 1, 32), taking 7.85 seconds to get val score of -0.369
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2056 of 143856: (5, 0, 1, 5, 1, 32), taking 4.15 seconds to get val score of 0.7303
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2057 of 143856: (5, 0, 0, 4, 1, 32), taking 3.77 seconds to get val score of 0.7174
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 0, 5, 0, 32), which had val score of 0.3512
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2057 of 143856 combinations so far
# Trained and Tested combination 2058 of 143856: (5, 0, 0, 5, 1, 31), taking 4.83 seconds to get val score of 0.7483
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2059 of 143856: (5, 0, 0, 5, 1, 33), taking 6.0 seconds to get val score of 0.8134
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# 	round 110 iteration:  1
#
# Trained and Tested combination 2060 of 143856: (4, 0, 1, 5, 1, 32), taking 5.97 seconds to get val score of 0.6943
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2061 of 143856: (5, 1, 1, 5, 1, 32), taking 7.32 seconds to get val score of -0.369
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 0, 5, 1, 32), which had val score of 0.7303
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2061 of 143856 combinations so far
# Trained and Tested combination 2062 of 143856: (5, 0, 2, 5, 1, 32), taking 5.55 seconds to get val score of 0.7303
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2063 of 143856: (5, 0, 1, 4, 1, 32), taking 2.3 seconds to get val score of 0.7174
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2064 of 143856: (5, 0, 1, 5, 0, 32), taking 4.7 seconds to get val score of 0.3512
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2065 of 143856: (5, 0, 1, 5, 1, 31), taking 3.95 seconds to get val score of 0.7483
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2066 of 143856: (5, 0, 1, 5, 1, 33), taking 4.58 seconds to get val score of 0.8134
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2067 of 143856: (4, 0, 0, 5, 1, 31), taking 5.87 seconds to get val score of 0.8292
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2068 of 143856: (5, 1, 0, 5, 1, 31), taking 7.84 seconds to get val score of -0.1317
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 1, 5, 1, 31), which had val score of 0.7483
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2068 of 143856 combinations so far
# Trained and Tested combination 2069 of 143856: (5, 0, 0, 4, 1, 31), taking 2.21 seconds to get val score of 0.432
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2070 of 143856: (5, 0, 0, 5, 0, 31), taking 5.08 seconds to get val score of 0.7954
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2071 of 143856: (5, 0, 0, 5, 1, 30), taking 4.44 seconds to get val score of 0.523
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 0, 5, 1, 32), which had val score of 0.7303
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2071 of 143856 combinations so far
# Trained and Tested combination 2072 of 143856: (4, 0, 0, 5, 1, 33), taking 6.5 seconds to get val score of 0.8055
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2073 of 143856: (5, 1, 0, 5, 1, 33), taking 8.39 seconds to get val score of -0.5094
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 1, 5, 1, 33), which had val score of 0.8134
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2073 of 143856 combinations so far
# Trained and Tested combination 2074 of 143856: (5, 0, 0, 4, 1, 33), taking 2.34 seconds to get val score of 0.561
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2075 of 143856: (5, 0, 0, 5, 0, 33), taking 4.8 seconds to get val score of 0.536
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (5, 0, 0, 5, 1, 32), which had val score of 0.7303
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2075 of 143856 combinations so far
# Trained and Tested combination 2076 of 143856: (5, 0, 0, 5, 1, 34), taking 4.18 seconds to get val score of 0.7726
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# % Combos Checked Thus Far: 2076 out of 143856 which is 1.4431100000000001%
# Cruising Coordrdinate 0 of 432
#
# Cruising Coordrdinate 0 of 432
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 0, 0, 5, 0, 36), which had val score of 0.6581
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2076 of 143856 combinations so far
# Already Trained and Tested combination (4, 0, 0, 5, 0, 36), which had val score of 0.7892
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2076 of 143856 combinations so far
# Already Trained and Tested combination (3, 1, 0, 5, 0, 36), which had val score of 0.3847
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2076 of 143856 combinations so far
# Already Trained and Tested combination (3, 0, 1, 5, 0, 36), which had val score of 0.8674
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2076 of 143856 combinations so far
# Already Trained and Tested combination (3, 0, 0, 4, 0, 36), which had val score of 0.5597
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2076 of 143856 combinations so far
# Already Trained and Tested combination (3, 0, 0, 5, 1, 36), which had val score of 0.8662
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2076 of 143856 combinations so far
# Already Trained and Tested combination (3, 0, 0, 5, 0, 35), which had val score of 0.7515
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2076 of 143856 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 2077 of 143856: (2, 0, 1, 5, 0, 36), taking 10.4 seconds to get val score of 0.6581
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2078 of 143856: (4, 0, 1, 5, 0, 36), taking 7.84 seconds to get val score of 0.7892
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2079 of 143856: (3, 1, 1, 5, 0, 36), taking 11.93 seconds to get val score of 0.3847
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (3, 0, 0, 5, 0, 36), which had val score of 0.8674
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2079 of 143856 combinations so far
# Trained and Tested combination 2080 of 143856: (3, 0, 2, 5, 0, 36), taking 11.86 seconds to get val score of 0.8674
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Trained and Tested combination 2081 of 143856: (3, 0, 1, 4, 0, 36), taking 5.27 seconds to get val score of 0.5597
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# Already Trained and Tested combination (3, 0, 1, 5, 1, 36), which had val score of 0.8662
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674.
#         Has trained 2081 of 143856 combinations so far
# Trained and Tested combination 2082 of 143856: (3, 0, 1, 5, 0, 35), taking 11.09 seconds to get val score of 0.7515
#         Current best combo: (3, 0, 0, 5, 0, 36) with val score 0.8674
# % Combos Checked Thus Far: 2082 out of 143856 which is 1.4472809999999998%
# Max Val Score:
#  0.8674012463663181
# Best Combo Test Score:
#  0.869394
# Best Combo Train Score:
#  0.869431
# Max Combo Index:
#  (3, 0, 0, 5, 0, 36) out of [6, 9, 6, 6, 2, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.1, 'degree': 1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 36}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Disposal Efficiency %', 'Rebound 50s', 'Uncontested Marks', 'Frees For', 'Inside 50s', 'Turnovers', 'Bounces', 'Centre Clearances', 'Behinds', 'Uncontested Possessions', 'Clearances', 'Stoppage Clearances', 'Ineffective Disposals', 'Winloss')
# % Combos Checked: 2082 out of 143856 which is 1.4472809999999998%
