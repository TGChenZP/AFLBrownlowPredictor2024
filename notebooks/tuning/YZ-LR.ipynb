# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lr'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.linear_model import LinearRegression as clf

# what values to try for each hyperparameter
parameter_choices = {
    'fit_intercept': (True, False),
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.linear_model._base.LinearRegression'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 74: (0, 20), taking 7.6 seconds to get val score of -2.0077
#         Current best combo: (0, 20) with val score -2.0077
# Trained and Tested combination 2 of 74: (0, 28), taking 0.05 seconds to get val score of -2.0053
#         Current best combo: (0, 28) with val score -2.0053
# Trained and Tested combination 3 of 74: (0, 10), taking 0.02 seconds to get val score of -2.018
#         Current best combo: (0, 28) with val score -2.0053
# Trained and Tested combination 4 of 74: (1, 24), taking 0.02 seconds to get val score of 0.8615
#         Current best combo: (1, 24) with val score 0.8615
# Trained and Tested combination 5 of 74: (0, 24), taking 0.02 seconds to get val score of -2.0066
#         Current best combo: (1, 24) with val score 0.8615
# Trained and Tested combination 6 of 74: (0, 36), taking 0.08 seconds to get val score of -0.4173
#         Current best combo: (1, 24) with val score 0.8615
# Trained and Tested combination 7 of 74: (1, 20), taking 0.03 seconds to get val score of 0.8604
#         Current best combo: (1, 24) with val score 0.8615
# Trained and Tested combination 8 of 74: (0, 15), taking 0.03 seconds to get val score of -2.0083
#         Current best combo: (1, 24) with val score 0.8615
# Trained and Tested combination 9 of 74: (1, 15), taking 0.02 seconds to get val score of 0.8597
#         Current best combo: (1, 24) with val score 0.8615
# Trained and Tested combination 10 of 74: (1, 36), taking 0.07 seconds to get val score of 0.8646
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 11 of 74: (0, 32), taking 0.08 seconds to get val score of -2.0041
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 12 of 74: (0, 5), taking 0.03 seconds to get val score of -2.1151
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 13 of 74: (0, 0), taking 0.01 seconds to get val score of -2.2965
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 14 of 74: (1, 28), taking 0.06 seconds to get val score of 0.8628
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 15 of 74: (1, 0), taking 0.01 seconds to get val score of 0.5715
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 16 of 74: (1, 5), taking 0.01 seconds to get val score of 0.753
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 17 of 74: (1, 18), taking 0.04 seconds to get val score of 0.8602
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 18 of 74: (1, 10), taking 0.12 seconds to get val score of 0.8501
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 19 of 74: (1, 32), taking 0.07 seconds to get val score of 0.8639
#         Current best combo: (1, 36) with val score 0.8646
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 20 of 74: (0, 18), taking 0.05 seconds to get val score of -2.0078
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 21 of 74: (1, 17), taking 0.06 seconds to get val score of 0.8602
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 22 of 74: (1, 19), taking 0.04 seconds to get val score of 0.8603
#         Current best combo: (1, 36) with val score 0.8646
# 	round 0 iteration:  1
#
# Trained and Tested combination 23 of 74: (0, 17), taking 0.04 seconds to get val score of -2.0078
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 24 of 74: (1, 16), taking 0.05 seconds to get val score of 0.8601
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 18), which had val score of 0.8602
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 24 of 74 combinations so far
# Trained and Tested combination 25 of 74: (0, 19), taking 0.04 seconds to get val score of -2.0078
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 18), which had val score of 0.8602
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 25 of 74 combinations so far
# Already Trained and Tested combination (1, 20), which had val score of 0.8604
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 25 of 74 combinations so far
# Already Trained and Tested combination (0, 36), which had val score of -0.4173
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 25 of 74 combinations so far
# Trained and Tested combination 26 of 74: (1, 35), taking 0.06 seconds to get val score of 0.8639
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 26 out of 74 which is 35.135135%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Already Trained and Tested combination (0, 0), which had val score of -2.2965
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 26 of 74 combinations so far
# Trained and Tested combination 27 of 74: (1, 1), taking 0.01 seconds to get val score of 0.5922
#         Current best combo: (1, 36) with val score 0.8646
# 	round 1 iteration:  1
#
# Trained and Tested combination 28 of 74: (0, 1), taking 0.01 seconds to get val score of -2.2758
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 0), which had val score of 0.5715
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 28 of 74 combinations so far
# Trained and Tested combination 29 of 74: (1, 2), taking 0.01 seconds to get val score of 0.6409
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 29 out of 74 which is 39.189189%
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (0, 5), which had val score of -2.1151
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 29 of 74 combinations so far
# Trained and Tested combination 30 of 74: (1, 4), taking 0.01 seconds to get val score of 0.718
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 31 of 74: (1, 6), taking 0.02 seconds to get val score of 0.7794
#         Current best combo: (1, 36) with val score 0.8646
# 	round 2 iteration:  1
#
# Trained and Tested combination 32 of 74: (0, 6), taking 0.01 seconds to get val score of -2.0886
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 5), which had val score of 0.753
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 32 of 74 combinations so far
# Trained and Tested combination 33 of 74: (1, 7), taking 0.01 seconds to get val score of 0.8001
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 33 out of 74 which is 44.594595%
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Already Trained and Tested combination (0, 10), which had val score of -2.018
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 33 of 74 combinations so far
# Trained and Tested combination 34 of 74: (1, 9), taking 0.02 seconds to get val score of 0.8454
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 35 of 74: (1, 11), taking 0.02 seconds to get val score of 0.8502
#         Current best combo: (1, 36) with val score 0.8646
# 	round 3 iteration:  1
#
# Trained and Tested combination 36 of 74: (0, 9), taking 0.02 seconds to get val score of -2.0226
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 37 of 74: (1, 8), taking 0.02 seconds to get val score of 0.8259
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 10), which had val score of 0.8501
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 37 of 74 combinations so far
# Trained and Tested combination 38 of 74: (0, 11), taking 0.02 seconds to get val score of -2.0179
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 10), which had val score of 0.8501
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 38 of 74 combinations so far
# Trained and Tested combination 39 of 74: (1, 12), taking 0.02 seconds to get val score of 0.8509
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 39 out of 74 which is 52.70270299999999%
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Already Trained and Tested combination (0, 15), which had val score of -2.0083
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 39 of 74 combinations so far
# Trained and Tested combination 40 of 74: (1, 14), taking 0.03 seconds to get val score of 0.8574
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 16), which had val score of 0.8601
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 40 of 74 combinations so far
# 	round 4 iteration:  1
#
# Trained and Tested combination 41 of 74: (0, 14), taking 0.02 seconds to get val score of -2.0106
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 42 of 74: (1, 13), taking 0.03 seconds to get val score of 0.8545
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 15), which had val score of 0.8597
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 42 of 74 combinations so far
# % Combos Checked Thus Far: 42 out of 74 which is 56.756757%
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Already Trained and Tested combination (0, 20), which had val score of -2.0077
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 42 of 74 combinations so far
# Already Trained and Tested combination (1, 19), which had val score of 0.8603
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 42 of 74 combinations so far
# Trained and Tested combination 43 of 74: (1, 21), taking 0.04 seconds to get val score of 0.8604
#         Current best combo: (1, 36) with val score 0.8646
# 	round 5 iteration:  1
#
# Trained and Tested combination 44 of 74: (0, 21), taking 0.03 seconds to get val score of -2.0076
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 20), which had val score of 0.8604
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 44 of 74 combinations so far
# Trained and Tested combination 45 of 74: (1, 22), taking 0.04 seconds to get val score of 0.8605
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 45 out of 74 which is 60.810811%
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Already Trained and Tested combination (0, 24), which had val score of -2.0066
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 45 of 74 combinations so far
# Trained and Tested combination 46 of 74: (1, 23), taking 0.04 seconds to get val score of 0.8614
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 47 of 74: (1, 25), taking 0.04 seconds to get val score of 0.8615
#         Current best combo: (1, 36) with val score 0.8646
# 	round 6 iteration:  1
#
# Trained and Tested combination 48 of 74: (0, 23), taking 0.04 seconds to get val score of -2.0066
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 22), which had val score of 0.8605
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 48 of 74 combinations so far
# Already Trained and Tested combination (1, 24), which had val score of 0.8615
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 48 of 74 combinations so far
# Trained and Tested combination 49 of 74: (0, 25), taking 0.03 seconds to get val score of -2.0065
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 24), which had val score of 0.8615
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 49 of 74 combinations so far
# Trained and Tested combination 50 of 74: (1, 26), taking 0.05 seconds to get val score of 0.8616
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 50 out of 74 which is 67.567568%
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Already Trained and Tested combination (0, 28), which had val score of -2.0053
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 50 of 74 combinations so far
# Trained and Tested combination 51 of 74: (1, 27), taking 0.05 seconds to get val score of 0.8627
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 52 of 74: (1, 29), taking 0.05 seconds to get val score of 0.8627
#         Current best combo: (1, 36) with val score 0.8646
# 	round 7 iteration:  1
#
# Trained and Tested combination 53 of 74: (0, 27), taking 0.04 seconds to get val score of -2.0053
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 26), which had val score of 0.8616
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 53 of 74 combinations so far
# Already Trained and Tested combination (1, 28), which had val score of 0.8628
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 53 of 74 combinations so far
# Trained and Tested combination 54 of 74: (0, 29), taking 0.04 seconds to get val score of -2.0053
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 28), which had val score of 0.8628
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 54 of 74 combinations so far
# Trained and Tested combination 55 of 74: (1, 30), taking 0.05 seconds to get val score of 0.8638
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 55 out of 74 which is 74.32432399999999%
# Cruising Coordrdinate 0 of 18
#
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# Already Trained and Tested combination (0, 32), which had val score of -2.0041
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 55 of 74 combinations so far
# Trained and Tested combination 56 of 74: (1, 31), taking 0.06 seconds to get val score of 0.864
#         Current best combo: (1, 36) with val score 0.8646
# Trained and Tested combination 57 of 74: (1, 33), taking 0.07 seconds to get val score of 0.8639
#         Current best combo: (1, 36) with val score 0.8646
# 	round 8 iteration:  1
#
# Trained and Tested combination 58 of 74: (0, 31), taking 0.05 seconds to get val score of -2.0041
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 30), which had val score of 0.8638
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 58 of 74 combinations so far
# Already Trained and Tested combination (1, 32), which had val score of 0.8639
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 58 of 74 combinations so far
# Trained and Tested combination 59 of 74: (0, 33), taking 0.06 seconds to get val score of -2.0041
#         Current best combo: (1, 36) with val score 0.8646
# Already Trained and Tested combination (1, 32), which had val score of 0.8639
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 59 of 74 combinations so far
# Trained and Tested combination 60 of 74: (1, 34), taking 0.06 seconds to get val score of 0.864
#         Current best combo: (1, 36) with val score 0.8646
# % Combos Checked Thus Far: 60 out of 74 which is 81.081081%
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Already Trained and Tested combination (1, 36), which had val score of 0.8646
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 60 of 74 combinations so far
# Trained and Tested combination 61 of 74: (0, 35), taking 0.06 seconds to get val score of -2.0041
#         Current best combo: (1, 36) with val score 0.8646
# 	round 9 iteration:  1
#
# Already Trained and Tested combination (0, 36), which had val score of -0.4173
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 61 of 74 combinations so far
# Already Trained and Tested combination (1, 35), which had val score of 0.8639
#         Current best combo: (1, 36) with val score 0.8646.
#         Has trained 61 of 74 combinations so far
# % Combos Checked Thus Far: 61 out of 74 which is 82.432432%
# Cruising Coordrdinate 0 of 18
#
# Cruise suspended due to suspicious case
# Guidance: round 10
#
# 	round 10 iteration:  0
#
# % Combos Checked Thus Far: 61 out of 74 which is 82.432432%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# % Combos Checked Thus Far: 61 out of 74 which is 82.432432%
# Max Val Score:
#  0.8646348500339305
# Best Combo Test Score:
#  0.866441
# Best Combo Train Score:
#  0.864844
# Max Combo Index:
#  (1, 36) out of [2, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'fit_intercept': True, 'features': 36}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Rebound 50s', 'Disposal Efficiency %', 'Uncontested Marks', 'Frees For', 'Clearances', 'Inside 50s', 'Turnovers', 'Bounces', 'Uncontested Possessions', 'Centre Clearances', 'Behinds', 'Stoppage Clearances', 'Ineffective Disposals', 'Winloss')
# % Combos Checked: 61 out of 74 which is 82.432432%
