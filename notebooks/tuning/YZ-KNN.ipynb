# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'knn'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.2.6-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.6-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.6

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.neighbors import KNeighborsRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_neighbors': [i for i in range(1, 101)],
    'p': (1, 2),
    'weights': ('uniform', 'distance')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'n_jobs': -1
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.neighbors._regression.KNeighborsRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1046 rows, for 1046.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (40, 1, 1, 5), which had val score of 0.7864
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (80, 0, 0, 32), which had val score of 0.8346
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (70, 1, 0, 32), which had val score of 0.8431
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (60, 1, 1, 32), which had val score of 0.8402
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (10, 1, 0, 24), which had val score of 0.8612
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (15, 1, 1, 24), which had val score of 0.8603
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (20, 0, 1, 32), which had val score of 0.8414
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.5053
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (30, 0, 1, 15), which had val score of 0.8665
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (85, 1, 0, 5), which had val score of 0.792
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (70, 1, 1, 0), which had val score of 0.5806
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (99, 1, 1, 5), which had val score of 0.7871
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (99, 0, 1, 24), which had val score of 0.8472
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (50, 0, 0, 15), which had val score of 0.8685
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (75, 0, 0, 24), which had val score of 0.8547
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (0, 0, 1, 15), which had val score of 0.7523
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (75, 1, 1, 5), which had val score of 0.7869
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (80, 1, 1, 20), which had val score of 0.8573
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (15, 0, 1, 20), which had val score of 0.8597
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (90, 0, 1, 20), which had val score of 0.8513
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (65, 1, 1, 15), which had val score of 0.8677
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (95, 0, 1, 28), which had val score of 0.8359
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (50, 1, 1, 15), which had val score of 0.8689
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (10, 0, 0, 5), which had val score of 0.7752
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (80, 1, 1, 15), which had val score of 0.8665
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (15, 1, 0, 32), which had val score of 0.8494
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (30, 1, 0, 10), which had val score of 0.8783
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (95, 1, 1, 15), which had val score of 0.8652
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (99, 1, 1, 24), which had val score of 0.8536
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (70, 1, 0, 15), which had val score of 0.8713
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (55, 0, 1, 28), which had val score of 0.8425
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (0, 0, 0, 15), which had val score of 0.7523
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (60, 1, 1, 36), which had val score of 0.8347
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (0, 1, 1, 24), which had val score of 0.7251
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (15, 1, 1, 20), which had val score of 0.8625
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (90, 0, 1, 24), which had val score of 0.8484
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (15, 1, 0, 20), which had val score of 0.8659
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (20, 1, 0, 15), which had val score of 0.8741
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 1, 28), which had val score of 0.8454
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (15, 1, 1, 10), which had val score of 0.8735
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (99, 1, 0, 5), which had val score of 0.7921
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (55, 1, 1, 15), which had val score of 0.8686
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (70, 1, 0, 0), which had val score of 0.5579
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 15), which had val score of 0.87
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (75, 1, 0, 15), which had val score of 0.8709
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (40, 1, 1, 0), which had val score of 0.576
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (95, 0, 1, 15), which had val score of 0.86
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (50, 1, 1, 5), which had val score of 0.7866
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 36), which had val score of 0.8372
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (45, 1, 1, 10), which had val score of 0.8748
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (40, 0, 1, 20), which had val score of 0.8577
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (75, 1, 0, 10), which had val score of 0.8772
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (85, 0, 0, 24), which had val score of 0.8534
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (15, 1, 1, 28), which had val score of 0.8515
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (50, 0, 1, 0), which had val score of 0.5786
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (85, 0, 1, 5), which had val score of 0.787
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (85, 1, 1, 15), which had val score of 0.8659
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (80, 0, 1, 20), which had val score of 0.8525
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (20, 0, 0, 0), which had val score of 0.5431
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (50, 0, 0, 10), which had val score of 0.8771
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (90, 1, 1, 20), which had val score of 0.8563
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (85, 0, 0, 32), which had val score of 0.8337
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (20, 0, 0, 10), which had val score of 0.8768
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (10, 0, 1, 10), which had val score of 0.8696
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (5, 1,
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (70, 1, 0, 20), which had val score of 0.8623
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (45, 1, 1, 0), which had val score of 0.5778
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (30, 1, 1, 28), which had val score of 0.8515
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (60, 0, 1, 0), which had val score of 0.5799
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (55, 0, 0, 32), which had val score of 0.8389
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (40, 0, 0, 24), which had val score of 0.8589
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 0, 20), which had val score of 0.866
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 10), which had val score of 0.8775
#         Current best combo: (35, 1, 0, 10) with val score 0.8783.
#         Has trained 1046 of 14800 combinations so far
# ...
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruise suspended due to suspicious case
# Guidance: round 19
#
# 	round 19 iteration:  0
#
# Already Trained and Tested combination (34, 0, 0, 10), which had val score of 0.8777
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (36, 0, 0, 10), which had val score of 0.8774
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 0, 10), which had val score of 0.8783
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 1, 10), which had val score of 0.874
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 9), which had val score of 0.8754
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 11), which had val score of 0.8759
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# 	round 19 iteration:  1
#
# Already Trained and Tested combination (33, 0, 0, 10), which had val score of 0.8776
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 10), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (34, 1, 0, 10), which had val score of 0.8784
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (34, 0, 1, 10), which had val score of 0.8743
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (34, 0, 0, 9), which had val score of 0.8755
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (34, 0, 0, 11), which had val score of 0.876
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 10), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (37, 0, 0, 10), which had val score of 0.8774
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (36, 1, 0, 10), which had val score of 0.8784
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (36, 0, 1, 10), which had val score of 0.874
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Already Trained and Tested combination (36, 0, 0, 9), which had val score of 0.8754
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1046 of 14800 combinations so far
# Trained and Tested combination 1047 of 14800: (36, 0, 0, 11), taking 0.61 seconds to get val score of 0.8759
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (34, 1, 0, 10), which had val score of 0.8784
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (36, 1, 0, 10), which had val score of 0.8784
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 10), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 1, 10), which had val score of 0.875
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 0, 9), which had val score of 0.8777
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 0, 11), which had val score of 0.8776
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (34, 0, 1, 10), which had val score of 0.8743
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (36, 0, 1, 10), which had val score of 0.874
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 1, 10), which had val score of 0.875
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 10), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1047 of 14800 combinations so far
# Trained and Tested combination 1048 of 14800: (35, 0, 1, 9), taking 0.15 seconds to get val score of 0.8722
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Trained and Tested combination 1049 of 14800: (35, 0, 1, 11), taking 0.12 seconds to get val score of 0.8726
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (34, 0, 0, 9), which had val score of 0.8755
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1049 of 14800 combinations so far
# Already Trained and Tested combination (36, 0, 0, 9), which had val score of 0.8754
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1049 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 0, 9), which had val score of 0.8777
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1049 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 1, 9), which had val score of 0.8722
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1049 of 14800 combinations so far
# Trained and Tested combination 1050 of 14800: (35, 0, 0, 8), taking 0.14 seconds to get val score of 0.8525
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (35, 0, 0, 10), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1050 of 14800 combinations so far
# Already Trained and Tested combination (34, 0, 0, 11), which had val score of 0.876
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1050 of 14800 combinations so far
# Already Trained and Tested combination (36, 0, 0, 11), which had val score of 0.8759
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1050 of 14800 combinations so far
# Already Trained and Tested combination (35, 1, 0, 11), which had val score of 0.8776
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1050 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 1, 11), which had val score of 0.8726
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1050 of 14800 combinations so far
# Already Trained and Tested combination (35, 0, 0, 10), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1050 of 14800 combinations so far
# Trained and Tested combination 1051 of 14800: (35, 0, 0, 12), taking 0.15 seconds to get val score of 0.8742
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# % Combos Checked Thus Far: 1051 out of 14800 which is 7.101351%
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruise suspended due to suspicious case
# Guidance: round 20
#
# 	round 20 iteration:  0
#
# % Combos Checked Thus Far: 1051 out of 14800 which is 7.101351%
# Cruising Coordrdinate 0 of 756
#
# Cruising Coordrdinate 0 of 756
#
# Cruise suspended due to suspicious case
# Guidance: round 21
#
# 	round 21 iteration:  0
#
# % Combos Checked Thus Far: 1051 out of 14800 which is 7.101351%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (27, 1, 0, 10), which had val score of 0.8785
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Already Trained and Tested combination (29, 1, 0, 10), which had val score of 0.8784
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Already Trained and Tested combination (28, 0, 0, 10), which had val score of 0.8777
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Already Trained and Tested combination (28, 1, 1, 10), which had val score of 0.8752
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Already Trained and Tested combination (28, 1, 0, 9), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Already Trained and Tested combination (28, 1, 0, 11), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (26, 1, 0, 10), which had val score of 0.8783
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Already Trained and Tested combination (28, 1, 0, 10), which had val score of 0.8785
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Already Trained and Tested combination (27, 0, 0, 10), which had val score of 0.8779
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1051 of 14800 combinations so far
# Trained and Tested combination 1052 of 14800: (27, 1, 1, 10), taking 0.18 seconds to get val score of 0.8752
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Trained and Tested combination 1053 of 14800: (27, 1, 0, 9), taking 0.1 seconds to get val score of 0.8774
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Trained and Tested combination 1054 of 14800: (27, 1, 0, 11), taking 0.13 seconds to get val score of 0.8774
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (27, 1, 1, 10), which had val score of 0.8752
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1054 of 14800 combinations so far
# Already Trained and Tested combination (29, 1, 1, 10), which had val score of 0.8751
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1054 of 14800 combinations so far
# Trained and Tested combination 1055 of 14800: (28, 0, 1, 10), taking 0.11 seconds to get val score of 0.8744
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (28, 1, 0, 10), which had val score of 0.8785
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1055 of 14800 combinations so far
# Trained and Tested combination 1056 of 14800: (28, 1, 1, 9), taking 0.19 seconds to get val score of 0.8745
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Trained and Tested combination 1057 of 14800: (28, 1, 1, 11), taking 0.12 seconds to get val score of 0.8742
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (27, 1, 0, 9), which had val score of 0.8774
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1057 of 14800 combinations so far
# Already Trained and Tested combination (29, 1, 0, 9), which had val score of 0.8776
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1057 of 14800 combinations so far
# Trained and Tested combination 1058 of 14800: (28, 0, 0, 9), taking 0.1 seconds to get val score of 0.8757
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (28, 1, 1, 9), which had val score of 0.8745
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1058 of 14800 combinations so far
# Trained and Tested combination 1059 of 14800: (28, 1, 0, 8), taking 0.1 seconds to get val score of 0.8532
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (28, 1, 0, 10), which had val score of 0.8785
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1059 of 14800 combinations so far
# Already Trained and Tested combination (27, 1, 0, 11), which had val score of 0.8774
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1059 of 14800 combinations so far
# Already Trained and Tested combination (29, 1, 0, 11), which had val score of 0.8775
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1059 of 14800 combinations so far
# Trained and Tested combination 1060 of 14800: (28, 0, 0, 11), taking 0.12 seconds to get val score of 0.8759
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# Already Trained and Tested combination (28, 1, 1, 11), which had val score of 0.8742
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1060 of 14800 combinations so far
# Already Trained and Tested combination (28, 1, 0, 10), which had val score of 0.8785
#         Current best combo: (28, 1, 0, 10) with val score 0.8785.
#         Has trained 1060 of 14800 combinations so far
# Trained and Tested combination 1061 of 14800: (28, 1, 0, 12), taking 0.14 seconds to get val score of 0.8764
#         Current best combo: (28, 1, 0, 10) with val score 0.8785
# % Combos Checked Thus Far: 1061 out of 14800 which is 7.168919%
# Max Val Score:
#  0.878461
# Best Combo Test Score:
#  0.879539
# Best Combo Train Score:
#  0.999985
# Max Combo Index:
#  (28, 1, 0, 10) out of [100, 2, 2, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_neighbors': 29, 'p': 2, 'weights': 'distance', 'features': 10}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks')
# % Combos Checked: 1061 out of 14800 which is 7.168919%
