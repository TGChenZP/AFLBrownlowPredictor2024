# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'ada'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.2.6-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.6-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.6

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import AdaBoostRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'learning_rate': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# No previous tuning data read in
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 1554: (0, 6, 28), taking 3.56 seconds to get val score of -2.868
#         Current best combo: (0, 6, 28) with val score -2.868
# Trained and Tested combination 2 of 1554: (0, 6, 0), taking 0.59 seconds to get val score of -2.868
#         Current best combo: (0, 6, 28) with val score -2.868
# Trained and Tested combination 3 of 1554: (0, 0, 20), taking 12.53 seconds to get val score of 0.6287
#         Current best combo: (0, 0, 20) with val score 0.6287
# Trained and Tested combination 4 of 1554: (5, 3, 36), taking 422.92 seconds to get val score of 0.6295
#         Current best combo: (5, 3, 36) with val score 0.6295
# Trained and Tested combination 5 of 1554: (0, 6, 5), taking 0.57 seconds to get val score of -2.868
#         Current best combo: (5, 3, 36) with val score 0.6295
# Trained and Tested combination 6 of 1554: (0, 6, 32), taking 2.14 seconds to get val score of -2.868
#         Current best combo: (5, 3, 36) with val score 0.6295
# Trained and Tested combination 7 of 1554: (0, 3, 24), taking 13.57 seconds to get val score of 0.6969
#         Current best combo: (0, 3, 24) with val score 0.6969
# Trained and Tested combination 8 of 1554: (5, 0, 32), taking 575.01 seconds to get val score of 0.6323
#         Current best combo: (0, 3, 24) with val score 0.6969
# Trained and Tested combination 9 of 1554: (0, 3, 36), taking 19.79 seconds to get val score of 0.6969
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 10 of 1554: (0, 0, 36), taking 18.91 seconds to get val score of 0.6287
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 11 of 1554: (0, 0, 10), taking 6.47 seconds to get val score of 0.6287
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 12 of 1554: (0, 6, 10), taking 0.98 seconds to get val score of -2.868
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 13 of 1554: (0, 0, 28), taking 15.78 seconds to get val score of 0.6287
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 14 of 1554: (5, 0, 0), taking 40.05 seconds to get val score of 0.5758
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 15 of 1554: (0, 3, 0), taking 1.15 seconds to get val score of 0.5766
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 16 of 1554: (5, 3, 10), taking 97.58 seconds to get val score of 0.6383
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 17 of 1554: (0, 6, 36), taking 1.63 seconds to get val score of -2.868
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 18 of 1554: (5, 0, 10), taking 203.46 seconds to get val score of 0.6323
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 19 of 1554: (0, 3, 10), taking 5.63 seconds to get val score of 0.6969
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 20 of 1554: (0, 3, 5), taking 3.71 seconds to get val score of 0.688
#         Current best combo: (0, 3, 36) with val score 0.6969
# Trained and Tested combination 21 of 1554: (3, 3, 18), taking 73.66 seconds to get val score of 0.6986
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 22 of 1554: (5, 6, 36), taking 31.21 seconds to get val score of -2.7031
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 23 of 1554: (5, 3, 15), taking 198.12 seconds to get val score of 0.5991
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 24 of 1554: (0, 6, 20), taking 1.25 seconds to get val score of -2.868
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 25 of 1554: (0, 3, 20), taking 11.6 seconds to get val score of 0.6969
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 26 of 1554: (5, 0, 36), taking 617.14 seconds to get val score of 0.6323
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 27 of 1554: (0, 3, 32), taking 17.44 seconds to get val score of 0.6969
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 28 of 1554: (5, 6, 10), taking 17.38 seconds to get val score of -2.5388
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 29 of 1554: (5, 0, 20), taking 363.8 seconds to get val score of 0.6323
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 30 of 1554: (5, 3, 5), taking 33.01 seconds to get val score of 0.6458
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 31 of 1554: (0, 0, 0), taking 1.13 seconds to get val score of 0.5753
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 32 of 1554: (5, 3, 28), taking 346.29 seconds to get val score of 0.6208
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 33 of 1554: (5, 6, 24), taking 24.31 seconds to get val score of -2.7084
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 34 of 1554: (5, 3, 32), taking 388.23 seconds to get val score of 0.6242
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 35 of 1554: (5, 0, 28), taking 510.75 seconds to get val score of 0.6323
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 36 of 1554: (0, 3, 15), taking 8.89 seconds to get val score of 0.6969
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 37 of 1554: (5, 6, 5), taking 15.83 seconds to get val score of -2.4841
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 38 of 1554: (0, 0, 15), taking 8.7 seconds to get val score of 0.6287
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 39 of 1554: (5, 0, 15), taking 293.28 seconds to get val score of 0.6323
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 40 of 1554: (0, 3, 28), taking 15.7 seconds to get val score of 0.6969
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 41 of 1554: (5, 6, 0), taking 13.9 seconds to get val score of -2.6149
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 42 of 1554: (0, 0, 32), taking 18.71 seconds to get val score of 0.6287
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 43 of 1554: (5, 3, 20), taking 249.17 seconds to get val score of 0.6142
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 44 of 1554: (5, 0, 5), taking 116.39 seconds to get val score of 0.6323
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 45 of 1554: (0, 0, 24), taking 14.0 seconds to get val score of 0.6287
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 46 of 1554: (0, 0, 5), taking 3.37 seconds to get val score of 0.6287
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 47 of 1554: (5, 3, 24), taking 300.86 seconds to get val score of 0.6139
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 48 of 1554: (5, 3, 0), taking 6.6 seconds to get val score of 0.5538
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 49 of 1554: (0, 6, 15), taking 0.89 seconds to get val score of -2.868
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 50 of 1554: (5, 6, 28), taking 25.53 seconds to get val score of -2.7006
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 51 of 1554: (0, 6, 24), taking 1.19 seconds to get val score of -2.868
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 52 of 1554: (5, 0, 24), taking 446.34 seconds to get val score of 0.6323
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 53 of 1554: (5, 6, 15), taking 20.71 seconds to get val score of -2.6849
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 54 of 1554: (5, 6, 32), taking 30.14 seconds to get val score of -2.6924
#         Current best combo: (3, 3, 18) with val score 0.6986
# Trained and Tested combination 55 of 1554: (5, 6, 20), taking 23.36 seconds to get val score of -2.679
#         Current best combo: (3, 3, 18) with val score 0.6986
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 56 of 1554: (2, 3, 18), taking 38.98 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 18) with val score 0.7158
# Trained and Tested combination 57 of 1554: (4, 3, 18), taking 133.31 seconds to get val score of 0.6653
#         Current best combo: (2, 3, 18) with val score 0.7158
# Trained and Tested combination 58 of 1554: (3, 2, 18), taking 82.19 seconds to get val score of 0.6893
#         Current best combo: (2, 3, 18) with val score 0.7158
# Trained and Tested combination 59 of 1554: (3, 4, 18), taking 41.45 seconds to get val score of 0.5266
#         Current best combo: (2, 3, 18) with val score 0.7158
# Trained and Tested combination 60 of 1554: (3, 3, 17), taking 70.51 seconds to get val score of 0.6974
#         Current best combo: (2, 3, 18) with val score 0.7158
# Trained and Tested combination 61 of 1554: (3, 3, 19), taking 77.84 seconds to get val score of 0.6986
#         Current best combo: (2, 3, 18) with val score 0.7158
# 	round 0 iteration:  1
#
# Trained and Tested combination 62 of 1554: (1, 3, 18), taking 21.11 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 18) with val score 0.7158
# Already Trained and Tested combination (3, 3, 18), which had val score of 0.6986
#         Current best combo: (2, 3, 18) with val score 0.7158.
#         Has trained 62 of 1554 combinations so far
# Trained and Tested combination 63 of 1554: (2, 2, 18), taking 41.29 seconds to get val score of 0.6726
#         Current best combo: (2, 3, 18) with val score 0.7158
# Trained and Tested combination 64 of 1554: (2, 4, 18), taking 25.22 seconds to get val score of 0.6039
#         Current best combo: (2, 3, 18) with val score 0.7158
# Trained and Tested combination 65 of 1554: (2, 3, 17), taking 41.75 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 66 of 1554: (2, 3, 19), taking 41.76 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 17) with val score 0.7158
# Already Trained and Tested combination (2, 3, 17), which had val score of 0.7158
#         Current best combo: (2, 3, 17) with val score 0.7158.
#         Has trained 66 of 1554 combinations so far
# Trained and Tested combination 67 of 1554: (4, 3, 17), taking 114.26 seconds to get val score of 0.6727
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 68 of 1554: (3, 2, 17), taking 80.29 seconds to get val score of 0.6893
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 69 of 1554: (3, 4, 17), taking 40.97 seconds to get val score of 0.5206
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 70 of 1554: (3, 3, 16), taking 68.23 seconds to get val score of 0.6974
#         Current best combo: (2, 3, 17) with val score 0.7158
# Already Trained and Tested combination (3, 3, 18), which had val score of 0.6986
#         Current best combo: (2, 3, 17) with val score 0.7158.
#         Has trained 70 of 1554 combinations so far
# Already Trained and Tested combination (2, 3, 19), which had val score of 0.7158
#         Current best combo: (2, 3, 17) with val score 0.7158.
#         Has trained 70 of 1554 combinations so far
# Trained and Tested combination 71 of 1554: (4, 3, 19), taking 138.35 seconds to get val score of 0.6673
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 72 of 1554: (3, 2, 19), taking 85.27 seconds to get val score of 0.6893
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 73 of 1554: (3, 4, 19), taking 47.41 seconds to get val score of 0.5301
#         Current best combo: (2, 3, 17) with val score 0.7158
# Already Trained and Tested combination (3, 3, 18), which had val score of 0.6986
#         Current best combo: (2, 3, 17) with val score 0.7158.
#         Has trained 73 of 1554 combinations so far
# Trained and Tested combination 74 of 1554: (3, 3, 20), taking 81.32 seconds to get val score of 0.6986
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 75 of 1554: (1, 3, 17), taking 19.68 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 17) with val score 0.7158
# Already Trained and Tested combination (3, 3, 17), which had val score of 0.6974
#         Current best combo: (2, 3, 17) with val score 0.7158.
#         Has trained 75 of 1554 combinations so far
# Trained and Tested combination 76 of 1554: (2, 2, 17), taking 40.11 seconds to get val score of 0.6726
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 77 of 1554: (2, 4, 17), taking 23.66 seconds to get val score of 0.5832
#         Current best combo: (2, 3, 17) with val score 0.7158
# Trained and Tested combination 78 of 1554: (2, 3, 16), taking 37.57 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 16) with val score 0.7158
# Already Trained and Tested combination (2, 3, 18), which had val score of 0.7158
#         Current best combo: (2, 3, 16) with val score 0.7158.
#         Has trained 78 of 1554 combinations so far
# Trained and Tested combination 79 of 1554: (1, 3, 16), taking 18.66 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 16) with val score 0.7158
# Already Trained and Tested combination (3, 3, 16), which had val score of 0.6974
#         Current best combo: (2, 3, 16) with val score 0.7158.
#         Has trained 79 of 1554 combinations so far
# Trained and Tested combination 80 of 1554: (2, 2, 16), taking 39.4 seconds to get val score of 0.6726
#         Current best combo: (2, 3, 16) with val score 0.7158
# Trained and Tested combination 81 of 1554: (2, 4, 16), taking 24.21 seconds to get val score of 0.5819
#         Current best combo: (2, 3, 16) with val score 0.7158
# Trained and Tested combination 82 of 1554: (2, 3, 15), taking 34.47 seconds to get val score of 0.7152
#         Current best combo: (2, 3, 16) with val score 0.7158
# Already Trained and Tested combination (2, 3, 17), which had val score of 0.7158
#         Current best combo: (2, 3, 16) with val score 0.7158.
#         Has trained 82 of 1554 combinations so far
# % Combos Checked Thus Far: 82 out of 1554 which is 5.276705000000001%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 83 of 1554: (1, 3, 36), taking 39.11 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 16) with val score 0.7158
# Trained and Tested combination 84 of 1554: (0, 2, 36), taking 19.35 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 16) with val score 0.7158
# Trained and Tested combination 85 of 1554: (0, 4, 36), taking 17.38 seconds to get val score of 0.6904
#         Current best combo: (2, 3, 16) with val score 0.7158
# Trained and Tested combination 86 of 1554: (0, 3, 35), taking 19.34 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 16) with val score 0.7158
# 	round 1 iteration:  1
#
# Already Trained and Tested combination (0, 3, 36), which had val score of 0.6969
#         Current best combo: (2, 3, 16) with val score 0.7158.
#         Has trained 86 of 1554 combinations so far
# Trained and Tested combination 87 of 1554: (2, 3, 36), taking 74.67 seconds to get val score of 0.7166
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 88 of 1554: (1, 2, 36), taking 39.47 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 89 of 1554: (1, 4, 36), taking 30.77 seconds to get val score of 0.6561
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 90 of 1554: (1, 3, 35), taking 39.22 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 35), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 90 of 1554 combinations so far
# Trained and Tested combination 91 of 1554: (0, 2, 35), taking 18.84 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 92 of 1554: (0, 4, 35), taking 16.41 seconds to get val score of 0.6812
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 93 of 1554: (0, 3, 34), taking 18.83 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 36), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 93 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 36), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 93 of 1554 combinations so far
# Trained and Tested combination 94 of 1554: (3, 3, 36), taking 139.65 seconds to get val score of 0.6997
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 95 of 1554: (2, 2, 36), taking 78.23 seconds to get val score of 0.6726
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 96 of 1554: (2, 4, 36), taking 48.74 seconds to get val score of 0.6224
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 97 of 1554: (2, 3, 35), taking 74.89 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 36) with val score 0.7166
# % Combos Checked Thus Far: 97 out of 1554 which is 6.241956%
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Trained and Tested combination 98 of 1554: (1, 3, 5), taking 7.84 seconds to get val score of 0.706
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 99 of 1554: (0, 2, 5), taking 3.32 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 100 of 1554: (0, 4, 5), taking 2.86 seconds to get val score of 0.6443
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 101 of 1554: (0, 3, 4), taking 3.64 seconds to get val score of 0.6871
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 102 of 1554: (0, 3, 6), taking 4.35 seconds to get val score of 0.6934
#         Current best combo: (2, 3, 36) with val score 0.7166
# 	round 2 iteration:  1
#
# Already Trained and Tested combination (0, 3, 5), which had val score of 0.688
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 102 of 1554 combinations so far
# Trained and Tested combination 103 of 1554: (2, 3, 5), taking 13.95 seconds to get val score of 0.6948
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 104 of 1554: (1, 2, 5), taking 6.61 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 105 of 1554: (1, 4, 5), taking 5.59 seconds to get val score of 0.6214
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 106 of 1554: (1, 3, 4), taking 5.83 seconds to get val score of 0.6935
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 107 of 1554: (1, 3, 6), taking 8.99 seconds to get val score of 0.7111
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 4), which had val score of 0.6935
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 107 of 1554 combinations so far
# Trained and Tested combination 108 of 1554: (0, 2, 4), taking 3.01 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 109 of 1554: (0, 4, 4), taking 2.0 seconds to get val score of 0.646
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 110 of 1554: (0, 3, 3), taking 2.44 seconds to get val score of 0.6808
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 5), which had val score of 0.688
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 110 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 6), which had val score of 0.7111
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 110 of 1554 combinations so far
# Trained and Tested combination 111 of 1554: (0, 2, 6), taking 5.17 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 112 of 1554: (0, 4, 6), taking 3.33 seconds to get val score of 0.6419
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 5), which had val score of 0.688
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 112 of 1554 combinations so far
# Trained and Tested combination 113 of 1554: (0, 3, 7), taking 4.39 seconds to get val score of 0.6934
#         Current best combo: (2, 3, 36) with val score 0.7166
# % Combos Checked Thus Far: 113 out of 1554 which is 7.271557%
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 3
#
# 	round 3 iteration:  0
#
# Trained and Tested combination 114 of 1554: (1, 3, 10), taking 12.5 seconds to get val score of 0.711
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 115 of 1554: (0, 2, 10), taking 6.78 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 116 of 1554: (0, 4, 10), taking 4.99 seconds to get val score of 0.6869
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 117 of 1554: (0, 3, 9), taking 5.31 seconds to get val score of 0.6934
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 118 of 1554: (0, 3, 11), taking 7.32 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# 	round 3 iteration:  1
#
# Already Trained and Tested combination (0, 3, 10), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 118 of 1554 combinations so far
# Trained and Tested combination 119 of 1554: (2, 3, 10), taking 23.44 seconds to get val score of 0.7146
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 120 of 1554: (1, 2, 10), taking 11.83 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 121 of 1554: (1, 4, 10), taking 9.42 seconds to get val score of 0.6358
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 122 of 1554: (1, 3, 9), taking 11.81 seconds to get val score of 0.7115
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 123 of 1554: (1, 3, 11), taking 13.37 seconds to get val score of 0.711
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 9), which had val score of 0.7115
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 123 of 1554 combinations so far
# Trained and Tested combination 124 of 1554: (0, 2, 9), taking 5.38 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 125 of 1554: (0, 4, 9), taking 5.74 seconds to get val score of 0.6808
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 126 of 1554: (0, 3, 8), taking 5.01 seconds to get val score of 0.6934
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 10), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 126 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 11), which had val score of 0.711
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 126 of 1554 combinations so far
# Trained and Tested combination 127 of 1554: (0, 2, 11), taking 6.65 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 128 of 1554: (0, 4, 11), taking 6.12 seconds to get val score of 0.6827
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 10), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 128 of 1554 combinations so far
# Trained and Tested combination 129 of 1554: (0, 3, 12), taking 7.04 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# % Combos Checked Thus Far: 129 out of 1554 which is 8.301158000000001%
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 4
#
# 	round 4 iteration:  0
#
# Trained and Tested combination 130 of 1554: (1, 3, 15), taking 19.13 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 131 of 1554: (0, 2, 15), taking 8.36 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 132 of 1554: (0, 4, 15), taking 8.34 seconds to get val score of 0.6733
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 133 of 1554: (0, 3, 14), taking 8.21 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 134 of 1554: (0, 3, 16), taking 9.36 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# 	round 4 iteration:  1
#
# Already Trained and Tested combination (0, 3, 15), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 134 of 1554 combinations so far
# Already Trained and Tested combination (2, 3, 15), which had val score of 0.7152
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 134 of 1554 combinations so far
# Trained and Tested combination 135 of 1554: (1, 2, 15), taking 17.98 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 136 of 1554: (1, 4, 15), taking 13.07 seconds to get val score of 0.6317
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 137 of 1554: (1, 3, 14), taking 17.28 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 16), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 137 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 14), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 137 of 1554 combinations so far
# Trained and Tested combination 138 of 1554: (0, 2, 14), taking 8.28 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 139 of 1554: (0, 4, 14), taking 7.96 seconds to get val score of 0.6758
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 140 of 1554: (0, 3, 13), taking 7.36 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 15), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 140 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 16), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 140 of 1554 combinations so far
# Trained and Tested combination 141 of 1554: (0, 2, 16), taking 9.93 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 142 of 1554: (0, 4, 16), taking 7.75 seconds to get val score of 0.6864
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 15), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 142 of 1554 combinations so far
# Trained and Tested combination 143 of 1554: (0, 3, 17), taking 9.94 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# % Combos Checked Thus Far: 143 out of 1554 which is 9.202059%
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 5
#
# 	round 5 iteration:  0
#
# Trained and Tested combination 144 of 1554: (1, 3, 20), taking 22.93 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 145 of 1554: (0, 2, 20), taking 11.02 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 146 of 1554: (0, 4, 20), taking 9.49 seconds to get val score of 0.6793
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 147 of 1554: (0, 3, 19), taking 10.98 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 148 of 1554: (0, 3, 21), taking 12.03 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# 	round 5 iteration:  1
#
# Already Trained and Tested combination (0, 3, 20), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 148 of 1554 combinations so far
# Trained and Tested combination 149 of 1554: (2, 3, 20), taking 43.51 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 150 of 1554: (1, 2, 20), taking 22.21 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 151 of 1554: (1, 4, 20), taking 17.72 seconds to get val score of 0.6468
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 152 of 1554: (1, 3, 19), taking 20.77 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 153 of 1554: (1, 3, 21), taking 24.15 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 19), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 153 of 1554 combinations so far
# Trained and Tested combination 154 of 1554: (0, 2, 19), taking 10.43 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 155 of 1554: (0, 4, 19), taking 9.04 seconds to get val score of 0.6793
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 156 of 1554: (0, 3, 18), taking 10.74 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 20), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 156 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 21), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 156 of 1554 combinations so far
# Trained and Tested combination 157 of 1554: (0, 2, 21), taking 12.16 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 158 of 1554: (0, 4, 21), taking 9.26 seconds to get val score of 0.6793
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 20), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 158 of 1554 combinations so far
# Trained and Tested combination 159 of 1554: (0, 3, 22), taking 12.58 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# % Combos Checked Thus Far: 159 out of 1554 which is 10.23166%
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Trained and Tested combination 160 of 1554: (1, 3, 24), taking 27.46 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 161 of 1554: (0, 2, 24), taking 13.96 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 162 of 1554: (0, 4, 24), taking 12.04 seconds to get val score of 0.6825
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 163 of 1554: (0, 3, 23), taking 13.25 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 164 of 1554: (0, 3, 25), taking 14.41 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# 	round 6 iteration:  1
#
# Already Trained and Tested combination (0, 3, 24), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 164 of 1554 combinations so far
# Trained and Tested combination 165 of 1554: (2, 3, 24), taking 52.57 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 166 of 1554: (1, 2, 24), taking 27.11 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 167 of 1554: (1, 4, 24), taking 20.7 seconds to get val score of 0.6493
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 168 of 1554: (1, 3, 23), taking 26.01 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 169 of 1554: (1, 3, 25), taking 28.28 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 23), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 169 of 1554 combinations so far
# Trained and Tested combination 170 of 1554: (0, 2, 23), taking 12.95 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 171 of 1554: (0, 4, 23), taking 10.32 seconds to get val score of 0.6874
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 22), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 171 of 1554 combinations so far
# Already Trained and Tested combination (0, 3, 24), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 171 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 25), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 171 of 1554 combinations so far
# Trained and Tested combination 172 of 1554: (0, 2, 25), taking 14.29 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 173 of 1554: (0, 4, 25), taking 12.41 seconds to get val score of 0.6828
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 24), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 173 of 1554 combinations so far
# Trained and Tested combination 174 of 1554: (0, 3, 26), taking 14.86 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# % Combos Checked Thus Far: 174 out of 1554 which is 11.196911%
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Trained and Tested combination 175 of 1554: (1, 3, 28), taking 31.8 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 176 of 1554: (0, 2, 28), taking 16.08 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 177 of 1554: (0, 4, 28), taking 13.37 seconds to get val score of 0.6848
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 178 of 1554: (0, 3, 27), taking 15.28 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 179 of 1554: (0, 3, 29), taking 16.37 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# 	round 7 iteration:  1
#
# Already Trained and Tested combination (0, 3, 28), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 179 of 1554 combinations so far
# Trained and Tested combination 180 of 1554: (2, 3, 28), taking 60.4 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 181 of 1554: (1, 2, 28), taking 31.68 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 182 of 1554: (1, 4, 28), taking 24.12 seconds to get val score of 0.6516
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 183 of 1554: (1, 3, 27), taking 30.12 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 184 of 1554: (1, 3, 29), taking 32.12 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 27), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 184 of 1554 combinations so far
# Trained and Tested combination 185 of 1554: (0, 2, 27), taking 15.22 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 186 of 1554: (0, 4, 27), taking 13.34 seconds to get val score of 0.6848
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 26), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 186 of 1554 combinations so far
# Already Trained and Tested combination (0, 3, 28), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 186 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 29), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 186 of 1554 combinations so far
# Trained and Tested combination 187 of 1554: (0, 2, 29), taking 16.22 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 188 of 1554: (0, 4, 29), taking 14.09 seconds to get val score of 0.6815
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 28), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 188 of 1554 combinations so far
# Trained and Tested combination 189 of 1554: (0, 3, 30), taking 16.77 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# % Combos Checked Thus Far: 189 out of 1554 which is 12.162162%
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruising Coordrdinate 0 of 54
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# Trained and Tested combination 190 of 1554: (1, 3, 32), taking 35.7 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 191 of 1554: (0, 2, 32), taking 17.55 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 192 of 1554: (0, 4, 32), taking 15.28 seconds to get val score of 0.6812
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 193 of 1554: (0, 3, 31), taking 17.05 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 194 of 1554: (0, 3, 33), taking 18.94 seconds to get val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166
# 	round 8 iteration:  1
#
# Already Trained and Tested combination (0, 3, 32), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 194 of 1554 combinations so far
# Trained and Tested combination 195 of 1554: (2, 3, 32), taking 68.3 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 196 of 1554: (1, 2, 32), taking 36.97 seconds to get val score of 0.6497
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 197 of 1554: (1, 4, 32), taking 26.86 seconds to get val score of 0.6529
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 198 of 1554: (1, 3, 31), taking 34.35 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 199 of 1554: (1, 3, 33), taking 37.29 seconds to get val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (1, 3, 31), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 199 of 1554 combinations so far
# Trained and Tested combination 200 of 1554: (0, 2, 31), taking 17.06 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 201 of 1554: (0, 4, 31), taking 14.82 seconds to get val score of 0.6815
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 30), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 201 of 1554 combinations so far
# Already Trained and Tested combination (0, 3, 32), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 201 of 1554 combinations so far
# Already Trained and Tested combination (1, 3, 33), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 201 of 1554 combinations so far
# Trained and Tested combination 202 of 1554: (0, 2, 33), taking 17.97 seconds to get val score of 0.6421
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 203 of 1554: (0, 4, 33), taking 15.41 seconds to get val score of 0.6812
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (0, 3, 32), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# Already Trained and Tested combination (0, 3, 34), which had val score of 0.6969
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# % Combos Checked Thus Far: 203 out of 1554 which is 13.063063%
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (1, 3, 36), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# Already Trained and Tested combination (3, 3, 36), which had val score of 0.6997
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# Already Trained and Tested combination (2, 2, 36), which had val score of 0.6726
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# Already Trained and Tested combination (2, 4, 36), which had val score of 0.6224
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# Already Trained and Tested combination (2, 3, 35), which had val score of 0.7158
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# 	round FINAL iteration:  1
#
# Already Trained and Tested combination (1, 3, 35), which had val score of 0.7127
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 203 of 1554 combinations so far
# Trained and Tested combination 204 of 1554: (3, 3, 35), taking 140.28 seconds to get val score of 0.6989
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 205 of 1554: (2, 2, 35), taking 77.43 seconds to get val score of 0.6726
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 206 of 1554: (2, 4, 35), taking 49.08 seconds to get val score of 0.615
#         Current best combo: (2, 3, 36) with val score 0.7166
# Trained and Tested combination 207 of 1554: (2, 3, 34), taking 72.07 seconds to get val score of 0.7158
#         Current best combo: (2, 3, 36) with val score 0.7166
# Already Trained and Tested combination (2, 3, 36), which had val score of 0.7166
#         Current best combo: (2, 3, 36) with val score 0.7166.
#         Has trained 207 of 1554 combinations so far
# % Combos Checked Thus Far: 207 out of 1554 which is 13.320462999999998%
# Max Val Score:
#  0.7165905217751881
# Best Combo Test Score:
#  0.720137
# Best Combo Train Score:
#  0.720507
# Max Combo Index:
#  (2, 3, 36) out of [6, 7, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 100, 'learning_rate': 0.1, 'features': 36}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Rebound 50s', 'Disposal Efficiency %', 'Uncontested Marks', 'Frees For', 'Clearances', 'Inside 50s', 'Turnovers', 'Bounces', 'Uncontested Possessions', 'Centre Clearances', 'Behinds', 'Stoppage Clearances', 'Ineffective Disposals', 'Winloss')
# % Combos Checked: 207 out of 1554 which is 13.320462999999998%
