# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nusvm(rbf)'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.2.6-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.6-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.6

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 767 rows, for 767.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 5, 20), which had val score of -8.049451980139847e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 5, 28), which had val score of -2.4739759142260002e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 4, 0, 0), which had val score of 0.0844
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 0, 0), which had val score of 0.0029
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 15), which had val score of 0.0031
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 0, 36), which had val score of 0.0037
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 0, 36), which had val score of 0.1057
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 5, 10), which had val score of -4.811791481630599e+40
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 0, 24), which had val score of 0.0041
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 5, 32), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 4, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 4, 0, 15), which had val score of 0.1216
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 5, 20), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 20), which had val score of 0.0034
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 0, 20), which had val score of 0.0031
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 4, 5, 24), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 28), which had val score of 0.0027
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 0, 24), which had val score of 0.1197
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 5, 15), which had val score of -7.199460692489783e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 0, 0, 0), which had val score of 0.0861
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 5, 24), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 5, 20), which had val score of -4.490776516355282e+42
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 5, 32), which had val score of -1.8530120799324367e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 0, 0, 20), which had val score of 0.0926
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 0, 0, 20), which had val score of 0.0927
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 0, 32), which had val score of 0.1056
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 36), which had val score of 0.0028
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 5, 0), which had val score of -3.4807989641515666e+41
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 0, 5, 0), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 0, 10), which had val score of 0.0041
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 10), which had val score of 0.0027
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 4, 0, 10), which had val score of 0.0032
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 20), which had val score of 0.0028
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 0, 0, 10), which had val score of 0.0927
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 0, 0, 5), which had val score of 0.1131
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 4, 0, 36), which had val score of 0.0926
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 5, 5), which had val score of -2.2357495107417782e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 28), which had val score of 0.0035
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 0, 5, 28), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 4, 5, 32), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 5, 24), which had val score of -1.7716605577002754e+40
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 0, 5, 0), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 4, 5, 20), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 4, 0, 10), which had val score of 0.0926
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 0, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 4, 5, 20), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 4, 0, 32), which had val score of 0.1083
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 0, 0, 36), which had val score of 0.1072
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 0), which had val score of 0.0028
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 0, 0, 0, 36), which had val score of 0.0847
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 0, 0, 5), which had val score of 0.0927
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 4, 5, 5), which had val score of -1.0035106786026244e+41
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 5, 36), which had val score of -2.69419116943829e+40
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 0, 36), which had val score of 0.0041
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 4, 0, 32), which had val score of 0.1212
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 0, 5), which had val score of 0.0027
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 0, 15), which had val score of 0.1
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 5), which had val score of 0.0038
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 36), which had val score of 0.0031
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 4, 5, 28), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 0, 0, 36), which had val score of 0.0927
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 4, 5, 0), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 15), which had val score of 0.0031
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 4, 0, 32), which had val score of 0.1232
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 10), which had val score of 0.0032
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 0, 20), which had val score of 0.004
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 5, 20), which had val score of -2.7490938694301096e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 0, 15), which had val score of 0.0041
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 4, 0, 15), which had val score of 0.1028
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 5, 24), which had val score of -2.7490938694301096e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 0, 0, 32), which had val score of 0.0926
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 0), which had val score of 0.0029
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 0, 0, 15), which had val score of 0.122
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 0, 24), which had val score of 0.1197
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 24), which had val score of 0.0036
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 4, 0, 5), which had val score of 0.0804
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 5, 28), which had val score of -1.198632009621405e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 4, 0, 20), which had val score of 0.105
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 5, 0), which had val score of -1.0665596170212332e+38
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 4, 0, 32), which had val score of 0.0848
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 0, 4, 5, 5), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 4, 5, 0), which had val score of -3.8116406598559885e+40
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 4, 0, 24), which had val score of 0.1075
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 0, 28), which had val score of 0.1194
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 10), which had val score of 0.0027
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 5, 32), which had val score of -1.851836563758008e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 5, 24), which had val score of -2.696030068982606e+41
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 0, 5, 20), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 5, 36), which had val score of -3.6844019017243027e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 4, 0, 24), which had val score of 0.0927
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 4, 5, 24), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 0, 0, 5, 20), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 5, 20), which had val score of -4.268031815424214e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 4, 5, 24), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 4, 5, 5), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 0, 0, 28), which had val score of 0.1056
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 0, 0, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 0, 10), which had val score of 0.0027
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 10), which had val score of 0.0032
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 0, 5, 0), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 5, 5), which had val score of -8.332510638363966e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 36), which had val score of 0.0036
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 24), which had val score of 0.0035
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 24), which had val score of 0.0031
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 4, 0, 24), which had val score of 0.0031
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 5, 20), which had val score of -1.836746816920145e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 4, 0, 15), which had val score of 0.1027
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 20), which had val score of 0.0034
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 0, 5), which had val score of 0.0026
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 0, 28), which had val score of 0.0041
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 0, 0), which had val score of 0.0028
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 5, 15), which had val score of -4.341499799034545e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 5), which had val score of 0.0025
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 20), which had val score of 0.0035
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 0, 28), which had val score of 0.084
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 0, 32), which had val score of 0.0028
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 15), which had val score of 0.0026
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 5, 15), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 4, 0, 36), which had val score of 0.1099
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 0, 0), which had val score of 0.0846
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 5, 20), which had val score of -2.7490938694301096e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 0, 0), which had val score of 0.0029
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 4, 0, 0), which had val score of 0.0861
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 0, 0, 24), which had val score of 0.1211
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 4, 5, 32), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 5, 36), which had val score of -1.986563272203476e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 28) with val score 0.1233.
#         Has trained 767 of 1165500 combinations so far
# As new Best Combo (5, 6, 4, 4, 4, 0, 20) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 6, 4, 4, 4, 0, 20), which had val score of 0.1234
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 0, 0, 10), which had val score of 0.1225
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 5, 15), which had val score of -2.093681745350751e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 4, 0, 24), which had val score of 0.1088
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 28), which had val score of 0.0036
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 5, 28), which had val score of -3.0651745505797223e+40
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 5), which had val score of 0.0027
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 4, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 15), which had val score of -4.4784468308099066e+41
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 4, 5, 15), which had val score of -1.568115154374832e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 15), which had val score of 0.0033
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 5, 24), which had val score of -1.4879109231193518e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 0, 5, 32), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 4, 5, 0), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 36), which had val score of 0.0036
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 5, 36), which had val score of -1.5893348856015336e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 4, 5, 32), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 5, 10), which had val score of -1.1970350501734325e+45
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 36), which had val score of 0.0028
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 0, 0, 20), which had val score of 0.1214
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 0, 0, 0, 36), which had val score of 0.1072
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 0, 5), which had val score of 0.0038
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 5, 36), which had val score of -2.0034635783237797e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 5, 36), which had val score of -1.5031742792120209e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 5, 5), which had val score of -5.369006605654507e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 5, 28), which had val score of -2.7490938694301096e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 5, 20), which had val score of -4.52329579480668e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 32), which had val score of 0.004
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 28), which had val score of 0.0031
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 5, 5), which had val score of -3.881103500519602e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 0, 20), which had val score of 0.1022
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 24), which had val score of 0.0035
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 0, 15), which had val score of 0.0042
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 4, 5, 10), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 4, 5, 24), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 4, 5, 36), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 0, 5, 15), which had val score of 0.0
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 4, 5, 32), which had val score of -5.40292374526571e+43
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 0, 0, 20), which had val score of 0.1214
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 28), which had val score of 0.004
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 0, 24), which had val score of 0.1049
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 4, 0, 5), which had val score of 0.1148
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 0, 10), which had val score of 0.004
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 5, 20), which had val score of -1.8520703449996794e+44
#         Current best combo: (5, 6, 4, 4, 4, 0, 20) with val score 0.1234.
#         Has trained 767 of 1165500 combinations so far
# As new Best Combo (5, 3, 4, 4, 4, 0, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 3, 4, 4, 4, 0, 10), which had val score of 0.1235
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 0, 28), which had val score of 0.004
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 5, 15), which had val score of -6.345032708158559e+39
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 32), which had val score of 0.0036
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 5, 5), which had val score of -1.1820825918737934e+42
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 5), which had val score of -7.356615578367784e+41
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 5, 36), which had val score of -7.321698659053496e+42
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 5), which had val score of 0.0025
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 5, 5), which had val score of -8.732041432992248e+43
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 0, 36), which had val score of 0.0031
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 36), which had val score of -1.225619922993119e+44
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 0, 0, 0), which had val score of 0.0861
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 0, 5, 28), which had val score of 0.0
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 4, 0, 32), which had val score of 0.1232
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5, 36), which had val score of -5.012632625262074e+43
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 5, 24), which had val score of 0.0
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 4, 4, 4, 5, 36), which had val score of 0.0
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5, 32), which had val score of -9.891266999139193e+41
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 24), which had val score of 0.0028
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 32), which had val score of 0.0037
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 0, 4, 0, 32), which had val score of 0.0846
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 4, 0, 0, 10), which had val score of 0.1225
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 4, 4, 0, 0, 28), which had val score of 0.0926
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 0, 10), which had val score of 0.0031
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 5, 28), which had val score of -6.166833256531999e+41
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 0, 32), which had val score of 0.1192
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 0, 0), which had val score of 0.0029
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 15), which had val score of 0.0032
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 4, 0, 28), which had val score of 0.084
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 4, 5, 10), which had val score of 0.0
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 0, 32), which had val score of 0.1192
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 20), which had val score of 0.0041
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 4, 0, 5), which had val score of 0.0927
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 5, 15), which had val score of -9.350595832378722e+40
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 0, 0, 4, 0, 5, 10), which had val score of 0.0
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 5, 10), which had val score of -2.928545112879978e+43
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 5, 28), which had val score of -1.056264715006881e+42
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 0, 5, 15), which had val score of 0.0
#         Current best combo: (5, 3, 4, 4, 4, 0, 10) with val score 0.1235.
#         Has trained 767 of 1165500 combinations so far
# ...
#         Has trained 1061 of 1165500 combinations so far
# Trained and Tested combination 1062 of 1165500: (4, 1, 4, 0, 1, 3, 18), taking 3.2 seconds to get val score of 0.895
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 4, 2, 1, 3, 18), which had val score of 0.8968
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1062 of 1165500 combinations so far
# Trained and Tested combination 1063 of 1165500: (4, 1, 4, 1, 0, 3, 18), taking 3.61 seconds to get val score of 0.8956
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1064 of 1165500: (4, 1, 4, 1, 2, 3, 18), taking 6.75 seconds to get val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1065 of 1165500: (4, 1, 4, 1, 1, 2, 18), taking 4.42 seconds to get val score of 0.8782
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1066 of 1165500: (4, 1, 4, 1, 1, 4, 18), taking 6.72 seconds to get val score of 0.7733
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1067 of 1165500: (4, 1, 4, 1, 1, 3, 17), taking 3.3 seconds to get val score of 0.8954
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1068 of 1165500: (4, 1, 4, 1, 1, 3, 19), taking 3.7 seconds to get val score of 0.8954
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (3, 1, 4, 3, 1, 3, 18), which had val score of 0.895
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1068 of 1165500 combinations so far
# Already Trained and Tested combination (5, 1, 4, 3, 1, 3, 18), which had val score of 0.8941
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1068 of 1165500 combinations so far
# Already Trained and Tested combination (4, 0, 4, 3, 1, 3, 18), which had val score of 0.8915
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1068 of 1165500 combinations so far
# Trained and Tested combination 1069 of 1165500: (4, 2, 4, 3, 1, 3, 18), taking 75.68 seconds to get val score of 0.8865
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 3, 3, 1, 3, 18), which had val score of 0.8949
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1069 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 2, 1, 3, 18), which had val score of 0.8968
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1069 of 1165500 combinations so far
# Trained and Tested combination 1070 of 1165500: (4, 1, 4, 4, 1, 3, 18), taking 5.05 seconds to get val score of 0.894
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1071 of 1165500: (4, 1, 4, 3, 0, 3, 18), taking 7.58 seconds to get val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1072 of 1165500: (4, 1, 4, 3, 2, 3, 18), taking 4.33 seconds to get val score of 0.8951
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1073 of 1165500: (4, 1, 4, 3, 1, 2, 18), taking 8.6 seconds to get val score of 0.8799
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1074 of 1165500: (4, 1, 4, 3, 1, 4, 18), taking 4.59 seconds to get val score of 0.7902
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1075 of 1165500: (4, 1, 4, 3, 1, 3, 17), taking 7.08 seconds to get val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1076 of 1165500: (4, 1, 4, 3, 1, 3, 19), taking 4.55 seconds to get val score of 0.8954
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (3, 1, 4, 2, 0, 3, 18), which had val score of 0.8963
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1076 of 1165500 combinations so far
# Already Trained and Tested combination (5, 1, 4, 2, 0, 3, 18), which had val score of 0.8956
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1076 of 1165500 combinations so far
# Already Trained and Tested combination (4, 0, 4, 2, 0, 3, 18), which had val score of 0.8922
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1076 of 1165500 combinations so far
# Trained and Tested combination 1077 of 1165500: (4, 2, 4, 2, 0, 3, 18), taking 66.35 seconds to get val score of 0.8876
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 3, 2, 0, 3, 18), which had val score of 0.8963
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1077 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 1, 0, 3, 18), which had val score of 0.8956
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1077 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 3, 0, 3, 18), which had val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1077 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 2, 1, 3, 18), which had val score of 0.8968
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1077 of 1165500 combinations so far
# Trained and Tested combination 1078 of 1165500: (4, 1, 4, 2, 0, 2, 18), taking 7.71 seconds to get val score of 0.8802
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1079 of 1165500: (4, 1, 4, 2, 0, 4, 18), taking 4.09 seconds to get val score of 0.7741
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1080 of 1165500: (4, 1, 4, 2, 0, 3, 17), taking 3.71 seconds to get val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1081 of 1165500: (4, 1, 4, 2, 0, 3, 19), taking 7.29 seconds to get val score of 0.8964
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (3, 1, 4, 2, 2, 3, 18), which had val score of 0.8961
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1081 of 1165500 combinations so far
# Already Trained and Tested combination (5, 1, 4, 2, 2, 3, 18), which had val score of 0.895
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1081 of 1165500 combinations so far
# Already Trained and Tested combination (4, 0, 4, 2, 2, 3, 18), which had val score of 0.8922
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1081 of 1165500 combinations so far
# Trained and Tested combination 1082 of 1165500: (4, 2, 4, 2, 2, 3, 18), taking 33.54 seconds to get val score of 0.8877
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 3, 2, 2, 3, 18), which had val score of 0.896
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1082 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 1, 2, 3, 18), which had val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1082 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 3, 2, 3, 18), which had val score of 0.8951
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1082 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 2, 1, 3, 18), which had val score of 0.8968
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1082 of 1165500 combinations so far
# Trained and Tested combination 1083 of 1165500: (4, 1, 4, 2, 3, 3, 18), taking 4.8 seconds to get val score of 0.8959
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1084 of 1165500: (4, 1, 4, 2, 2, 2, 18), taking 4.87 seconds to get val score of 0.8802
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1085 of 1165500: (4, 1, 4, 2, 2, 4, 18), taking 7.1 seconds to get val score of 0.771
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1086 of 1165500: (4, 1, 4, 2, 2, 3, 17), taking 3.76 seconds to get val score of 0.8956
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1087 of 1165500: (4, 1, 4, 2, 2, 3, 19), taking 4.38 seconds to get val score of 0.8961
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (3, 1, 4, 2, 1, 3, 17), which had val score of 0.8949
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1087 of 1165500 combinations so far
# Already Trained and Tested combination (5, 1, 4, 2, 1, 3, 17), which had val score of 0.8948
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1087 of 1165500 combinations so far
# Already Trained and Tested combination (4, 0, 4, 2, 1, 3, 17), which had val score of 0.8917
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1087 of 1165500 combinations so far
# Trained and Tested combination 1088 of 1165500: (4, 2, 4, 2, 1, 3, 17), taking 62.58 seconds to get val score of 0.8863
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 3, 2, 1, 3, 17), which had val score of 0.8955
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1088 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 1, 1, 3, 17), which had val score of 0.8954
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1088 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 3, 1, 3, 17), which had val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1088 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 2, 0, 3, 17), which had val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1088 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 2, 2, 3, 17), which had val score of 0.8956
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1088 of 1165500 combinations so far
# Trained and Tested combination 1089 of 1165500: (4, 1, 4, 2, 1, 2, 17), taking 4.62 seconds to get val score of 0.8798
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1090 of 1165500: (4, 1, 4, 2, 1, 4, 17), taking 7.12 seconds to get val score of 0.7963
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1091 of 1165500: (4, 1, 4, 2, 1, 3, 16), taking 3.61 seconds to get val score of 0.8943
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 4, 2, 1, 3, 18), which had val score of 0.8968
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1091 of 1165500 combinations so far
# Already Trained and Tested combination (3, 1, 4, 2, 1, 3, 19), which had val score of 0.8961
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1091 of 1165500 combinations so far
# Already Trained and Tested combination (5, 1, 4, 2, 1, 3, 19), which had val score of 0.8953
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1091 of 1165500 combinations so far
# Already Trained and Tested combination (4, 0, 4, 2, 1, 3, 19), which had val score of 0.8925
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1091 of 1165500 combinations so far
# Trained and Tested combination 1092 of 1165500: (4, 2, 4, 2, 1, 3, 19), taking 68.85 seconds to get val score of 0.8883
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 3, 2, 1, 3, 19), which had val score of 0.8956
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1092 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 1, 1, 3, 19), which had val score of 0.8954
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1092 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 3, 1, 3, 19), which had val score of 0.8954
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1092 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 2, 0, 3, 19), which had val score of 0.8964
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1092 of 1165500 combinations so far
# Already Trained and Tested combination (4, 1, 4, 2, 2, 3, 19), which had val score of 0.8961
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1092 of 1165500 combinations so far
# Trained and Tested combination 1093 of 1165500: (4, 1, 4, 2, 1, 2, 19), taking 8.08 seconds to get val score of 0.8804
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Trained and Tested combination 1094 of 1165500: (4, 1, 4, 2, 1, 4, 19), taking 4.14 seconds to get val score of 0.785
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# Already Trained and Tested combination (4, 1, 4, 2, 1, 3, 18), which had val score of 0.8968
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968.
#         Has trained 1094 of 1165500 combinations so far
# Trained and Tested combination 1095 of 1165500: (4, 1, 4, 2, 1, 3, 20), taking 4.11 seconds to get val score of 0.8967
#         Current best combo: (4, 1, 4, 2, 1, 3, 18) with val score 0.8968
# % Combos Checked Thus Far: 1095 out of 1165500 which is 0.09395099999999999%
# Max Val Score:
#  0.8968300301294004
# Best Combo Test Score:
#  0.896192
# Best Combo Train Score:
#  0.939061
# Max Combo Index:
#  (4, 1, 4, 2, 1, 3, 18) out of [6, 7, 5, 5, 5, 6, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 400, 'max_depth': 6, 'subsample': 1, 'colsample_bytree': 0.7, 'gamma': 1e-06, 'eta': 0.1, 'features': 18}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains')
# % Combos Checked: 1095 out of 1165500 which is 0.09395099999999999%
