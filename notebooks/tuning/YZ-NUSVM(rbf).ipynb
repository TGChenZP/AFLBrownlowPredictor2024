# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'nusvm(rbf)'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.3.0-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 828.4 kB/s eta 0:00:00
# Downloading JXAutoML-0.3.0-py3-none-any.whl (34 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.3.0

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.svm import NuSVR as clf

# what values to try for each hyperparameter
parameter_choices = {
    'C': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'tol': (0.0001, 0.001, 0.01, 0.1, 1, 10),
    'max_iter': (50, 100, 200, 400, 800, 1600),
    'gamma': ('scale', 'auto')
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'verbose': False,
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.svm._classes.NuSVR'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# BEGIN TUNING
#
#
# STAGE ZERO: Tune all Cruise combinations
#
#
# Trained and Tested combination 1 of 15984: (5, 5, 5, 1, 10), taking 47.27 seconds to get val score of -1.4906
#         Current best combo: (5, 5, 5, 1, 10) with val score -1.4906
# Trained and Tested combination 2 of 15984: (0, 0, 5, 0, 0), taking 33.23 seconds to get val score of -1.4757
#         Current best combo: (0, 0, 5, 0, 0) with val score -1.4757
# Trained and Tested combination 3 of 15984: (5, 0, 0, 1, 0), taking 28.8 seconds to get val score of -0.3355
#         Current best combo: (5, 0, 0, 1, 0) with val score -0.3355
# Trained and Tested combination 4 of 15984: (0, 5, 0, 1, 28), taking 55.56 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 0) with val score -0.3355
# Trained and Tested combination 5 of 15984: (5, 0, 0, 1, 32), taking 46.39 seconds to get val score of 0.1339
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 6 of 15984: (5, 5, 0, 0, 20), taking 45.44 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 7 of 15984: (5, 5, 5, 0, 20), taking 46.41 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 8 of 15984: (0, 0, 5, 1, 15), taking 45.48 seconds to get val score of -1.0756
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 9 of 15984: (5, 5, 5, 0, 32), taking 45.59 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 10 of 15984: (5, 5, 0, 1, 15), taking 42.66 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 11 of 15984: (0, 5, 5, 1, 36), taking 51.01 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 12 of 15984: (5, 5, 0, 0, 10), taking 40.89 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 13 of 15984: (5, 5, 5, 1, 28), taking 55.91 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 14 of 15984: (0, 5, 0, 0, 10), taking 40.96 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 15 of 15984: (5, 0, 0, 1, 5), taking 35.31 seconds to get val score of -9.4116
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 16 of 15984: (0, 0, 5, 1, 24), taking 58.01 seconds to get val score of -1.207
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 17 of 15984: (5, 0, 5, 0, 0), taking 32.79 seconds to get val score of -2.7734
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 18 of 15984: (0, 5, 5, 0, 32), taking 46.93 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 19 of 15984: (0, 5, 0, 0, 28), taking 54.82 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 32) with val score 0.1339
# Trained and Tested combination 20 of 15984: (5, 0, 0, 1, 20), taking 46.83 seconds to get val score of 0.2517
#         Current best combo: (5, 0, 0, 1, 20) with val score 0.2517
# Trained and Tested combination 21 of 15984: (5, 5, 0, 1, 36), taking 51.1 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 20) with val score 0.2517
# Trained and Tested combination 22 of 15984: (5, 5, 5, 0, 0), taking 29.26 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 20) with val score 0.2517
# Trained and Tested combination 23 of 15984: (0, 5, 0, 1, 32), taking 47.36 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 20) with val score 0.2517
# Trained and Tested combination 24 of 15984: (0, 0, 0, 0, 5), taking 35.59 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 20) with val score 0.2517
# Trained and Tested combination 25 of 15984: (5, 0, 0, 1, 28), taking 56.39 seconds to get val score of 0.5345
#         Current best combo: (5, 0, 0, 1, 28) with val score 0.5345
# Trained and Tested combination 26 of 15984: (5, 5, 5, 0, 10), taking 41.06 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 28) with val score 0.5345
# Trained and Tested combination 27 of 15984: (0, 5, 5, 1, 0), taking 28.82 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 0, 1, 28) with val score 0.5345
# Trained and Tested combination 28 of 15984: (5, 0, 5, 1, 10), taking 47.28 seconds to get val score of 0.5458
#         Current best combo: (5, 0, 5, 1, 10) with val score 0.5458
# Trained and Tested combination 29 of 15984: (5, 5, 0, 1, 32), taking 46.01 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 1, 10) with val score 0.5458
# Trained and Tested combination 30 of 15984: (5, 5, 5, 0, 36), taking 52.22 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 1, 10) with val score 0.5458
# Trained and Tested combination 31 of 15984: (5, 5, 5, 0, 5), taking 34.57 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 1, 10) with val score 0.5458
# Trained and Tested combination 32 of 15984: (0, 5, 0, 0, 15), taking 41.04 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 1, 10) with val score 0.5458
# Trained and Tested combination 33 of 15984: (5, 5, 0, 1, 20), taking 47.11 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 1, 10) with val score 0.5458
# Trained and Tested combination 34 of 15984: (0, 5, 5, 0, 28), taking 55.32 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 1, 10) with val score 0.5458
# Trained and Tested combination 35 of 15984: (5, 0, 5, 0, 28), taking 63.05 seconds to get val score of 0.7752
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 36 of 15984: (5, 0, 0, 1, 24), taking 51.33 seconds to get val score of 0.5343
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 37 of 15984: (0, 0, 0, 1, 32), taking 47.81 seconds to get val score of -1.4854
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 38 of 15984: (0, 5, 5, 1, 28), taking 56.15 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 39 of 15984: (5, 0, 5, 0, 5), taking 40.67 seconds to get val score of -0.4487
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 40 of 15984: (0, 5, 5, 1, 5), taking 34.41 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 41 of 15984: (0, 5, 5, 1, 20), taking 46.9 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 42 of 15984: (0, 5, 0, 0, 24), taking 50.7 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 43 of 15984: (5, 0, 0, 0, 0), taking 30.04 seconds to get val score of -1.53
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 44 of 15984: (5, 5, 5, 0, 28), taking 55.14 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 45 of 15984: (0, 5, 0, 0, 0), taking 29.55 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 46 of 15984: (5, 5, 5, 1, 5), taking 34.57 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 47 of 15984: (0, 0, 0, 0, 20), taking 47.16 seconds to get val score of -1.4847
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 48 of 15984: (0, 0, 0, 1, 36), taking 51.68 seconds to get val score of -1.4856
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 49 of 15984: (0, 0, 5, 0, 32), taking 53.86 seconds to get val score of -1.186
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 50 of 15984: (0, 5, 5, 0, 10), taking 40.88 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 51 of 15984: (0, 0, 0, 0, 10), taking 41.18 seconds to get val score of -1.4873
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 52 of 15984: (5, 0, 0, 0, 20), taking 47.14 seconds to get val score of 0.553
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 53 of 15984: (0, 0, 0, 0, 15), taking 41.76 seconds to get val score of -1.4851
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 54 of 15984: (5, 5, 0, 0, 32), taking 45.94 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 55 of 15984: (0, 5, 0, 1, 20), taking 46.85 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 56 of 15984: (0, 5, 0, 1, 36), taking 50.92 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 57 of 15984: (0, 5, 5, 1, 15), taking 41.43 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 58 of 15984: (5, 5, 0, 0, 5), taking 33.97 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 59 of 15984: (0, 0, 0, 1, 24), taking 51.23 seconds to get val score of -1.4857
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 60 of 15984: (5, 0, 5, 1, 15), taking 45.62 seconds to get val score of 0.6624
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 61 of 15984: (5, 5, 0, 1, 5), taking 34.97 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 62 of 15984: (0, 5, 0, 0, 20), taking 45.75 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 63 of 15984: (0, 5, 5, 1, 10), taking 41.8 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 64 of 15984: (5, 0, 5, 1, 0), taking 32.58 seconds to get val score of -1.1988
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 65 of 15984: (5, 0, 0, 0, 28), taking 56.26 seconds to get val score of 0.5408
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 66 of 15984: (5, 5, 5, 0, 24), taking 50.73 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 67 of 15984: (5, 0, 0, 0, 10), taking 41.07 seconds to get val score of 0.2183
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 68 of 15984: (0, 0, 5, 1, 20), taking 52.82 seconds to get val score of -1.0609
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 69 of 15984: (0, 0, 5, 0, 15), taking 46.41 seconds to get val score of -1.0743
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 70 of 15984: (0, 0, 0, 1, 0), taking 29.21 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 71 of 15984: (0, 0, 5, 1, 32), taking 53.35 seconds to get val score of -1.1882
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 72 of 15984: (5, 5, 5, 1, 15), taking 40.47 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 73 of 15984: (5, 0, 5, 1, 24), taking 57.56 seconds to get val score of 0.7667
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 74 of 15984: (0, 5, 0, 1, 10), taking 41.51 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 75 of 15984: (5, 5, 0, 1, 0), taking 28.69 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 76 of 15984: (5, 5, 0, 0, 36), taking 51.43 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 28) with val score 0.7752
# Trained and Tested combination 77 of 15984: (5, 0, 5, 0, 36), taking 59.25 seconds to get val score of 0.816
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 78 of 15984: (5, 5, 0, 0, 24), taking 50.64 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 79 of 15984: (5, 0, 5, 0, 24), taking 57.43 seconds to get val score of 0.7693
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 80 of 15984: (5, 0, 5, 1, 28), taking 62.5 seconds to get val score of 0.7897
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 81 of 15984: (5, 0, 0, 1, 10), taking 41.26 seconds to get val score of -0.1837
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 82 of 15984: (5, 0, 5, 0, 20), taking 52.97 seconds to get val score of 0.712
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 83 of 15984: (5, 0, 5, 0, 10), taking 46.71 seconds to get val score of 0.376
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 84 of 15984: (0, 0, 5, 1, 10), taking 46.44 seconds to get val score of -1.0911
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 85 of 15984: (5, 0, 0, 1, 15), taking 40.28 seconds to get val score of 0.5118
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 86 of 15984: (5, 0, 5, 1, 5), taking 40.63 seconds to get val score of -2.2041
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 87 of 15984: (5, 5, 5, 1, 0), taking 29.7 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 88 of 15984: (0, 0, 5, 0, 28), taking 62.86 seconds to get val score of -1.1869
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 89 of 15984: (5, 0, 0, 0, 5), taking 35.1 seconds to get val score of -29.0942
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 90 of 15984: (0, 5, 0, 1, 5), taking 35.01 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 91 of 15984: (5, 0, 0, 0, 32), taking 46.6 seconds to get val score of 0.6157
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 92 of 15984: (5, 0, 0, 0, 36), taking 51.94 seconds to get val score of 0.5039
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 93 of 15984: (0, 5, 0, 0, 5), taking 35.14 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 94 of 15984: (5, 5, 5, 1, 32), taking 45.44 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 95 of 15984: (0, 0, 0, 1, 5), taking 35.23 seconds to get val score of -1.4907
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 96 of 15984: (5, 0, 5, 1, 32), taking 52.38 seconds to get val score of 0.8132
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 97 of 15984: (0, 0, 0, 1, 28), taking 55.84 seconds to get val score of -1.4855
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 98 of 15984: (0, 5, 5, 1, 24), taking 50.41 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 99 of 15984: (0, 5, 5, 0, 20), taking 45.79 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 100 of 15984: (5, 0, 5, 0, 15), taking 44.66 seconds to get val score of 0.5061
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 101 of 15984: (0, 0, 0, 0, 24), taking 50.54 seconds to get val score of -1.4857
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 102 of 15984: (0, 0, 5, 1, 28), taking 62.24 seconds to get val score of -1.1908
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 103 of 15984: (5, 0, 0, 0, 24), taking 50.31 seconds to get val score of 0.4784
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 104 of 15984: (0, 5, 0, 0, 36), taking 51.96 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 105 of 15984: (0, 5, 0, 1, 0), taking 28.83 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 106 of 15984: (0, 0, 0, 1, 15), taking 39.38 seconds to get val score of -1.4852
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 107 of 15984: (0, 5, 0, 1, 15), taking 39.2 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 108 of 15984: (0, 0, 0, 1, 10), taking 41.58 seconds to get val score of -1.4873
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 109 of 15984: (0, 0, 0, 1, 20), taking 46.43 seconds to get val score of -1.4847
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 110 of 15984: (5, 5, 0, 0, 28), taking 54.92 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 111 of 15984: (5, 5, 0, 1, 10), taking 40.33 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 112 of 15984: (0, 0, 5, 1, 0), taking 33.31 seconds to get val score of -1.4759
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 113 of 15984: (0, 0, 5, 0, 5), taking 39.4 seconds to get val score of -1.163
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 114 of 15984: (5, 5, 0, 1, 28), taking 53.97 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 115 of 15984: (0, 5, 0, 0, 32), taking 46.54 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 116 of 15984: (0, 5, 5, 0, 0), taking 28.56 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 117 of 15984: (5, 0, 0, 1, 36), taking 50.8 seconds to get val score of 0.605
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 118 of 15984: (0, 0, 5, 0, 10), taking 46.82 seconds to get val score of -1.0902
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 119 of 15984: (5, 5, 0, 1, 24), taking 49.87 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 120 of 15984: (5, 0, 5, 0, 32), taking 52.03 seconds to get val score of 0.8137
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 121 of 15984: (0, 0, 0, 0, 0), taking 28.69 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 122 of 15984: (5, 5, 0, 0, 15), taking 40.4 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 123 of 15984: (5, 0, 5, 1, 20), taking 51.97 seconds to get val score of 0.7785
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 124 of 15984: (5, 5, 5, 1, 20), taking 45.15 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 125 of 15984: (5, 0, 0, 0, 15), taking 40.25 seconds to get val score of 0.4507
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 126 of 15984: (5, 5, 5, 1, 24), taking 49.95 seconds to get val score of -1.4906
#         Current best combo: (5, 0, 5, 0, 36) with val score 0.816
# Trained and Tested combination 127 of 15984: (3, 3, 3, 1, 18), taking 44.07 seconds to get val score of 0.8363
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 128 of 15984: (5, 0, 5, 1, 36), taking 57.58 seconds to get val score of 0.774
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 129 of 15984: (0, 5, 0, 1, 24), taking 49.92 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 130 of 15984: (5, 5, 5, 1, 36), taking 50.73 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 131 of 15984: (5, 5, 5, 0, 15), taking 40.28 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 132 of 15984: (0, 5, 5, 0, 24), taking 50.2 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 133 of 15984: (0, 5, 5, 0, 5), taking 34.65 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 134 of 15984: (0, 0, 5, 0, 24), taking 56.47 seconds to get val score of -1.2036
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 135 of 15984: (0, 0, 0, 0, 32), taking 46.79 seconds to get val score of -1.4853
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 136 of 15984: (0, 0, 0, 0, 36), taking 51.53 seconds to get val score of -1.4855
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 137 of 15984: (5, 5, 0, 0, 0), taking 29.53 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 138 of 15984: (0, 0, 5, 0, 20), taking 52.07 seconds to get val score of -1.0613
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 139 of 15984: (0, 0, 5, 0, 36), taking 58.19 seconds to get val score of -1.1861
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 140 of 15984: (0, 0, 5, 1, 36), taking 57.9 seconds to get val score of -1.1883
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 141 of 15984: (0, 5, 5, 0, 15), taking 39.27 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 142 of 15984: (0, 5, 5, 0, 36), taking 51.47 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 143 of 15984: (0, 5, 5, 1, 32), taking 46.17 seconds to get val score of -1.4906
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 144 of 15984: (0, 0, 0, 0, 28), taking 54.79 seconds to get val score of -1.4855
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 145 of 15984: (0, 0, 5, 1, 5), taking 40.22 seconds to get val score of -1.164
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
#
#
# STAGE ONE: Begin initial Guidance system
#
#
# Guidance: initial round
#
# 	round 0 iteration:  0
#
# Trained and Tested combination 146 of 15984: (2, 3, 3, 1, 18), taking 46.05 seconds to get val score of 0.4568
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 147 of 15984: (4, 3, 3, 1, 18), taking 46.09 seconds to get val score of 0.7661
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 148 of 15984: (3, 2, 3, 1, 18), taking 46.11 seconds to get val score of 0.8363
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 149 of 15984: (3, 4, 3, 1, 18), taking 44.67 seconds to get val score of -0.454
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 150 of 15984: (3, 3, 2, 1, 18), taking 45.47 seconds to get val score of 0.8142
#         Current best combo: (3, 3, 3, 1, 18) with val score 0.8363
# Trained and Tested combination 151 of 15984: (3, 3, 4, 1, 18), taking 47.56 seconds to get val score of 0.8666
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 152 of 15984: (3, 3, 3, 0, 18), taking 46.04 seconds to get val score of 0.8211
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 153 of 15984: (3, 3, 3, 1, 17), taking 45.06 seconds to get val score of 0.8516
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 154 of 15984: (3, 3, 3, 1, 19), taking 45.39 seconds to get val score of 0.8485
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# 	round 0 iteration:  1
#
# Trained and Tested combination 155 of 15984: (2, 2, 3, 1, 18), taking 46.04 seconds to get val score of 0.4568
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 156 of 15984: (4, 2, 3, 1, 18), taking 46.2 seconds to get val score of 0.7661
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 157 of 15984: (3, 1, 3, 1, 18), taking 46.04 seconds to get val score of 0.8363
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Already Trained and Tested combination (3, 3, 3, 1, 18), which had val score of 0.8363
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666.
#         Has trained 157 of 15984 combinations so far
# Trained and Tested combination 158 of 15984: (3, 2, 2, 1, 18), taking 45.6 seconds to get val score of 0.8142
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 159 of 15984: (3, 2, 4, 1, 18), taking 47.54 seconds to get val score of 0.8666
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 160 of 15984: (3, 2, 3, 0, 18), taking 46.07 seconds to get val score of 0.8211
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 161 of 15984: (3, 2, 3, 1, 17), taking 45.05 seconds to get val score of 0.8516
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 162 of 15984: (3, 2, 3, 1, 19), taking 45.36 seconds to get val score of 0.8485
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 163 of 15984: (2, 3, 4, 1, 18), taking 47.42 seconds to get val score of 0.7736
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Trained and Tested combination 164 of 15984: (4, 3, 4, 1, 18), taking 47.55 seconds to get val score of 0.8175
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Already Trained and Tested combination (3, 2, 4, 1, 18), which had val score of 0.8666
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666.
#         Has trained 164 of 15984 combinations so far
# Trained and Tested combination 165 of 15984: (3, 4, 4, 1, 18), taking 43.91 seconds to get val score of -0.454
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666
# Already Trained and Tested combination (3, 3, 3, 1, 18), which had val score of 0.8363
#         Current best combo: (3, 3, 4, 1, 18) with val score 0.8666.
#         Has trained 165 of 15984 combinations so far
# Trained and Tested combination 166 of 15984: (3, 3, 5, 1, 18), taking 50.35 seconds to get val score of 0.8767
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 167 of 15984: (3, 3, 4, 0, 18), taking 47.61 seconds to get val score of 0.8743
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 168 of 15984: (3, 3, 4, 1, 17), taking 45.51 seconds to get val score of 0.8727
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 169 of 15984: (3, 3, 4, 1, 19), taking 46.91 seconds to get val score of 0.8677
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 170 of 15984: (2, 3, 3, 1, 17), taking 45.35 seconds to get val score of 0.4877
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 171 of 15984: (4, 3, 3, 1, 17), taking 45.43 seconds to get val score of 0.7547
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Already Trained and Tested combination (3, 2, 3, 1, 17), which had val score of 0.8516
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767.
#         Has trained 171 of 15984 combinations so far
# Trained and Tested combination 172 of 15984: (3, 4, 3, 1, 17), taking 43.76 seconds to get val score of -0.8929
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 173 of 15984: (3, 3, 2, 1, 17), taking 43.51 seconds to get val score of 0.7895
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Already Trained and Tested combination (3, 3, 4, 1, 17), which had val score of 0.8727
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767.
#         Has trained 173 of 15984 combinations so far
# Trained and Tested combination 174 of 15984: (3, 3, 3, 0, 17), taking 45.11 seconds to get val score of 0.8495
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 175 of 15984: (3, 3, 3, 1, 16), taking 44.02 seconds to get val score of 0.8229
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Already Trained and Tested combination (3, 3, 3, 1, 18), which had val score of 0.8363
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767.
#         Has trained 175 of 15984 combinations so far
# Trained and Tested combination 176 of 15984: (2, 3, 3, 1, 19), taking 45.34 seconds to get val score of 0.468
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 177 of 15984: (4, 3, 3, 1, 19), taking 45.46 seconds to get val score of 0.7904
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Already Trained and Tested combination (3, 2, 3, 1, 19), which had val score of 0.8485
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767.
#         Has trained 177 of 15984 combinations so far
# Trained and Tested combination 178 of 15984: (3, 4, 3, 1, 19), taking 43.53 seconds to get val score of -0.8165
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 179 of 15984: (3, 3, 2, 1, 19), taking 44.5 seconds to get val score of 0.8289
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Already Trained and Tested combination (3, 3, 4, 1, 19), which had val score of 0.8677
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767.
#         Has trained 179 of 15984 combinations so far
# Trained and Tested combination 180 of 15984: (3, 3, 3, 0, 19), taking 45.43 seconds to get val score of 0.8516
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Already Trained and Tested combination (3, 3, 3, 1, 18), which had val score of 0.8363
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767.
#         Has trained 180 of 15984 combinations so far
# Trained and Tested combination 181 of 15984: (3, 3, 3, 1, 20), taking 48.51 seconds to get val score of 0.8527
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 182 of 15984: (2, 3, 5, 1, 18), taking 49.71 seconds to get val score of 0.8561
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 183 of 15984: (4, 3, 5, 1, 18), taking 50.09 seconds to get val score of 0.8345
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 184 of 15984: (3, 2, 5, 1, 18), taking 49.79 seconds to get val score of 0.8767
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 185 of 15984: (3, 4, 5, 1, 18), taking 44.16 seconds to get val score of -0.454
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Already Trained and Tested combination (3, 3, 4, 1, 18), which had val score of 0.8666
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767.
#         Has trained 185 of 15984 combinations so far
# Trained and Tested combination 186 of 15984: (3, 3, 5, 0, 18), taking 49.6 seconds to get val score of 0.8765
#         Current best combo: (3, 3, 5, 1, 18) with val score 0.8767
# Trained and Tested combination 187 of 15984: (3, 3, 5, 1, 17), taking 48.65 seconds to get val score of 0.8807
#         Current best combo: (3, 3, 5, 1, 17) with val score 0.8807
# Trained and Tested combination 188 of 15984: (3, 3, 5, 1, 19), taking 49.7 seconds to get val score of 0.879
#         Current best combo: (3, 3, 5, 1, 17) with val score 0.8807
# Trained and Tested combination 189 of 15984: (2, 3, 5, 1, 17), taking 48.69 seconds to get val score of 0.8478
#         Current best combo: (3, 3, 5, 1, 17) with val score 0.8807
# Trained and Tested combination 190 of 15984: (4, 3, 5, 1, 17), taking 49.08 seconds to get val score of 0.7806
#         Current best combo: (3, 3, 5, 1, 17) with val score 0.8807
# Trained and Tested combination 191 of 15984: (3, 2, 5, 1, 17), taking 48.86 seconds to get val score of 0.8807
#         Current best combo: (3, 3, 5, 1, 17) with val score 0.8807
# Trained and Tested combination 192 of 15984: (3, 4, 5, 1, 17), taking 42.37 seconds to get val score of -0.8929
#         Current best combo: (3, 3, 5, 1, 17) with val score 0.8807
# Already Trained and Tested combination (3, 3, 4, 1, 17), which had val score of 0.8727
#         Current best combo: (3, 3, 5, 1, 17) with val score 0.8807.
#         Has trained 192 of 15984 combinations so far
# Trained and Tested combination 193 of 15984: (3, 3, 5, 0, 17), taking 48.77 seconds to get val score of 0.8834
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 194 of 15984: (3, 3, 5, 1, 16), taking 47.15 seconds to get val score of 0.8546
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (3, 3, 5, 1, 18), which had val score of 0.8767
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 194 of 15984 combinations so far
# Trained and Tested combination 195 of 15984: (2, 3, 5, 0, 17), taking 48.8 seconds to get val score of 0.8517
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 196 of 15984: (4, 3, 5, 0, 17), taking 49.11 seconds to get val score of 0.8202
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 197 of 15984: (3, 2, 5, 0, 17), taking 48.76 seconds to get val score of 0.8834
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 198 of 15984: (3, 4, 5, 0, 17), taking 43.18 seconds to get val score of -0.8797
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 199 of 15984: (3, 3, 4, 0, 17), taking 45.97 seconds to get val score of 0.875
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (3, 3, 5, 1, 17), which had val score of 0.8807
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 199 of 15984 combinations so far
# Trained and Tested combination 200 of 15984: (3, 3, 5, 0, 16), taking 47.21 seconds to get val score of 0.8804
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (3, 3, 5, 0, 18), which had val score of 0.8765
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 200 of 15984 combinations so far
# % Combos Checked Thus Far: 200 out of 15984 which is 1.251251%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 1 of 144
#
# Cruising Coordrdinate 2 of 144
#
# Cruising Coordrdinate 3 of 144
#
# Cruising Coordrdinate 4 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 1
#
# 	round 1 iteration:  0
#
# Trained and Tested combination 201 of 15984: (4, 0, 0, 1, 36), taking 52.59 seconds to get val score of 0.6037
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 202 of 15984: (5, 1, 0, 1, 36), taking 54.52 seconds to get val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 203 of 15984: (5, 0, 1, 1, 36), taking 53.03 seconds to get val score of 0.6619
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 0, 0, 0, 36), which had val score of 0.5039
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 203 of 15984 combinations so far
# Trained and Tested combination 204 of 15984: (5, 0, 0, 1, 35), taking 48.75 seconds to get val score of 0.6155
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# 	round 1 iteration:  1
#
# Trained and Tested combination 205 of 15984: (3, 0, 0, 1, 36), taking 52.72 seconds to get val score of 0.152
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 0, 0, 1, 36), which had val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 205 of 15984 combinations so far
# Trained and Tested combination 206 of 15984: (4, 1, 0, 1, 36), taking 53.11 seconds to get val score of 0.6037
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 207 of 15984: (4, 0, 1, 1, 36), taking 52.66 seconds to get val score of 0.7606
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 208 of 15984: (4, 0, 0, 0, 36), taking 53.83 seconds to get val score of 0.716
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 209 of 15984: (4, 0, 0, 1, 35), taking 48.34 seconds to get val score of 0.7052
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (4, 1, 0, 1, 36), which had val score of 0.6037
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 209 of 15984 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 36), which had val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 209 of 15984 combinations so far
# Trained and Tested combination 210 of 15984: (5, 2, 0, 1, 36), taking 52.08 seconds to get val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 211 of 15984: (5, 1, 1, 1, 36), taking 52.19 seconds to get val score of 0.6619
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 212 of 15984: (5, 1, 0, 0, 36), taking 53.41 seconds to get val score of 0.5039
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 213 of 15984: (5, 1, 0, 1, 35), taking 47.82 seconds to get val score of 0.6155
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (4, 0, 1, 1, 36), which had val score of 0.7606
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 213 of 15984 combinations so far
# Already Trained and Tested combination (5, 1, 1, 1, 36), which had val score of 0.6619
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 213 of 15984 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 36), which had val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 213 of 15984 combinations so far
# Trained and Tested combination 214 of 15984: (5, 0, 2, 1, 36), taking 52.49 seconds to get val score of 0.6214
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 215 of 15984: (5, 0, 1, 0, 36), taking 52.63 seconds to get val score of 0.6598
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 216 of 15984: (5, 0, 1, 1, 35), taking 48.92 seconds to get val score of 0.5677
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (4, 0, 0, 1, 35), which had val score of 0.7052
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 216 of 15984 combinations so far
# Already Trained and Tested combination (5, 1, 0, 1, 35), which had val score of 0.6155
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 216 of 15984 combinations so far
# Already Trained and Tested combination (5, 0, 1, 1, 35), which had val score of 0.5677
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 216 of 15984 combinations so far
# Trained and Tested combination 217 of 15984: (5, 0, 0, 0, 35), taking 48.95 seconds to get val score of 0.6092
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 218 of 15984: (5, 0, 0, 1, 34), taking 50.09 seconds to get val score of 0.6378
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 0, 0, 1, 36), which had val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 218 of 15984 combinations so far
# % Combos Checked Thus Far: 218 out of 15984 which is 1.363864%
# Cruising Coordrdinate 5 of 144
#
# Cruising Coordrdinate 6 of 144
#
# Cruise suspended due to suspicious case
# Guidance: round 2
#
# 	round 2 iteration:  0
#
# Already Trained and Tested combination (4, 0, 0, 0, 36), which had val score of 0.716
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 218 of 15984 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0, 36), which had val score of 0.5039
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 218 of 15984 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 36), which had val score of 0.6598
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 218 of 15984 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 36), which had val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 218 of 15984 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 35), which had val score of 0.6092
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 218 of 15984 combinations so far
# 	round 2 iteration:  1
#
# Trained and Tested combination 219 of 15984: (4, 1, 0, 0, 36), taking 53.21 seconds to get val score of 0.716
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 0, 0, 0, 36), which had val score of 0.5039
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 219 of 15984 combinations so far
# Trained and Tested combination 220 of 15984: (5, 2, 0, 0, 36), taking 52.74 seconds to get val score of 0.5039
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 221 of 15984: (5, 1, 1, 0, 36), taking 54.12 seconds to get val score of 0.6598
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 1, 0, 1, 36), which had val score of 0.605
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 221 of 15984 combinations so far
# Trained and Tested combination 222 of 15984: (5, 1, 0, 0, 35), taking 48.96 seconds to get val score of 0.6092
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Trained and Tested combination 223 of 15984: (4, 0, 0, 0, 35), taking 49.18 seconds to get val score of 0.6917
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 1, 0, 0, 35), which had val score of 0.6092
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 223 of 15984 combinations so far
# Trained and Tested combination 224 of 15984: (5, 0, 1, 0, 35), taking 49.34 seconds to get val score of 0.5839
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 0, 0, 1, 35), which had val score of 0.6155
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 224 of 15984 combinations so far
# Trained and Tested combination 225 of 15984: (5, 0, 0, 0, 34), taking 50.07 seconds to get val score of 0.5452
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834
# Already Trained and Tested combination (5, 0, 0, 0, 36), which had val score of 0.5039
#         Current best combo: (3, 3, 5, 0, 17) with val score 0.8834.
#         Has trained 225 of 15984 combinations so far
# ...
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 272 of 15984: (4, 0, 5, 0, 32), taking 54.7 seconds to get val score of 0.8554
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 273 of 15984: (4, 0, 5, 1, 31), taking 49.97 seconds to get val score of 0.8306
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 274 of 15984: (4, 0, 5, 1, 33), taking 54.3 seconds to get val score of 0.8535
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Already Trained and Tested combination (4, 1, 5, 1, 32), which had val score of 0.8278
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851.
#         Has trained 274 of 15984 combinations so far
# Already Trained and Tested combination (5, 0, 5, 1, 32), which had val score of 0.8132
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851.
#         Has trained 274 of 15984 combinations so far
# Trained and Tested combination 275 of 15984: (5, 2, 5, 1, 32), taking 53.06 seconds to get val score of 0.8132
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 276 of 15984: (5, 1, 4, 1, 32), taking 49.9 seconds to get val score of 0.7991
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 277 of 15984: (5, 1, 5, 0, 32), taking 53.87 seconds to get val score of 0.8137
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 278 of 15984: (5, 1, 5, 1, 31), taking 49.56 seconds to get val score of 0.804
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 279 of 15984: (5, 1, 5, 1, 33), taking 53.49 seconds to get val score of 0.7753
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Already Trained and Tested combination (4, 0, 5, 0, 32), which had val score of 0.8554
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851.
#         Has trained 279 of 15984 combinations so far
# Already Trained and Tested combination (5, 1, 5, 0, 32), which had val score of 0.8137
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851.
#         Has trained 279 of 15984 combinations so far
# Trained and Tested combination 280 of 15984: (5, 0, 4, 0, 32), taking 50.22 seconds to get val score of 0.7312
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Already Trained and Tested combination (5, 0, 5, 1, 32), which had val score of 0.8132
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851.
#         Has trained 280 of 15984 combinations so far
# Trained and Tested combination 281 of 15984: (5, 0, 5, 0, 31), taking 50.45 seconds to get val score of 0.806
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 282 of 15984: (5, 0, 5, 0, 33), taking 54.46 seconds to get val score of 0.8032
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 283 of 15984: (2, 0, 5, 1, 32), taking 52.88 seconds to get val score of 0.826
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Already Trained and Tested combination (4, 0, 5, 1, 32), which had val score of 0.8278
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851.
#         Has trained 283 of 15984 combinations so far
# Trained and Tested combination 284 of 15984: (3, 1, 5, 1, 32), taking 51.89 seconds to get val score of 0.8851
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 285 of 15984: (3, 0, 4, 1, 32), taking 48.81 seconds to get val score of 0.8741
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 286 of 15984: (3, 0, 5, 0, 32), taking 53.65 seconds to get val score of 0.8712
#         Current best combo: (3, 0, 5, 1, 32) with val score 0.8851
# Trained and Tested combination 287 of 15984: (3, 0, 5, 1, 31), taking 49.57 seconds to get val score of 0.8854
#         Current best combo: (3, 0, 5, 1, 31) with val score 0.8854
# Trained and Tested combination 288 of 15984: (3, 0, 5, 1, 33), taking 52.6 seconds to get val score of 0.8849
#         Current best combo: (3, 0, 5, 1, 31) with val score 0.8854
# Trained and Tested combination 289 of 15984: (2, 0, 5, 1, 31), taking 49.9 seconds to get val score of 0.8238
#         Current best combo: (3, 0, 5, 1, 31) with val score 0.8854
# Already Trained and Tested combination (4, 0, 5, 1, 31), which had val score of 0.8306
#         Current best combo: (3, 0, 5, 1, 31) with val score 0.8854.
#         Has trained 289 of 15984 combinations so far
# Trained and Tested combination 290 of 15984: (3, 1, 5, 1, 31), taking 50.04 seconds to get val score of 0.8854
#         Current best combo: (3, 0, 5, 1, 31) with val score 0.8854
# Trained and Tested combination 291 of 15984: (3, 0, 4, 1, 31), taking 46.81 seconds to get val score of 0.866
#         Current best combo: (3, 0, 5, 1, 31) with val score 0.8854
# Trained and Tested combination 292 of 15984: (3, 0, 5, 0, 31), taking 50.05 seconds to get val score of 0.8863
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Trained and Tested combination 293 of 15984: (3, 0, 5, 1, 30), taking 65.05 seconds to get val score of 0.878
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Already Trained and Tested combination (3, 0, 5, 1, 32), which had val score of 0.8851
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 293 of 15984 combinations so far
# Trained and Tested combination 294 of 15984: (2, 0, 5, 0, 31), taking 50.45 seconds to get val score of 0.8323
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Trained and Tested combination 295 of 15984: (4, 0, 5, 0, 31), taking 50.52 seconds to get val score of 0.8453
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Trained and Tested combination 296 of 15984: (3, 1, 5, 0, 31), taking 50.54 seconds to get val score of 0.8863
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Trained and Tested combination 297 of 15984: (3, 0, 4, 0, 31), taking 47.54 seconds to get val score of 0.8734
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Already Trained and Tested combination (3, 0, 5, 1, 31), which had val score of 0.8854
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 297 of 15984 combinations so far
# Trained and Tested combination 298 of 15984: (3, 0, 5, 0, 30), taking 66.18 seconds to get val score of 0.8802
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Already Trained and Tested combination (3, 0, 5, 0, 32), which had val score of 0.8712
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# % Combos Checked Thus Far: 298 out of 15984 which is 1.864364%
# Cruising Coordrdinate 45 of 144
#
# Cruising Coordrdinate 46 of 144
#
# Cruising Coordrdinate 47 of 144
#
# Cruising Coordrdinate 48 of 144
#
# Cruising Coordrdinate 49 of 144
#
# Cruising Coordrdinate 50 of 144
#
# Cruising Coordrdinate 51 of 144
#
# Cruising Coordrdinate 52 of 144
#
# Cruising Coordrdinate 53 of 144
#
# Cruising Coordrdinate 54 of 144
#
# Cruising Coordrdinate 55 of 144
#
# Cruising Coordrdinate 56 of 144
#
# Cruising Coordrdinate 57 of 144
#
# Cruising Coordrdinate 58 of 144
#
# Cruising Coordrdinate 59 of 144
#
# Cruising Coordrdinate 60 of 144
#
# Cruising Coordrdinate 61 of 144
#
# Cruising Coordrdinate 62 of 144
#
# Cruising Coordrdinate 63 of 144
#
# Cruising Coordrdinate 64 of 144
#
# Cruising Coordrdinate 65 of 144
#
# Cruising Coordrdinate 66 of 144
#
# Cruising Coordrdinate 67 of 144
#
# Cruising Coordrdinate 68 of 144
#
# Cruising Coordrdinate 69 of 144
#
# Cruising Coordrdinate 70 of 144
#
# Cruising Coordrdinate 71 of 144
#
# Cruising Coordrdinate 72 of 144
#
# Cruising Coordrdinate 73 of 144
#
# Cruising Coordrdinate 74 of 144
#
# Cruising Coordrdinate 75 of 144
#
# Cruising Coordrdinate 76 of 144
#
# Cruising Coordrdinate 77 of 144
#
# Cruising Coordrdinate 78 of 144
#
# Cruising Coordrdinate 79 of 144
#
# Cruising Coordrdinate 80 of 144
#
# Cruising Coordrdinate 81 of 144
#
# Cruising Coordrdinate 82 of 144
#
# Cruising Coordrdinate 83 of 144
#
# Cruising Coordrdinate 84 of 144
#
# Cruising Coordrdinate 85 of 144
#
# Cruising Coordrdinate 86 of 144
#
# Cruising Coordrdinate 87 of 144
#
# Cruising Coordrdinate 88 of 144
#
# Cruising Coordrdinate 89 of 144
#
# Cruising Coordrdinate 90 of 144
#
# Cruising Coordrdinate 91 of 144
#
# Cruising Coordrdinate 92 of 144
#
# Cruising Coordrdinate 93 of 144
#
# Cruising Coordrdinate 94 of 144
#
# Cruising Coordrdinate 95 of 144
#
# Cruising Coordrdinate 96 of 144
#
# Cruising Coordrdinate 97 of 144
#
# Cruising Coordrdinate 98 of 144
#
# Cruising Coordrdinate 99 of 144
#
# Cruising Coordrdinate 100 of 144
#
# Cruising Coordrdinate 101 of 144
#
# Cruising Coordrdinate 102 of 144
#
# Cruising Coordrdinate 103 of 144
#
# Cruising Coordrdinate 104 of 144
#
# Cruising Coordrdinate 105 of 144
#
# Cruising Coordrdinate 106 of 144
#
# Cruising Coordrdinate 107 of 144
#
# Cruising Coordrdinate 108 of 144
#
# Cruising Coordrdinate 109 of 144
#
# Cruising Coordrdinate 110 of 144
#
# Cruising Coordrdinate 111 of 144
#
# Cruising Coordrdinate 112 of 144
#
# Cruising Coordrdinate 113 of 144
#
# Cruising Coordrdinate 114 of 144
#
# Cruising Coordrdinate 115 of 144
#
# Cruising Coordrdinate 116 of 144
#
# Cruising Coordrdinate 117 of 144
#
# Cruising Coordrdinate 118 of 144
#
# Cruising Coordrdinate 119 of 144
#
# Cruising Coordrdinate 120 of 144
#
# Cruising Coordrdinate 121 of 144
#
# Cruising Coordrdinate 122 of 144
#
# Cruising Coordrdinate 123 of 144
#
# Cruising Coordrdinate 124 of 144
#
# Cruising Coordrdinate 125 of 144
#
# Cruising Coordrdinate 126 of 144
#
# Cruising Coordrdinate 127 of 144
#
# Cruising Coordrdinate 128 of 144
#
# Cruising Coordrdinate 129 of 144
#
# Cruising Coordrdinate 130 of 144
#
# Cruising Coordrdinate 131 of 144
#
# Cruising Coordrdinate 132 of 144
#
# Cruising Coordrdinate 133 of 144
#
# Cruising Coordrdinate 134 of 144
#
# Cruising Coordrdinate 135 of 144
#
# Cruising Coordrdinate 136 of 144
#
# Cruising Coordrdinate 137 of 144
#
# Cruising Coordrdinate 138 of 144
#
# Cruising Coordrdinate 139 of 144
#
# Cruising Coordrdinate 140 of 144
#
# Cruising Coordrdinate 141 of 144
#
# Cruising Coordrdinate 142 of 144
#
# Cruising Coordrdinate 143 of 144
#
# Cruising Coordrdinate 144 of 144
#
# FINAL STAGE: Begin final Guidance system
#
#
# Guidance: round FINAL
#
# 	round FINAL iteration:  0
#
# Already Trained and Tested combination (2, 0, 5, 0, 31), which had val score of 0.8323
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# Already Trained and Tested combination (4, 0, 5, 0, 31), which had val score of 0.8453
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# Already Trained and Tested combination (3, 1, 5, 0, 31), which had val score of 0.8863
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 4, 0, 31), which had val score of 0.8734
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 5, 1, 31), which had val score of 0.8854
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 5, 0, 30), which had val score of 0.8802
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 5, 0, 32), which had val score of 0.8712
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 298 of 15984 combinations so far
# 	round FINAL iteration:  1
#
# Trained and Tested combination 299 of 15984: (2, 1, 5, 0, 31), taking 50.93 seconds to get val score of 0.8323
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Trained and Tested combination 300 of 15984: (4, 1, 5, 0, 31), taking 50.38 seconds to get val score of 0.8453
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Already Trained and Tested combination (3, 0, 5, 0, 31), which had val score of 0.8863
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 300 of 15984 combinations so far
# Trained and Tested combination 301 of 15984: (3, 2, 5, 0, 31), taking 50.48 seconds to get val score of 0.8863
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Trained and Tested combination 302 of 15984: (3, 1, 4, 0, 31), taking 47.27 seconds to get val score of 0.8734
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Already Trained and Tested combination (3, 1, 5, 1, 31), which had val score of 0.8854
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 302 of 15984 combinations so far
# Trained and Tested combination 303 of 15984: (3, 1, 5, 0, 30), taking 67.17 seconds to get val score of 0.8802
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Trained and Tested combination 304 of 15984: (3, 1, 5, 0, 32), taking 54.81 seconds to get val score of 0.8712
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863
# Already Trained and Tested combination (2, 0, 5, 1, 31), which had val score of 0.8238
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 304 of 15984 combinations so far
# Already Trained and Tested combination (4, 0, 5, 1, 31), which had val score of 0.8306
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 304 of 15984 combinations so far
# Already Trained and Tested combination (3, 1, 5, 1, 31), which had val score of 0.8854
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 304 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 4, 1, 31), which had val score of 0.866
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 304 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 5, 0, 31), which had val score of 0.8863
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 304 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 5, 1, 30), which had val score of 0.878
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 304 of 15984 combinations so far
# Already Trained and Tested combination (3, 0, 5, 1, 32), which had val score of 0.8851
#         Current best combo: (3, 0, 5, 0, 31) with val score 0.8863.
#         Has trained 304 of 15984 combinations so far
# % Combos Checked Thus Far: 304 out of 15984 which is 1.9019020000000002%
# Max Val Score:
#  0.8863193167440262
# Best Combo Test Score:
#  0.88655
# Best Combo Train Score:
#  0.891789
# Max Combo Index:
#  (3, 0, 5, 0, 31) out of [6, 6, 6, 2, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 0.1, 'tol': 0.0001, 'max_iter': 1600, 'gamma': 'auto', 'features': 31}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Rebound 50s', 'Disposal Efficiency %', 'Uncontested Marks', 'Frees For', 'Clearances', 'Inside 50s', 'Turnovers', 'Bounces', 'Uncontested Possessions')
# % Combos Checked: 304 out of 15984 which is 1.9019020000000002%
