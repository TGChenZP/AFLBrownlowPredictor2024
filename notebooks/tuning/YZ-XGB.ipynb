# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'xgb'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.2.6-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.6-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.6

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from xgboost import XGBRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'gamma': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'eta': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 19260817,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Error message: 800.0
# Error Importing this Row: (7, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      1.0
# colsample_bytree                                                               0.4
# gamma                                                                          0.0
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.99546
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         51.71
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     33.0
# n_features                                                                    32.0
# Precedence                                                                     7.0
# Name: 7, dtype: object)
# Error message: 800.0
# Error Importing this Row: (11, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                                  1.0
# Train r2                                                                  0.126813
# Val r2                                                                    0.119079
# Test r2                                                                   0.119519
# Train rmse                                                                0.275882
# Val rmse                                                                  0.277106
# Test rmse                                                                 0.277051
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                       1193.01
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     37.0
# n_features                                                                    36.0
# Precedence                                                                    11.0
# Name: 11, dtype: object)
# Error message: 800.0
# Error Importing this Row: (12, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.833449
# Train r2                                                                  0.092799
# Val r2                                                                     0.09264
# Test r2                                                                   0.093135
# Train rmse                                                                0.281204
# Val rmse                                                                  0.281233
# Test rmse                                                                 0.281172
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          2.23
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                      6.0
# n_features                                                                     5.0
# Precedence                                                                    12.0
# Name: 12, dtype: object)
# Error message: 800.0
# Error Importing this Row: (17, n_estimators                                       800.0
# max_depth                                            3.0
# subsample                                            1.0
# colsample_bytree                                     1.0
# gamma                                                0.0
# eta                                               0.0001
# features                         ['Effective Disposals']
# feature combo ningxiang score                    0.44653
# Train r2                                        0.085017
# Val r2                                          0.084382
# Test r2                                         0.085081
# Train rmse                                      0.282407
# Val rmse                                         0.28251
# Test rmse                                       0.282418
# Train mape                                           NaN
# Val mape                                             NaN
# Test mape                                            NaN
# Time                                                1.45
# random_state                                  19260817.0
# n_jobs                                              -1.0
# n_columns                                            1.0
# n_features                                           0.0
# Precedence                                          17.0
# Name: 17, dtype: object)
# Error message: 800.0
# Error Importing this Row: (22, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.929612
# Train r2                                                                  0.127178
# Val r2                                                                    0.120507
# Test r2                                                                   0.121021
# Train rmse                                                                0.275824
# Val rmse                                                                  0.276881
# Test rmse                                                                 0.276815
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                        356.67
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     11.0
# n_features                                                                    10.0
# Precedence                                                                    22.0
# Name: 22, dtype: object)
# Error message: 800.0
# Error Importing this Row: (25, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      1.0
# colsample_bytree                                                               0.4
# gamma                                                                          0.1
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.989568
# Train r2                                                                    0.0843
# Val r2                                                                    0.083801
# Test r2                                                                   0.084355
# Train rmse                                                                0.282518
# Val rmse                                                                    0.2826
# Test rmse                                                                  0.28253
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          7.74
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     29.0
# n_features                                                                    28.0
# Precedence                                                                    25.0
# Name: 25, dtype: object)
# Error message: 800.0
# Error Importing this Row: (27, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      1.0
# colsample_bytree                                                               0.4
# gamma                                                                          0.0
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.983012
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         40.91
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     25.0
# n_features                                                                    24.0
# Precedence                                                                    27.0
# Name: 27, dtype: object)
# Error message: 800.0
# Error Importing this Row: (29, n_estimators                                       800.0
# max_depth                                            3.0
# subsample                                            1.0
# colsample_bytree                                     0.4
# gamma                                                0.0
# eta                                               0.0001
# features                         ['Effective Disposals']
# feature combo ningxiang score                    0.44653
# Train r2                                        0.085017
# Val r2                                          0.084382
# Test r2                                         0.085081
# Train rmse                                      0.282407
# Val rmse                                         0.28251
# Test rmse                                       0.282418
# Train mape                                           NaN
# Val mape                                             NaN
# Test mape                                            NaN
# Time                                                 1.4
# random_state                                  19260817.0
# n_jobs                                              -1.0
# n_columns                                            1.0
# n_features                                           0.0
# Precedence                                          29.0
# Name: 29, dtype: object)
# Error message: 800.0
# Error Importing this Row: (30, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.1
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.833449
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          4.79
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                      6.0
# n_features                                                                     5.0
# Precedence                                                                    30.0
# Name: 30, dtype: object)
# Error message: 800.0
# Error Importing this Row: (34, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.929612
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         28.99
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     11.0
# n_features                                                                    10.0
# Precedence                                                                    34.0
# Name: 34, dtype: object)
# Error message: 800.0
# Error Importing this Row: (35, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.833449
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         12.91
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                      6.0
# n_features                                                                     5.0
# Precedence                                                                    35.0
# Name: 35, dtype: object)
# Error message: 800.0
# Error Importing this Row: (38, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      1.0
# colsample_bytree                                                               0.4
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.983012
# Train r2                                                                  0.085445
# Val r2                                                                     0.08493
# Test r2                                                                   0.085427
# Train rmse                                                                0.282341
# Val rmse                                                                  0.282426
# Test rmse                                                                 0.282364
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          7.19
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     25.0
# n_features                                                                    24.0
# Precedence                                                                    38.0
# Name: 38, dtype: object)
# Error message: 800.0
# Error Importing this Row: (39, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      1.0
# colsample_bytree                                                               0.4
# gamma                                                                          0.1
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.929612
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         10.63
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     11.0
# n_features                                                                    10.0
# Precedence                                                                    39.0
# Name: 39, dtype: object)
# Error message: 800.0
# Error Importing this Row: (40, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      0.4
# colsample_bytree                                                               0.4
# gamma                                                                          0.1
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.989568
# Train r2                                                                  0.113496
# Val r2                                                                    0.106996
# Test r2                                                                   0.107138
# Train rmse                                                                0.277978
# Val rmse                                                                     0.279
# Test rmse                                                                 0.278992
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                        166.52
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     29.0
# n_features                                                                    28.0
# Precedence                                                                    40.0
# Name: 40, dtype: object)
# Error message: 800.0
# Error Importing this Row: (42, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      1.0
# colsample_bytree                                                               0.4
# gamma                                                                          0.1
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.975217
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         24.63
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     21.0
# n_features                                                                    20.0
# Precedence                                                                    42.0
# Name: 42, dtype: object)
# Error message: 800.0
# Error Importing this Row: (44, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.989568
# Train r2                                                                  0.137974
# Val r2                                                                    0.121106
# Test r2                                                                   0.121548
# Train rmse                                                                0.274113
# Val rmse                                                                  0.276787
# Test rmse                                                                 0.276732
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                       2220.87
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     29.0
# n_features                                                                    28.0
# Precedence                                                                    44.0
# Name: 44, dtype: object)
# Error message: 800.0
# Error Importing this Row: (47, n_estimators                                       800.0
# max_depth                                           24.0
# subsample                                            0.4
# colsample_bytree                                     0.4
# gamma                                                0.1
# eta                                               0.0001
# features                         ['Effective Disposals']
# feature combo ningxiang score                    0.44653
# Train r2                                        0.086588
# Val r2                                          0.086104
# Test r2                                          0.08673
# Train rmse                                      0.282165
# Val rmse                                        0.282245
# Test rmse                                       0.282163
# Train mape                                           NaN
# Val mape                                             NaN
# Test mape                                            NaN
# Time                                                3.51
# random_state                                  19260817.0
# n_jobs                                              -1.0
# n_columns                                            1.0
# n_features                                           0.0
# Precedence                                          47.0
# Name: 47, dtype: object)
# Error message: 800.0
# Error Importing this Row: (50, n_estimators                                       800.0
# max_depth                                            3.0
# subsample                                            0.4
# colsample_bytree                                     0.4
# gamma                                                0.1
# eta                                                 10.0
# features                         ['Effective Disposals']
# feature combo ningxiang score                    0.44653
# Train r2                                             0.0
# Val r2                                               0.0
# Test r2                                              0.0
# Train rmse                                           0.0
# Val rmse                                             0.0
# Test rmse                                            0.0
# Train mape                                           NaN
# Val mape                                             NaN
# Test mape                                            NaN
# Time                                                2.78
# random_state                                  19260817.0
# n_jobs                                              -1.0
# n_columns                                            1.0
# n_features                                           0.0
# Precedence                                          50.0
# Name: 50, dtype: object)
# Error message: 800.0
# Error Importing this Row: (52, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      0.4
# colsample_bytree                                                               0.4
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.99546
# Train r2                                                                   0.08513
# Val r2                                                                    0.084781
# Test r2                                                                   0.085174
# Train rmse                                                                 0.28239
# Val rmse                                                                  0.282449
# Test rmse                                                                 0.282403
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          5.31
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     33.0
# n_features                                                                    32.0
# Precedence                                                                    52.0
# Name: 52, dtype: object)
# Error message: 800.0
# Error Importing this Row: (53, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.1
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.989568
# Train r2                                                                  0.131623
# Val r2                                                                    0.123255
# Test r2                                                                    0.12357
# Train rmse                                                                0.275121
# Val rmse                                                                  0.276448
# Test rmse                                                                 0.276413
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                        542.87
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     29.0
# n_features                                                                    28.0
# Precedence                                                                    53.0
# Name: 53, dtype: object)
# Error message: 800.0
# Error Importing this Row: (54, n_estimators                                       800.0
# max_depth                                            3.0
# subsample                                            0.4
# colsample_bytree                                     1.0
# gamma                                                0.1
# eta                                                 10.0
# features                         ['Effective Disposals']
# feature combo ningxiang score                    0.44653
# Train r2                                             0.0
# Val r2                                               0.0
# Test r2                                              0.0
# Train rmse                                           0.0
# Val rmse                                             0.0
# Test rmse                                            0.0
# Train mape                                           NaN
# Val mape                                             NaN
# Test mape                                            NaN
# Time                                                0.76
# random_state                                  19260817.0
# n_jobs                                              -1.0
# n_columns                                            1.0
# n_features                                           0.0
# Precedence                                          54.0
# Name: 54, dtype: object)
# Error message: 800.0
# Error Importing this Row: (57, n_estimators                                       800.0
# max_depth                                            3.0
# subsample                                            1.0
# colsample_bytree                                     1.0
# gamma                                                0.1
# eta                                               0.0001
# features                         ['Effective Disposals']
# feature combo ningxiang score                    0.44653
# Train r2                                        0.085017
# Val r2                                          0.084382
# Test r2                                         0.085081
# Train rmse                                      0.282407
# Val rmse                                         0.28251
# Test rmse                                       0.282418
# Train mape                                           NaN
# Val mape                                             NaN
# Test mape                                            NaN
# Time                                                1.43
# random_state                                  19260817.0
# n_jobs                                              -1.0
# n_columns                                            1.0
# n_features                                           0.0
# Precedence                                          57.0
# Name: 57, dtype: object)
# Error message: 800.0
# Error Importing this Row: (61, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      0.4
# colsample_bytree                                                               0.4
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                                  1.0
# Train r2                                                                  0.117152
# Val r2                                                                    0.105684
# Test r2                                                                   0.105791
# Train rmse                                                                0.277404
# Val rmse                                                                  0.279205
# Test rmse                                                                 0.279203
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                        675.93
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     37.0
# n_features                                                                    36.0
# Precedence                                                                    61.0
# Name: 61, dtype: object)
# Error message: 800.0
# Error Importing this Row: (64, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.99546
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         37.45
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     33.0
# n_features                                                                    32.0
# Precedence                                                                    64.0
# Name: 64, dtype: object)
# Error message: 800.0
# Error Importing this Row: (65, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.1
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.929612
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          6.08
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     11.0
# n_features                                                                    10.0
# Precedence                                                                    65.0
# Name: 65, dtype: object)
# Error message: 800.0
# Error Importing this Row: (66, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.1
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.96115
# Train r2                                                                  0.125297
# Val r2                                                                    0.121635
# Test r2                                                                   0.122163
# Train rmse                                                                0.276121
# Val rmse                                                                  0.276704
# Test rmse                                                                 0.276635
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# ...
# Time                                                                         25.58
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     25.0
# n_features                                                                    24.0
# Precedence                                                                    75.0
# Name: 75, dtype: object)
# Error message: 800.0
# Error Importing this Row: (78, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.975217
# Train r2                                                                  0.092799
# Val r2                                                                     0.09264
# Test r2                                                                   0.093135
# Train rmse                                                                0.281204
# Val rmse                                                                  0.281233
# Test rmse                                                                 0.281172
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          4.09
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     21.0
# n_features                                                                    20.0
# Precedence                                                                    78.0
# Name: 78, dtype: object)
# Error message: 800.0
# Error Importing this Row: (79, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.975217
# Train r2                                                                  0.092908
# Val r2                                                                    0.092695
# Test r2                                                                   0.093257
# Train rmse                                                                0.281187
# Val rmse                                                                  0.281225
# Test rmse                                                                 0.281153
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          4.43
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     21.0
# n_features                                                                    20.0
# Precedence                                                                    79.0
# Name: 79, dtype: object)
# Error message: 800.0
# Error Importing this Row: (80, n_estimators                                                                 800.0
# max_depth                                                                     24.0
# subsample                                                                      0.4
# colsample_bytree                                                               0.4
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.99546
# Train r2                                                                  0.117055
# Val r2                                                                    0.105613
# Test r2                                                                   0.105656
# Train rmse                                                                0.277419
# Val rmse                                                                  0.279216
# Test rmse                                                                 0.279224
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                        634.27
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     33.0
# n_features                                                                    32.0
# Precedence                                                                    80.0
# Name: 80, dtype: object)
# Error message: 800.0
# Error Importing this Row: (83, n_estimators                                       800.0
# max_depth                                            3.0
# subsample                                            0.4
# colsample_bytree                                     1.0
# gamma                                                0.0
# eta                                                 10.0
# features                         ['Effective Disposals']
# feature combo ningxiang score                    0.44653
# Train r2                                             0.0
# Val r2                                               0.0
# Test r2                                              0.0
# Train rmse                                           0.0
# Val rmse                                             0.0
# Test rmse                                            0.0
# Train mape                                           NaN
# Val mape                                             NaN
# Test mape                                            NaN
# Time                                                0.72
# random_state                                  19260817.0
# n_jobs                                              -1.0
# n_columns                                            1.0
# n_features                                           0.0
# Precedence                                          83.0
# Name: 83, dtype: object)
# Error message: 800.0
# Error Importing this Row: (84, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                           10.0
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.929612
# Train r2                                                                       0.0
# Val r2                                                                         0.0
# Test r2                                                                        0.0
# Train rmse                                                                     0.0
# Val rmse                                                                       0.0
# Test rmse                                                                      0.0
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         12.41
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     11.0
# n_features                                                                    10.0
# Precedence                                                                    84.0
# Name: 84, dtype: object)
# Error message: 800.0
# Error Importing this Row: (89, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      0.4
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.929612
# Train r2                                                                  0.092908
# Val r2                                                                    0.092695
# Test r2                                                                   0.093257
# Train rmse                                                                0.281187
# Val rmse                                                                  0.281225
# Test rmse                                                                 0.281153
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          4.82
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     11.0
# n_features                                                                    10.0
# Precedence                                                                    89.0
# Name: 89, dtype: object)
# Error message: 800.0
# Error Importing this Row: (90, n_estimators                                                                 800.0
# max_depth                                                                    192.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.0
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.833449
# Train r2                                                                  0.132193
# Val r2                                                                    0.113138
# Test r2                                                                   0.113731
# Train rmse                                                                0.275031
# Val rmse                                                                  0.278039
# Test rmse                                                                  0.27796
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                        425.12
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                      6.0
# n_features                                                                     5.0
# Precedence                                                                    90.0
# Name: 90, dtype: object)
# Error message: 800.0
# Error Importing this Row: (91, n_estimators                                                                 800.0
# max_depth                                                                      3.0
# subsample                                                                      1.0
# colsample_bytree                                                               1.0
# gamma                                                                          0.1
# eta                                                                         0.0001
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                                  1.0
# Train r2                                                                  0.092799
# Val r2                                                                     0.09264
# Test r2                                                                   0.093135
# Train rmse                                                                0.281204
# Val rmse                                                                  0.281233
# Test rmse                                                                 0.281172
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          9.72
# random_state                                                            19260817.0
# n_jobs                                                                        -1.0
# n_columns                                                                     37.0
# n_features                                                                    36.0
# Precedence                                                                    91.0
# Name: 91, dtype: object)
# Successfully read in tuning result of 831 rows, for 792.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 0, 20), which had val score of 0.0531
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 24), which had val score of 0.0035
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 0, 15), which had val score of 0.0042
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 4, 5, 10), which had val score of 0.0
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 4, 5, 24), which had val score of 0.0
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 4, 5, 36), which had val score of 0.0
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 0, 5, 15), which had val score of 0.0
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 4, 5, 32), which had val score of -5.40292374526571e+43
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 0, 0, 20), which had val score of 0.0631
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 28), which had val score of 0.004
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 0, 24), which had val score of 0.054
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 0, 5), which had val score of 0.0597
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 0, 10), which had val score of 0.004
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 5, 20), which had val score of -1.8520703449996794e+44
#         Current best combo: (4, 6, 4, 4, 4, 0, 20) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# As new Best Combo (4, 3, 4, 4, 4, 0, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (4, 3, 4, 4, 4, 0, 10), which had val score of 0.0642
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 0, 28), which had val score of 0.004
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 5, 15), which had val score of -6.345032708158559e+39
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 0, 32), which had val score of 0.0036
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 5, 5), which had val score of -8.036085871544012e+41
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 5), which had val score of -5.762097346764102e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 5, 36), which had val score of -7.321698659053496e+42
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 5), which had val score of 0.0025
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 5, 5), which had val score of -7.231425821228401e+44
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 0, 36), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 36), which had val score of -5.307928409361388e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 0, 0, 0), which had val score of 0.0448
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 0, 5, 28), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 4, 0, 32), which had val score of 0.0641
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5, 36), which had val score of -1.0179931899233256e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 4, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5, 32), which had val score of -3.256838112401503e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 24), which had val score of 0.0028
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 32), which had val score of 0.0037
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 0, 32), which had val score of 0.0439
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 0, 0, 10), which had val score of 0.0637
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 0, 0, 28), which had val score of 0.0482
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 0, 10), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 5, 28), which had val score of -2.972834424490514e+42
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 0, 32), which had val score of 0.0618
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 0, 0), which had val score of 0.0029
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 15), which had val score of 0.0032
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 4, 0, 28), which had val score of 0.0431
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 4, 5, 10), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 0, 32), which had val score of 0.0618
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 20), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 4, 0, 5), which had val score of 0.0481
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 5, 15), which had val score of -9.350595832378722e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 0, 5, 10), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 5, 10), which had val score of -2.928545112879978e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 5, 28), which had val score of -6.429052134078658e+41
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 0, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 32), which had val score of 0.0037
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 5, 5), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 4, 5, 10), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 10), which had val score of -8.084189375321062e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 5, 20), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 4, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 0, 15), which had val score of 0.0429
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 4, 5, 32), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 0, 5), which had val score of 0.0039
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 0, 36), which had val score of 0.0547
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 4, 5, 0), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 0, 24), which had val score of 0.063
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 0, 36), which had val score of 0.0618
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 0, 32), which had val score of 0.0036
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 0, 28), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 4, 0, 0), which had val score of 0.044
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 0, 0), which had val score of 0.0448
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 4, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 0, 0, 0), which had val score of 0.044
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5, 15), which had val score of -1.5665198915996278e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 5, 20), which had val score of -7.479039625291135e+42
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 5, 28), which had val score of -6.849017011355133e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 4, 5, 0), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 5, 28), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 5, 10), which had val score of -1.6780858864533475e+45
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 4, 0, 28), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 0, 0, 5, 5), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 0, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 4, 5, 28), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 4, 5, 10), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 0, 0), which had val score of 0.0438
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 0, 15), which had val score of 0.0042
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 5, 28), which had val score of -1.1799458240897096e+44
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 0, 0, 28), which had val score of 0.0481
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 0, 0), which had val score of 0.0029
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 4, 0, 36), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 0, 28), which had val score of 0.0027
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 4, 0, 20), which had val score of 0.0642
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 0, 28), which had val score of 0.0036
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 5, 0), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 5, 10), which had val score of -1.2166271311602647e+39
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 28), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 0, 20), which had val score of 0.0531
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 4, 0, 20), which had val score of 0.0545
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 5, 28), which had val score of -4.934726774702762e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 4, 0, 5), which had val score of 0.0482
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 10), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 0, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 5, 0), which had val score of -1.7932034077943542e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 0, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 0, 36), which had val score of 0.0437
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 5, 5), which had val score of -6.9688708286682085e+44
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 0, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 0, 32), which had val score of 0.0036
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 28), which had val score of 0.0036
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 10), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 0, 10), which had val score of 0.0042
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 0, 28), which had val score of 0.062
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 4, 5, 20), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 4, 5, 20), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 0, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 5, 28), which had val score of -9.258696016344315e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 4, 0, 28), which had val score of 0.0551
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 0, 32), which had val score of 0.0037
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 5, 20), which had val score of -1.84609461391995e+44
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 0, 5), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 4, 0, 15), which had val score of 0.0482
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 0, 10), which had val score of 0.0487
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 4, 0, 32), which had val score of 0.0482
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 4, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 5, 0), which had val score of -2.0800215708267935e+41
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 0, 0, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 0, 24), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 5, 5), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 0, 10), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 4, 0, 36), which had val score of 0.0481
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 4, 0, 20), which had val score of 0.0035
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 5, 15), which had val score of -6.345032708158559e+39
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 0, 0), which had val score of 0.0448
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 5, 20), which had val score of -2.6293535072415328e+45
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 0, 5, 5), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 5, 32), which had val score of -6.541860458961058e+39
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 0, 5, 28), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 0, 15), which had val score of 0.0033
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 5, 32), which had val score of -3.256838112401503e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 0, 5, 15), which had val score of -6.899765405240503e+42
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 0, 36), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 0, 28), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 5, 5), which had val score of -1.2064564273949863e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 4, 0, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 0, 5), which had val score of 0.0377
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 0, 0, 5), which had val score of 0.0031
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 5, 0), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 20), which had val score of 0.0035
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 0, 10), which had val score of 0.0632
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 0, 5), which had val score of 0.0409
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 4, 0, 36), which had val score of 0.0438
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 5, 24), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 5, 0), which had val score of -4.305762133888539e+41
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 0, 5, 20), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 5, 0), which had val score of -4.305762133888539e+41
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 0, 5, 10), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 4, 5, 10), which had val score of -1.2721189794318514e+44
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 0, 4, 5, 10), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 4, 5, 20), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 0, 28), which had val score of 0.063
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 4, 0, 20), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 5, 32), which had val score of -4.9802219363554795e+42
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 0, 4, 5, 0), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 4, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 4, 4, 0, 24), which had val score of 0.0482
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 4, 5, 0), which had val score of -1.0665596170212332e+38
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 4, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 0, 32), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 0, 4, 0, 28), which had val score of 0.0036
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 4, 5, 32), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 0, 28), which had val score of 0.0537
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 4, 0, 0), which had val score of 0.0029
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 4, 5, 36), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 20), which had val score of 0.0028
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 5, 20), which had val score of -7.479039625291135e+42
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 0, 5, 32), which had val score of -1.8620126409694262e+44
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 0, 5, 20), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 4, 0, 36), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 4, 5, 32), which had val score of -8.658648024777267e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 4, 5, 10), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 4, 0, 36), which had val score of 0.0561
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 4, 4, 0, 10), which had val score of 0.0642
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 4, 4, 0, 36), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 0, 0, 28), which had val score of 0.043
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 5, 0), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 0, 0, 10), which had val score of 0.0028
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 5, 32), which had val score of -3.153356443303543e+45
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 0, 4, 0, 28), which had val score of 0.0028
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 4, 0, 20), which had val score of 0.0631
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 0, 5, 36), which had val score of -9.417080129297173e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 5, 24), which had val score of -3.177374691030929e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 0, 28), which had val score of 0.0559
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 0, 0, 5), which had val score of 0.0378
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 0, 0), which had val score of 0.0448
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 4, 5, 28), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 4, 0, 0, 0, 20), which had val score of 0.0439
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 4, 0, 28), which had val score of 0.063
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 4, 0, 24), which had val score of 0.0028
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 4, 4, 5, 24), which had val score of -9.258696016344315e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 0, 15), which had val score of 0.0514
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 0, 4, 4, 0, 0), which had val score of 0.0029
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 5, 15), which had val score of -2.235211847422152e+43
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 4, 0, 4, 0, 0), which had val score of 0.0448
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 3, 4, 0, 0, 0, 10), which had val score of 0.0032
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 0, 4, 0, 0, 5, 24), which had val score of -1.7716605577002754e+40
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (0, 6, 4, 4, 0, 0, 24), which had val score of 0.0041
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
#         Has trained 792 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4, 4, 5, 15), which had val score of 0.0
#         Current best combo: (4, 3, 4, 4, 4, 0, 10) with val score 0.0642.
# ...
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1167 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 1, 3, 19), which had val score of 0.8967
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1167 of 971250 combinations so far
# Trained and Tested combination 1168 of 971250: (4, 1, 2, 0, 0, 3, 19), taking 6.45 seconds to get val score of 0.8954
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 2, 0, 2, 3, 19), which had val score of 0.8959
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1168 of 971250 combinations so far
# Trained and Tested combination 1169 of 971250: (4, 1, 2, 0, 1, 2, 19), taking 3.93 seconds to get val score of 0.8748
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1170 of 971250: (4, 1, 2, 0, 1, 4, 19), taking 3.36 seconds to get val score of 0.7234
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1171 of 971250: (4, 1, 2, 0, 1, 3, 18), taking 6.08 seconds to get val score of 0.8953
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1172 of 971250: (4, 1, 2, 0, 1, 3, 20), taking 3.54 seconds to get val score of 0.8957
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (3, 1, 2, 2, 1, 3, 19), which had val score of 0.895
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1172 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 2, 2, 1, 3, 19), which had val score of 0.8933
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1172 of 971250 combinations so far
# Trained and Tested combination 1173 of 971250: (4, 2, 2, 2, 1, 3, 19), taking 74.57 seconds to get val score of 0.8882
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 1, 2, 1, 3, 19), which had val score of 0.8942
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1173 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 3, 2, 1, 3, 19), which had val score of 0.8961
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1173 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 1, 3, 19), which had val score of 0.8967
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1173 of 971250 combinations so far
# Trained and Tested combination 1174 of 971250: (4, 1, 2, 3, 1, 3, 19), taking 4.65 seconds to get val score of 0.8949
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1175 of 971250: (4, 1, 2, 2, 0, 3, 19), taking 7.25 seconds to get val score of 0.8952
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 2, 2, 2, 3, 19), which had val score of 0.8951
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1175 of 971250 combinations so far
# Trained and Tested combination 1176 of 971250: (4, 1, 2, 2, 1, 2, 19), taking 4.9 seconds to get val score of 0.8812
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1177 of 971250: (4, 1, 2, 2, 1, 4, 19), taking 7.4 seconds to get val score of 0.7118
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1178 of 971250: (4, 1, 2, 2, 1, 3, 18), taking 4.08 seconds to get val score of 0.8949
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1179 of 971250: (4, 1, 2, 2, 1, 3, 20), taking 7.4 seconds to get val score of 0.8952
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (3, 1, 2, 1, 0, 3, 19), which had val score of 0.8962
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1179 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 2, 1, 0, 3, 19), which had val score of 0.8934
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1179 of 971250 combinations so far
# Trained and Tested combination 1180 of 971250: (4, 2, 2, 1, 0, 3, 19), taking 59.02 seconds to get val score of 0.8871
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 1, 1, 0, 3, 19), which had val score of 0.8954
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1180 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 3, 1, 0, 3, 19), which had val score of 0.8963
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1180 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 0, 0, 3, 19), which had val score of 0.8954
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1180 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 2, 0, 3, 19), which had val score of 0.8952
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1180 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 1, 3, 19), which had val score of 0.8967
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1180 of 971250 combinations so far
# Trained and Tested combination 1181 of 971250: (4, 1, 2, 1, 0, 2, 19), taking 4.48 seconds to get val score of 0.8803
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1182 of 971250: (4, 1, 2, 1, 0, 4, 19), taking 3.84 seconds to get val score of 0.7162
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1183 of 971250: (4, 1, 2, 1, 0, 3, 18), taking 6.7 seconds to get val score of 0.8953
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1184 of 971250: (4, 1, 2, 1, 0, 3, 20), taking 3.85 seconds to get val score of 0.8952
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (3, 1, 2, 1, 2, 3, 19), which had val score of 0.8959
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 2, 1, 2, 3, 19), which had val score of 0.8934
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 2, 2, 1, 2, 3, 19), which had val score of 0.8879
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 1, 1, 2, 3, 19), which had val score of 0.8957
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 3, 1, 2, 3, 19), which had val score of 0.896
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 0, 2, 3, 19), which had val score of 0.8959
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 2, 2, 3, 19), which had val score of 0.8951
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 1, 3, 19), which had val score of 0.8967
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 3, 3, 19), which had val score of 0.8958
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 2, 19), which had val score of 0.8803
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 4, 19), which had val score of 0.7169
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 3, 18), which had val score of 0.8957
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 3, 20), which had val score of 0.8954
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 1, 3, 18), which had val score of 0.8953
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 2, 1, 1, 3, 18), which had val score of 0.8932
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1184 of 971250 combinations so far
# Trained and Tested combination 1185 of 971250: (4, 2, 2, 1, 1, 3, 18), taking 56.52 seconds to get val score of 0.8826
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 1, 1, 1, 3, 18), which had val score of 0.8945
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1185 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 3, 1, 1, 3, 18), which had val score of 0.8955
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1185 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 0, 1, 3, 18), which had val score of 0.8953
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1185 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 2, 1, 3, 18), which had val score of 0.8949
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1185 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 0, 3, 18), which had val score of 0.8953
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1185 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 3, 18), which had val score of 0.8957
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1185 of 971250 combinations so far
# Trained and Tested combination 1186 of 971250: (4, 1, 2, 1, 1, 2, 18), taking 4.28 seconds to get val score of 0.8789
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1187 of 971250: (4, 1, 2, 1, 1, 4, 18), taking 5.52 seconds to get val score of 0.682
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1188 of 971250: (4, 1, 2, 1, 1, 3, 17), taking 3.69 seconds to get val score of 0.8954
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 2, 1, 1, 3, 19), which had val score of 0.8967
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1188 of 971250 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 1, 3, 20), which had val score of 0.895
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1188 of 971250 combinations so far
# Already Trained and Tested combination (4, 0, 2, 1, 1, 3, 20), which had val score of 0.8929
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1188 of 971250 combinations so far
# Trained and Tested combination 1189 of 971250: (4, 2, 2, 1, 1, 3, 20), taking 59.95 seconds to get val score of 0.8859
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 1, 1, 1, 3, 20), which had val score of 0.8946
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1189 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 3, 1, 1, 3, 20), which had val score of 0.8958
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1189 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 0, 1, 3, 20), which had val score of 0.8957
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1189 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 2, 1, 3, 20), which had val score of 0.8952
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1189 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 0, 3, 20), which had val score of 0.8952
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1189 of 971250 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 3, 20), which had val score of 0.8954
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1189 of 971250 combinations so far
# Trained and Tested combination 1190 of 971250: (4, 1, 2, 1, 1, 2, 20), taking 5.71 seconds to get val score of 0.8786
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Trained and Tested combination 1191 of 971250: (4, 1, 2, 1, 1, 4, 20), taking 3.89 seconds to get val score of 0.6769
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# Already Trained and Tested combination (4, 1, 2, 1, 1, 3, 19), which had val score of 0.8967
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967.
#         Has trained 1191 of 971250 combinations so far
# Trained and Tested combination 1192 of 971250: (4, 1, 2, 1, 1, 3, 21), taking 7.23 seconds to get val score of 0.8955
#         Current best combo: (4, 1, 2, 1, 1, 3, 19) with val score 0.8967
# % Combos Checked Thus Far: 1192 out of 971250 which is 0.122728%
# Max Val Score:
#  0.8967472708637356
# Best Combo Test Score:
#  0.89692
# Best Combo Train Score:
#  0.93898
# Max Combo Index:
#  (4, 1, 2, 1, 1, 3, 19) out of [5, 7, 5, 5, 5, 6, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 400, 'max_depth': 6, 'subsample': 0.7, 'colsample_bytree': 0.55, 'gamma': 1e-06, 'eta': 0.1, 'features': 19}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains', 'Tackles Inside 50')
# % Combos Checked: 1192 out of 971250 which is 0.122728%
