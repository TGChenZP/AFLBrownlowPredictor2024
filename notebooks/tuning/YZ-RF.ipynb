# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'rf'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.2.8-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.8-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.8

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1536 rows, for 1536.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (1, 2, 0, 4, 0, 36), which had val score of 0.7536
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 4, 0, 4, 0, 36), which had val score of 0.7903
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 1, 4, 0, 36), which had val score of 0.795
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 3, 0, 36), which had val score of 0.8732
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 1, 36), which had val score of 0.7914
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 0, 35), which had val score of 0.7935
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 1, 4, 0, 36), which had val score of 0.795
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 1, 4, 0, 36), which had val score of 0.7475
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 1, 4, 0, 36), which had val score of 0.7867
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 36), which had val score of 0.784
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 2, 4, 0, 36), which had val score of 0.794
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 3, 0, 36), which had val score of 0.8702
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 4, 1, 36), which had val score of 0.7878
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 4, 0, 35), which had val score of 0.7933
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 3, 0, 36), which had val score of 0.8732
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 3, 0, 36), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 3, 0, 36), which had val score of 0.8687
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 3, 0, 36), which had val score of 0.8702
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 2, 0, 36), which had val score of 0.8687
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 36), which had val score of 0.784
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 1, 36), which had val score of 0.8689
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 35), which had val score of 0.868
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 1, 36), which had val score of 0.7914
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 4, 1, 36), which had val score of 0.7481
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 1, 36), which had val score of 0.7852
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 4, 1, 36), which had val score of 0.7878
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 1, 36), which had val score of 0.8689
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 36), which had val score of 0.784
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 2, 36), which had val score of 0.6822
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 35), which had val score of 0.7863
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 4, 0, 35), which had val score of 0.7935
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 4, 0, 35), which had val score of 0.7549
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 0, 35), which had val score of 0.7857
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 4, 0, 35), which had val score of 0.7933
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 3, 0, 35), which had val score of 0.868
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 1, 35), which had val score of 0.7863
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 34), which had val score of 0.7906
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 4, 0, 36), which had val score of 0.784
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# % Combos Checked Thus Far: 1536 out of 194250 which is 0.790734%
# Cruising Coordrdinate 23 of 432
#
# Cruising Coordrdinate 24 of 432
#
# Cruising Coordrdinate 25 of 432
#
# Cruising Coordrdinate 26 of 432
#
# Cruising Coordrdinate 27 of 432
#
# Cruising Coordrdinate 28 of 432
#
# Cruising Coordrdinate 29 of 432
#
# Cruising Coordrdinate 30 of 432
#
# Cruising Coordrdinate 31 of 432
#
# Cruising Coordrdinate 32 of 432
#
# Cruising Coordrdinate 33 of 432
#
# Cruising Coordrdinate 34 of 432
#
# Cruising Coordrdinate 35 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 6
#
# 	round 6 iteration:  0
#
# Already Trained and Tested combination (4, 0, 0, 0, 0, 36), which had val score of 0.6852
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0, 0, 36), which had val score of 0.7861
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 0, 36), which had val score of 0.6849
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 0, 36), which had val score of 0.6878
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 35), which had val score of 0.6866
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# 	round 6 iteration:  1
#
# Already Trained and Tested combination (3, 0, 0, 0, 0, 36), which had val score of 0.6839
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 1, 0, 0, 0, 36), which had val score of 0.7864
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 0, 36), which had val score of 0.6848
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 1, 0, 36), which had val score of 0.687
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 1, 36), which had val score of 0.6852
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 0, 35), which had val score of 0.6868
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 1, 0, 0, 0, 36), which had val score of 0.7864
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 36), which had val score of 0.8621
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 1, 0, 0, 36), which had val score of 0.7856
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 0, 1, 0, 36), which had val score of 0.7898
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0, 1, 36), which had val score of 0.7861
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0, 0, 35), which had val score of 0.7869
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0, 0, 36), which had val score of 0.6848
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 1, 0, 0, 36), which had val score of 0.7856
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 2, 0, 0, 36), which had val score of 0.6847
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 1, 1, 0, 36), which had val score of 0.6877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 1, 36), which had val score of 0.6849
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 0, 35), which had val score of 0.6865
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 1, 0, 36), which had val score of 0.687
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 0, 1, 0, 36), which had val score of 0.7898
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 1, 1, 0, 36), which had val score of 0.6877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 2, 0, 36), which had val score of 0.6867
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 1, 36), which had val score of 0.6878
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 0, 35), which had val score of 0.6887
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 1, 36), which had val score of 0.6852
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0, 1, 36), which had val score of 0.7861
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 1, 36), which had val score of 0.6849
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 1, 36), which had val score of 0.6878
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 2, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 35), which had val score of 0.6866
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0, 0, 35), which had val score of 0.6868
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0, 0, 35), which had val score of 0.7869
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 1, 0, 0, 35), which had val score of 0.6865
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 1, 0, 35), which had val score of 0.6887
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 1, 35), which had val score of 0.6866
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 34), which had val score of 0.686
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0, 0, 36), which had val score of 0.6854
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# % Combos Checked Thus Far: 1536 out of 194250 which is 0.790734%
# Cruising Coordrdinate 36 of 432
#
# Cruising Coordrdinate 37 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 7
#
# 	round 7 iteration:  0
#
# Already Trained and Tested combination (4, 6, 0, 0, 0, 36), which had val score of 0.8723
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 0, 36), which had val score of 0.8743
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 0, 36), which had val score of 0.875
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 1, 36), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 35), which had val score of 0.8721
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# 	round 7 iteration:  1
#
# Already Trained and Tested combination (3, 6, 0, 0, 0, 36), which had val score of 0.8718
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 0, 0, 36), which had val score of 0.8723
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 1, 0, 0, 36), which had val score of 0.874
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 0, 36), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 1, 36), which had val score of 0.8716
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 35), which had val score of 0.8718
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 0, 0, 36), which had val score of 0.8723
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 1, 0, 0, 36), which had val score of 0.8743
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 0, 36), which had val score of 0.875
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 1, 36), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 0, 35), which had val score of 0.8721
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 1, 0, 0, 36), which had val score of 0.874
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 1, 0, 0, 36), which had val score of 0.8743
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 2, 0, 0, 36), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 0, 36), which had val score of 0.8771
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 1, 36), which had val score of 0.8735
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 0, 35), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 0, 36), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 0, 36), which had val score of 0.875
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 0, 36), which had val score of 0.8771
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 0, 36), which had val score of 0.8758
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 1, 36), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 0, 35), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 1, 36), which had val score of 0.8716
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 1, 36), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 1, 36), which had val score of 0.8735
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 1, 36), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 2, 36), which had val score of 0.7933
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 1, 35), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 35), which had val score of 0.8718
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 0, 35), which had val score of 0.8721
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 0, 35), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 0, 35), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 1, 35), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 34), which had val score of 0.8724
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# % Combos Checked Thus Far: 1536 out of 194250 which is 0.790734%
# Cruising Coordrdinate 38 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 8
#
# 	round 8 iteration:  0
#
# Already Trained and Tested combination (4, 6, 0, 4, 0, 36), which had val score of 0.7987
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 0, 36), which had val score of 0.8049
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 0, 36), which had val score of 0.8762
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 36), which had val score of 0.7995
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 35), which had val score of 0.8017
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# 	round 8 iteration:  1
#
# Already Trained and Tested combination (3, 6, 0, 4, 0, 36), which had val score of 0.7967
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 4, 0, 36), which had val score of 0.7987
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 1, 4, 0, 36), which had val score of 0.8049
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 3, 0, 36), which had val score of 0.876
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 1, 36), which had val score of 0.798
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 35), which had val score of 0.8019
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 4, 0, 36), which had val score of 0.7987
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 1, 4, 0, 36), which had val score of 0.8049
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 3, 0, 36), which had val score of 0.8762
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 1, 36), which had val score of 0.7995
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 0, 35), which had val score of 0.8017
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 1, 4, 0, 36), which had val score of 0.8049
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 1, 4, 0, 36), which had val score of 0.8049
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 2, 4, 0, 36), which had val score of 0.807
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 3, 0, 36), which had val score of 0.8777
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 1, 36), which had val score of 0.8036
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 0, 35), which had val score of 0.806
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 3, 0, 36), which had val score of 0.876
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 3, 0, 36), which had val score of 0.8762
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 3, 0, 36), which had val score of 0.8777
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 0, 36), which had val score of 0.8758
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 1, 36), which had val score of 0.8756
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 0, 35), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 1, 36), which had val score of 0.798
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 1, 36), which had val score of 0.7995
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 1, 36), which had val score of 0.8036
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 1, 36), which had val score of 0.8756
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 2, 36), which had val score of 0.6894
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 35), which had val score of 0.8009
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 35), which had val score of 0.8019
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 0, 35), which had val score of 0.8017
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 0, 35), which had val score of 0.806
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 0, 35), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 35), which had val score of 0.8009
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 34), which had val score of 0.8032
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 36), which had val score of 0.8003
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# % Combos Checked Thus Far: 1536 out of 194250 which is 0.790734%
# Cruising Coordrdinate 39 of 432
#
# Cruising Coordrdinate 40 of 432
#
# Cruising Coordrdinate 41 of 432
#
# Cruising Coordrdinate 42 of 432
#
# Cruising Coordrdinate 43 of 432
#
# Cruising Coordrdinate 44 of 432
#
# Cruising Coordrdinate 45 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 9
#
# 	round 9 iteration:  0
#
# Already Trained and Tested combination (4, 3, 0, 0, 0, 36), which had val score of 0.872
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 36), which had val score of 0.8621
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 36), which had val score of 0.8722
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 36), which had val score of 0.8742
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 36), which had val score of 0.8752
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 36), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 35), which had val score of 0.872
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# 	round 9 iteration:  1
#
# Already Trained and Tested combination (3, 3, 0, 0, 0, 36), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 36), which had val score of 0.872
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 2, 0, 0, 0, 36), which had val score of 0.8621
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 0, 0, 0, 36), which had val score of 0.8723
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 0, 0, 36), which had val score of 0.8742
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 1, 0, 36), which had val score of 0.8747
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 1, 36), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 35), which had val score of 0.8716
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 0, 0, 36), which had val score of 0.8742
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 1, 0, 0, 36), which had val score of 0.8629
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 1, 0, 0, 36), which had val score of 0.8743
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 36), which had val score of 0.872
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 0, 0, 36), which had val score of 0.8758
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 1, 0, 36), which had val score of 0.8769
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 1, 36), which had val score of 0.8735
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 35), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 1, 0, 36), which had val score of 0.8747
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 1, 0, 36), which had val score of 0.8653
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 1, 0, 36), which had val score of 0.875
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 1, 0, 36), which had val score of 0.8769
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 36), which had val score of 0.872
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 2, 0, 36), which had val score of 0.876
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 1, 36), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 35), which had val score of 0.8747
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 1, 36), which had val score of 0.8715
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# ...
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 0, 5), which had val score of 0.7899
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 1, 5), which had val score of 0.7897
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 4), which had val score of 0.7584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 6), which had val score of 0.8101
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# 	round 30 iteration:  1
#
# Already Trained and Tested combination (3, 6, 0, 0, 0, 5), which had val score of 0.789
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 0, 0, 5), which had val score of 0.7894
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 1, 0, 0, 5), which had val score of 0.7897
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 0, 5), which had val score of 0.7895
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 1, 5), which had val score of 0.7895
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 4), which had val score of 0.7581
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 6), which had val score of 0.8096
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 0, 0, 5), which had val score of 0.7894
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 1, 0, 0, 5), which had val score of 0.7899
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 1, 5), which had val score of 0.7897
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 0, 4), which had val score of 0.7584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 0, 6), which had val score of 0.8101
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 1, 0, 0, 5), which had val score of 0.7897
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 1, 0, 0, 5), which had val score of 0.7899
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 2, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 0, 5), which had val score of 0.7895
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 1, 5), which had val score of 0.7901
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 0, 4), which had val score of 0.7578
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 0, 6), which had val score of 0.8107
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 0, 5), which had val score of 0.7895
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 0, 5), which had val score of 0.7895
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 0, 5), which had val score of 0.7894
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 1, 5), which had val score of 0.7897
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 0, 4), which had val score of 0.7584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 0, 6), which had val score of 0.8111
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 1, 5), which had val score of 0.7895
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 1, 5), which had val score of 0.7897
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 1, 5), which had val score of 0.7901
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 1, 5), which had val score of 0.7897
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 2, 5), which had val score of 0.7659
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 1, 4), which had val score of 0.7586
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 1, 6), which had val score of 0.81
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 0, 6), which had val score of 0.8096
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 0, 6), which had val score of 0.8101
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 0, 6), which had val score of 0.8107
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 0, 6), which had val score of 0.8111
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 1, 6), which had val score of 0.81
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 5), which had val score of 0.7896
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 0, 7), which had val score of 0.8326
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# % Combos Checked Thus Far: 1536 out of 194250 which is 0.790734%
# Cruising Coordrdinate 198 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 31
#
# 	round 31 iteration:  0
#
# Already Trained and Tested combination (4, 6, 0, 4, 0, 5), which had val score of 0.7882
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 0, 5), which had val score of 0.7886
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 0, 5), which had val score of 0.789
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 0, 5), which had val score of 0.7887
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 5), which had val score of 0.7883
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 4), which had val score of 0.7573
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 6), which had val score of 0.8045
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# 	round 31 iteration:  1
#
# Already Trained and Tested combination (3, 6, 0, 4, 0, 5), which had val score of 0.7871
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 5), which had val score of 0.7886
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 4, 0, 5), which had val score of 0.7882
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 1, 4, 0, 5), which had val score of 0.7884
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 3, 0, 5), which had val score of 0.7884
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 1, 5), which had val score of 0.7881
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 4), which had val score of 0.7568
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 6), which had val score of 0.8041
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Already Trained and Tested combination (4, 5, 0, 4, 0, 5), which had val score of 0.7882
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1536 of 194250 combinations so far
# Trained and Tested combination 1537 of 194250: (5, 4, 0, 4, 0, 5), taking 204.62 seconds to get val score of 0.7886
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Already Trained and Tested combination (5, 6, 0, 4, 0, 5), which had val score of 0.7886
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 1537 of 194250 combinations so far
# Trained and Tested combination 1538 of 194250: (5, 5, 1, 4, 0, 5), taking 453.52 seconds to get val score of 0.789
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Trained and Tested combination 1539 of 194250: (5, 5, 0, 3, 0, 5), taking 421.46 seconds to get val score of 0.7887
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
