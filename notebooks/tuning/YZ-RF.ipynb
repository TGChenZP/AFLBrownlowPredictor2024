# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'rf'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.4.0-py3-none-any.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.8 MB/s eta 0:00:00
# Downloading JXAutoML-0.4.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.4.0

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import RandomForestRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': SEED,
    'n_jobs': -1
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 3284 rows, for 3284.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (5, 6, 0, 4, 2, 24), which had val score of 0.7261
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 23), which had val score of 0.8231
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 25), which had val score of 0.8211
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 23), which had val score of 0.8239
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 0, 23), which had val score of 0.824
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 0, 23), which had val score of 0.8265
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 0, 23), which had val score of 0.8787
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 23), which had val score of 0.8231
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 22), which had val score of 0.8259
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 24), which had val score of 0.8261
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 6, 0, 4, 0, 25), which had val score of 0.8213
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 0, 4, 0, 25), which had val score of 0.8218
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 1, 4, 0, 25), which had val score of 0.8255
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 0, 25), which had val score of 0.8779
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 1, 25), which had val score of 0.8211
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 24), which had val score of 0.8261
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 6, 0, 4, 0, 26), which had val score of 0.8197
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# % Combos Checked Thus Far: 3284 out of 194250 which is 1.690605%
# Cruising Coordrdinate 321 of 432
#
# Cruising Coordrdinate 322 of 432
#
# Cruising Coordrdinate 323 of 432
#
# Cruising Coordrdinate 324 of 432
#
# Cruising Coordrdinate 325 of 432
#
# Cruising Coordrdinate 326 of 432
#
# Cruising Coordrdinate 327 of 432
#
# Cruising Coordrdinate 328 of 432
#
# Cruising Coordrdinate 329 of 432
#
# Cruising Coordrdinate 330 of 432
#
# Cruising Coordrdinate 331 of 432
#
# Cruising Coordrdinate 332 of 432
#
# Cruising Coordrdinate 333 of 432
#
# Cruising Coordrdinate 334 of 432
#
# Cruising Coordrdinate 335 of 432
#
# Cruising Coordrdinate 336 of 432
#
# Cruising Coordrdinate 337 of 432
#
# Cruising Coordrdinate 338 of 432
#
# Cruising Coordrdinate 339 of 432
#
# Cruising Coordrdinate 340 of 432
#
# Cruising Coordrdinate 341 of 432
#
# Cruising Coordrdinate 342 of 432
#
# Cruising Coordrdinate 343 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 57
#
# 	round 57 iteration:  0
#
# Already Trained and Tested combination (4, 3, 0, 0, 0, 10), which had val score of 0.8751
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 10), which had val score of 0.8649
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 10), which had val score of 0.8754
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 10), which had val score of 0.8767
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 10), which had val score of 0.8771
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 10), which had val score of 0.8747
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 9), which had val score of 0.8731
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 11), which had val score of 0.8743
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# 	round 57 iteration:  1
#
# Already Trained and Tested combination (3, 3, 0, 0, 0, 10), which had val score of 0.8747
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 10), which had val score of 0.8753
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 2, 0, 0, 0, 10), which had val score of 0.8648
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 0, 0, 0, 10), which had val score of 0.8752
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 0, 0, 10), which had val score of 0.8765
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 1, 0, 10), which had val score of 0.877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 1, 10), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 9), which had val score of 0.873
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 11), which had val score of 0.8741
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 0, 0, 10), which had val score of 0.8765
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 1, 0, 0, 10), which had val score of 0.8653
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 1, 0, 0, 10), which had val score of 0.8767
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 10), which had val score of 0.8753
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 0, 0, 10), which had val score of 0.8777
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 1, 0, 10), which had val score of 0.8781
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 1, 10), which had val score of 0.8758
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 9), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 11), which had val score of 0.8759
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 1, 0, 10), which had val score of 0.877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 1, 0, 10), which had val score of 0.8674
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 1, 0, 10), which had val score of 0.8769
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 1, 0, 10), which had val score of 0.8781
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 10), which had val score of 0.8753
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 2, 0, 10), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 1, 10), which had val score of 0.8764
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 9), which had val score of 0.874
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 11), which had val score of 0.8762
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 1, 10), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 1, 10), which had val score of 0.8649
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 1, 10), which had val score of 0.8747
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 1, 10), which had val score of 0.8758
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 1, 10), which had val score of 0.8764
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 10), which had val score of 0.8753
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 2, 10), which had val score of 0.7968
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 9), which had val score of 0.8725
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 11), which had val score of 0.8736
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 9), which had val score of 0.873
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 9), which had val score of 0.8633
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 9), which had val score of 0.8731
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 9), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 9), which had val score of 0.874
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 9), which had val score of 0.8725
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 8), which had val score of 0.855
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 10), which had val score of 0.8753
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 11), which had val score of 0.8741
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 11), which had val score of 0.8641
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 11), which had val score of 0.8745
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 11), which had val score of 0.8759
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 11), which had val score of 0.8762
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 11), which had val score of 0.8736
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 10), which had val score of 0.8753
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 12), which had val score of 0.8754
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# % Combos Checked Thus Far: 3284 out of 194250 which is 1.690605%
# Cruising Coordrdinate 344 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 58
#
# 	round 58 iteration:  0
#
# Already Trained and Tested combination (4, 3, 0, 0, 0, 24), which had val score of 0.8758
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 24), which had val score of 0.8649
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 24), which had val score of 0.8755
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 24), which had val score of 0.8775
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 24), which had val score of 0.8775
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 24), which had val score of 0.8751
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 23), which had val score of 0.8754
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 25), which had val score of 0.8747
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# 	round 58 iteration:  1
#
# Already Trained and Tested combination (3, 3, 0, 0, 0, 24), which had val score of 0.8756
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 24), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 2, 0, 0, 0, 24), which had val score of 0.8646
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 0, 0, 0, 24), which had val score of 0.8753
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 0, 0, 24), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 1, 0, 24), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 1, 24), which had val score of 0.8752
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 23), which had val score of 0.8751
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 25), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 0, 0, 24), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 1, 0, 0, 24), which had val score of 0.8654
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 1, 0, 0, 24), which had val score of 0.8775
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 24), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 0, 0, 24), which had val score of 0.8787
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 1, 0, 24), which had val score of 0.8792
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 1, 24), which had val score of 0.8766
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 23), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 25), which had val score of 0.877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 1, 0, 24), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 1, 0, 24), which had val score of 0.8669
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 1, 0, 24), which had val score of 0.8774
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 1, 0, 24), which had val score of 0.8792
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 24), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 2, 0, 24), which had val score of 0.8782
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 1, 24), which had val score of 0.8768
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 23), which had val score of 0.878
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 25), which had val score of 0.8772
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 1, 24), which had val score of 0.8752
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 1, 24), which had val score of 0.8649
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 1, 24), which had val score of 0.8748
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 1, 24), which had val score of 0.8766
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 1, 24), which had val score of 0.8768
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 24), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 2, 24), which had val score of 0.7954
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 23), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 25), which had val score of 0.8741
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 23), which had val score of 0.8751
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 23), which had val score of 0.8647
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 23), which had val score of 0.8754
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 23), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 23), which had val score of 0.878
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 23), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 22), which had val score of 0.8759
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 24), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 0, 0, 25), which had val score of 0.8744
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 0, 0, 25), which had val score of 0.8642
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 0, 0, 25), which had val score of 0.8748
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 0, 0, 25), which had val score of 0.877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 1, 0, 25), which had val score of 0.8772
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 1, 25), which had val score of 0.8741
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 24), which had val score of 0.8757
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 0, 0, 26), which had val score of 0.874
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# % Combos Checked Thus Far: 3284 out of 194250 which is 1.690605%
# Cruising Coordrdinate 345 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 59
#
# 	round 59 iteration:  0
#
# Already Trained and Tested combination (4, 3, 0, 4, 0, 10), which had val score of 0.8585
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 0, 10), which had val score of 0.8349
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 10), which had val score of 0.8583
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 10), which had val score of 0.8611
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 10), which had val score of 0.8772
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 10), which had val score of 0.8576
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 9), which had val score of 0.8583
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 11), which had val score of 0.8553
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# 	round 59 iteration:  1
#
# Already Trained and Tested combination (3, 3, 0, 4, 0, 10), which had val score of 0.8574
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 10), which had val score of 0.8584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 2, 0, 4, 0, 10), which had val score of 0.8349
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 0, 10), which had val score of 0.8583
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 4, 0, 10), which had val score of 0.861
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 0, 10), which had val score of 0.8768
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 1, 10), which had val score of 0.8578
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 9), which had val score of 0.858
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 11), which had val score of 0.8551
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 4, 0, 10), which had val score of 0.861
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 1, 4, 0, 10), which had val score of 0.8355
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 1, 4, 0, 10), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 10), which had val score of 0.8584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 4, 0, 10), which had val score of 0.8622
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 3, 0, 10), which had val score of 0.8783
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 1, 10), which had val score of 0.8599
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 9), which had val score of 0.8606
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 11), which had val score of 0.8582
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 0, 10), which had val score of 0.8768
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 3, 0, 10), which had val score of 0.868
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 3, 0, 10), which had val score of 0.8775
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 3, 0, 10), which had val score of 0.8783
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 2, 0, 10), which had val score of 0.8773
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 10), which had val score of 0.8584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 1, 10), which had val score of 0.8766
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 9), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 11), which had val score of 0.877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 1, 10), which had val score of 0.8578
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 1, 10), which had val score of 0.835
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 1, 10), which had val score of 0.8574
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 1, 10), which had val score of 0.8599
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 1, 10), which had val score of 0.8766
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 10), which had val score of 0.8584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 10), which had val score of 0.7787
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 9), which had val score of 0.8574
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 11), which had val score of 0.8546
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 9), which had val score of 0.858
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 0, 9), which had val score of 0.8357
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 9), which had val score of 0.8582
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 9), which had val score of 0.8606
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 9), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 9), which had val score of 0.8574
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 8), which had val score of 0.8428
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 10), which had val score of 0.8584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 11), which had val score of 0.8551
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 0, 11), which had val score of 0.8312
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 11), which had val score of 0.8559
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 11), which had val score of 0.8582
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 11), which had val score of 0.877
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 11), which had val score of 0.8546
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 10), which had val score of 0.8584
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 12), which had val score of 0.851
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# % Combos Checked Thus Far: 3284 out of 194250 which is 1.690605%
# Cruising Coordrdinate 346 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 60
#
# 	round 60 iteration:  0
#
# Already Trained and Tested combination (4, 3, 0, 4, 0, 24), which had val score of 0.8248
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 0, 24), which had val score of 0.7908
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 24), which had val score of 0.8261
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 24), which had val score of 0.8285
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 24), which had val score of 0.8782
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 24), which had val score of 0.8244
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 23), which had val score of 0.824
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 25), which had val score of 0.8218
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# 	round 60 iteration:  1
#
# Already Trained and Tested combination (3, 3, 0, 4, 0, 24), which had val score of 0.8243
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 24), which had val score of 0.8252
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 2, 0, 4, 0, 24), which had val score of 0.7915
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 0, 4, 0, 24), which had val score of 0.8254
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 1, 4, 0, 24), which had val score of 0.8287
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 3, 0, 24), which had val score of 0.8779
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 1, 24), which had val score of 0.8241
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 23), which had val score of 0.8236
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 25), which had val score of 0.8213
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
# ...
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 3, 2, 0, 17), which had val score of 0.8822
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 17), which had val score of 0.8827
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 3, 2, 0, 17), which had val score of 0.8824
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 0, 17), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 4, 2, 0, 17), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 1, 0, 17), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 0, 17), which had val score of 0.8819
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 1, 17), which had val score of 0.8808
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 0, 16), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 0, 18), which had val score of 0.8822
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 0, 17), which had val score of 0.8817
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 2, 2, 0, 17), which had val score of 0.8691
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 2, 2, 0, 17), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 2, 0, 17), which had val score of 0.8809
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 17), which had val score of 0.8827
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 1, 0, 17), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 0, 17), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 1, 17), which had val score of 0.8805
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 0, 16), which had val score of 0.8805
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 0, 18), which had val score of 0.8814
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 1, 0, 17), which had val score of 0.8817
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 3, 1, 0, 17), which had val score of 0.868
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 1, 0, 17), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 1, 0, 17), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 4, 1, 0, 17), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 0, 0, 17), which had val score of 0.8805
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 17), which had val score of 0.8827
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 1, 1, 17), which had val score of 0.8803
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 1, 0, 16), which had val score of 0.8804
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 1, 0, 18), which had val score of 0.8816
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 0, 17), which had val score of 0.882
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 3, 3, 0, 17), which had val score of 0.8686
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 0, 17), which had val score of 0.8819
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 0, 17), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 4, 3, 0, 17), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 17), which had val score of 0.8827
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 4, 0, 17), which had val score of 0.8457
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1, 17), which had val score of 0.8805
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 16), which had val score of 0.8809
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 18), which had val score of 0.8817
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 1, 17), which had val score of 0.881
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 3, 2, 1, 17), which had val score of 0.8689
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 1, 17), which had val score of 0.8808
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 1, 17), which had val score of 0.8805
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 4, 2, 1, 17), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 1, 1, 17), which had val score of 0.8803
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1, 17), which had val score of 0.8805
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 17), which had val score of 0.8827
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3284 of 194250 combinations so far
# Trained and Tested combination 3285 of 194250: (5, 3, 3, 2, 2, 17), taking 4414.44 seconds to get val score of 0.7943
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Trained and Tested combination 3286 of 194250: (5, 3, 3, 2, 1, 16), taking 4176.73 seconds to get val score of 0.8794
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Trained and Tested combination 3287 of 194250: (5, 3, 3, 2, 1, 18), taking 4206.33 seconds to get val score of 0.8807
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Already Trained and Tested combination (4, 3, 3, 2, 0, 16), which had val score of 0.8806
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3287 of 194250 combinations so far
# Trained and Tested combination 3288 of 194250: (5, 2, 3, 2, 0, 16), taking 371.91 seconds to get val score of 0.8683
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Already Trained and Tested combination (5, 4, 3, 2, 0, 16), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3288 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 0, 16), which had val score of 0.8805
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3288 of 194250 combinations so far
# Trained and Tested combination 3289 of 194250: (5, 3, 4, 2, 0, 16), taking 2.0 seconds to get val score of -0.0001
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Already Trained and Tested combination (5, 3, 3, 1, 0, 16), which had val score of 0.8804
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3289 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 16), which had val score of 0.8809
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3289 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 1, 16), which had val score of 0.8794
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3289 of 194250 combinations so far
# Trained and Tested combination 3290 of 194250: (5, 3, 3, 2, 0, 15), taking 2032.19 seconds to get val score of 0.8813
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Already Trained and Tested combination (5, 3, 3, 2, 0, 17), which had val score of 0.8827
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3290 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 0, 18), which had val score of 0.882
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3290 of 194250 combinations so far
# Trained and Tested combination 3291 of 194250: (5, 2, 3, 2, 0, 18), taking 434.12 seconds to get val score of 0.8685
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Already Trained and Tested combination (5, 4, 3, 2, 0, 18), which had val score of 0.8822
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3291 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 0, 18), which had val score of 0.8814
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3291 of 194250 combinations so far
# Trained and Tested combination 3292 of 194250: (5, 3, 4, 2, 0, 18), taking 2.12 seconds to get val score of -0.0001
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# Already Trained and Tested combination (5, 3, 3, 1, 0, 18), which had val score of 0.8816
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3292 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 18), which had val score of 0.8817
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3292 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 1, 18), which had val score of 0.8807
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3292 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 17), which had val score of 0.8827
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827.
#         Has trained 3292 of 194250 combinations so far
# Trained and Tested combination 3293 of 194250: (5, 3, 3, 2, 0, 19), taking 2156.97 seconds to get val score of 0.8823
#         Current best combo: (5, 3, 3, 2, 0, 17) with val score 0.8827
# % Combos Checked Thus Far: 3293 out of 194250 which is 1.695238%
# Max Val Score:
#  0.882694
# Best Combo Test Score:
#  0.884742
# Best Combo Train Score:
#  0.978528
# Max Combo Index:
#  (5, 3, 3, 2, 0, 17) out of [6, 7, 5, 5, 5, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.7, 'ccp_alpha': 1e-08, 'features': 17}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists')
# % Combos Checked: 3293 out of 194250 which is 1.695238%
