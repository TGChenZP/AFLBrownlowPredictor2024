# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'cb'
TUNER = 'jiaocheng'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cb':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.JiaoCheng import JiaoCheng as Tuner

import pandas as pd
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5
# Collecting JXAutoML
#   Downloading JXAutoML-0.2.6-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.6-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.6

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from catboost import CatBoostClassifier as clf

# what values to try for each hyperparameter
parameter_choices = {

    'n_estimators': (25, 50, 100, 200),
    'max_depth': (2, 4, 8),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bylevel': (0.4, 0.55, 0.7, 0.85, 1),
    'max_bin': (64, 256),
    'reg_lambda': (0.01, 0.1, 1),
    'learning_rate': (0.001, 0.01, 0.1, 1),

}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
    'random_state': 19260817,
    'verbose': False,
    'bootstrap_type': 'Bernoulli',
}

# what order to tune hyperparameters in (JiaoCheng specific)
tuning_order = ['features',
                'max_depth',
                'max_bin',
                'colsample_bylevel',
                'subsample',
                'n_estimators',
                'reg_lambda',
                'learning_rate']

# what order to tune hyperparameters in (JiaoCheng specific)
default_hyperparameter_values = {
    'features': 0,
    'n_estimators': 50,
    'max_depth': 4,
    'subsample': 0.7,
    'colsample_bylevel': 0.7,
    'learning_rate': 0.01,
    'reg_lambda': 0.01,
    'max_bin': 64,
}

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up the order of hyperparameters when iteratively tuning using JiaoCheng
tuner.set_tuning_order(tuning_order)

print('---')

# set up the default hp values for first iteration of tuning JiaoCheng
tuner.set_hyperparameter_default_values(default_hyperparameter_values)

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# JiaoCheng Initialised
# ---
# Successfully read in model <class 'catboost.core.CatBoostClassifier'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# ---
# ---
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts')
# Error Importing this Row: (4, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.792628
# Train r2                                                                  0.561893
# Val r2                                                                    0.553237
# Test r2                                                                   0.559289
# Train rmse                                                                0.195416
# Val rmse                                                                   0.19734
# Test rmse                                                                  0.19601
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         45.42
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                      5.0
# n_features                                                                     4.0
# Precedence                                                                     4.0
# Name: 4, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements')
# Error Importing this Row: (5, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.828421
# Train r2                                                                  0.589243
# Val r2                                                                    0.579624
# Test r2                                                                   0.585444
# Train rmse                                                                0.189218
# Val rmse                                                                  0.191424
# Test rmse                                                                 0.190104
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         45.99
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                      6.0
# n_features                                                                     5.0
# Precedence                                                                     5.0
# Name: 5, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks')
# Error Importing this Row: (6, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.86044
# Train r2                                                                  0.600279
# Val r2                                                                    0.594137
# Test r2                                                                   0.587944
# Train rmse                                                                0.186659
# Val rmse                                                                   0.18809
# Test rmse                                                                  0.18953
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         50.23
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                      7.0
# n_features                                                                     6.0
# Precedence                                                                     6.0
# Name: 6, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles')
# Error Importing this Row: (7, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.886374
# Train r2                                                                  0.586557
# Val r2                                                                    0.575258
# Test r2                                                                   0.574876
# Train rmse                                                                0.189836
# Val rmse                                                                  0.192415
# Test rmse                                                                 0.192512
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         47.61
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                      8.0
# n_features                                                                     7.0
# Precedence                                                                     7.0
# Name: 7, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters')
# Error Importing this Row: (8, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.906895
# Train r2                                                                  0.606849
# Val r2                                                                    0.594144
# Test r2                                                                   0.592768
# Train rmse                                                                0.185118
# Val rmse                                                                  0.188089
# Test rmse                                                                 0.188418
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         49.43
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                      9.0
# n_features                                                                     8.0
# Precedence                                                                     8.0
# Name: 8, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers')
# Error Importing this Row: (9, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.92179
# Train r2                                                                  0.575929
# Val r2                                                                    0.564847
# Test r2                                                                   0.565015
# Train rmse                                                                 0.19226
# Val rmse                                                                  0.194759
# Test rmse                                                                 0.194732
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         52.48
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     10.0
# n_features                                                                     9.0
# Precedence                                                                     9.0
# Name: 9, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50')
# Error Importing this Row: (10, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.93001
# Train r2                                                                  0.593803
# Val r2                                                                    0.586576
# Test r2                                                                   0.586342
# Train rmse                                                                0.188165
# Val rmse                                                                  0.189834
# Test rmse                                                                 0.189898
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         53.46
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     11.0
# n_features                                                                    10.0
# Precedence                                                                    10.0
# Name: 10, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks')
# Error Importing this Row: (11, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.937978
# Train r2                                                                  0.589056
# Val r2                                                                    0.583952
# Test r2                                                                   0.581546
# Train rmse                                                                0.189261
# Val rmse                                                                  0.190436
# Test rmse                                                                 0.190996
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         56.12
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     12.0
# n_features                                                                    11.0
# Precedence                                                                    11.0
# Name: 11, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists')
# Error Importing this Row: (12, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.945127
# Train r2                                                                  0.591685
# Val r2                                                                    0.588293
# Test r2                                                                   0.581528
# Train rmse                                                                0.188655
# Val rmse                                                                   0.18944
# Test rmse                                                                    0.191
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         55.07
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     13.0
# n_features                                                                    12.0
# Precedence                                                                    12.0
# Name: 12, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained')
# Error Importing this Row: (13, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.95156
# Train r2                                                                  0.595782
# Val r2                                                                    0.586918
# Test r2                                                                   0.586628
# Train rmse                                                                0.187706
# Val rmse                                                                  0.189756
# Test rmse                                                                 0.189833
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         59.44
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     14.0
# n_features                                                                    13.0
# Precedence                                                                    13.0
# Name: 13, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks')
# Error Importing this Row: (14, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.957743
# Train r2                                                                  0.588679
# Val r2                                                                     0.57774
# Test r2                                                                   0.580667
# Train rmse                                                                0.189348
# Val rmse                                                                  0.191852
# Test rmse                                                                 0.191196
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          57.4
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     15.0
# n_features                                                                    14.0
# Precedence                                                                    14.0
# Name: 14, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts')
# Error Importing this Row: (15, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.962291
# Train r2                                                                  0.600126
# Val r2                                                                    0.593518
# Test r2                                                                   0.592738
# Train rmse                                                                0.186694
# Val rmse                                                                  0.188234
# Test rmse                                                                 0.188424
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         59.29
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     16.0
# n_features                                                                    15.0
# Precedence                                                                    15.0
# Name: 15, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50')
# Error Importing this Row: (16, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                               0.9654
# Train r2                                                                  0.594329
# Val r2                                                                    0.584544
# Test r2                                                                   0.582824
# Train rmse                                                                0.188043
# Val rmse                                                                    0.1903
# Test rmse                                                                 0.190704
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         66.67
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     17.0
# n_features                                                                    16.0
# Precedence                                                                    16.0
# Name: 16, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains')
# Error Importing this Row: (17, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.968349
# Train r2                                                                  0.589686
# Val r2                                                                    0.584739
# Test r2                                                                   0.581492
# Train rmse                                                                0.189116
# Val rmse                                                                  0.190256
# Test rmse                                                                 0.191008
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         62.32
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     18.0
# n_features                                                                    17.0
# Precedence                                                                    17.0
# Name: 17, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists')
# Error Importing this Row: (18, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.971279
# Train r2                                                                  0.587328
# Val r2                                                                    0.580345
# Test r2                                                                     0.5781
# Train rmse                                                                0.189658
# Val rmse                                                                   0.19126
# Test rmse                                                                 0.191781
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         63.42
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     19.0
# n_features                                                                    18.0
# Precedence                                                                    18.0
# Name: 18, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50')
# Error Importing this Row: (19, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                              0.97392
# Train r2                                                                  0.610949
# Val r2                                                                    0.603753
# Test r2                                                                   0.593486
# Train rmse                                                                 0.18415
# Val rmse                                                                  0.185849
# Test rmse                                                                 0.188251
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         68.81
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     20.0
# n_features                                                                    19.0
# Precedence                                                                    19.0
# Name: 19, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs')
# Error Importing this Row: (20, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.976479
# Train r2                                                                  0.580294
# Val r2                                                                    0.574174
# Test r2                                                                   0.571854
# Train rmse                                                                0.191268
# Val rmse                                                                  0.192661
# Test rmse                                                                 0.193195
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         65.78
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     21.0
# n_features                                                                    20.0
# Precedence                                                                    20.0
# Name: 20, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50')
# Error Importing this Row: (21, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.978626
# Train r2                                                                  0.606736
# Val r2                                                                    0.604923
# Test r2                                                                    0.59828
# Train rmse                                                                0.185145
# Val rmse                                                                  0.185574
# Test rmse                                                                 0.187138
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         70.65
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     22.0
# n_features                                                                    21.0
# Precedence                                                                    21.0
# Name: 21, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %')
# Error Importing this Row: (22, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.980688
# Train r2                                                                  0.583943
# Val r2                                                                    0.580902
# Test r2                                                                   0.574211
# Train rmse                                                                0.190435
# Val rmse                                                                  0.191133
# Test rmse                                                                 0.192663
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          68.9
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     23.0
# n_features                                                                    22.0
# Precedence                                                                    22.0
# Name: 22, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Disposal Efficiency %')
# Error Importing this Row: (23, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.982672
# Train r2                                                                   0.56262
# Val r2                                                                    0.552064
# Test r2                                                                   0.556399
# Train rmse                                                                0.195254
# Val rmse                                                                  0.197599
# Test rmse                                                                 0.196651
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         70.05
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     24.0
# n_features                                                                    23.0
# ...
# Error Importing this Row: (33, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.997437
# Train r2                                                                  0.555719
# Val r2                                                                    0.550281
# Test r2                                                                   0.548354
# Train rmse                                                                0.196788
# Val rmse                                                                  0.197992
# Test rmse                                                                 0.198426
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         87.08
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     34.0
# n_features                                                                    33.0
# Precedence                                                                    33.0
# Name: 33, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Disposal Efficiency %', 'Rebound 50s', 'Uncontested Marks', 'Frees For', 'Inside 50s', 'Turnovers', 'Bounces', 'Centre Clearances', 'Behinds', 'Uncontested Possessions', 'Clearances', 'Stoppage Clearances')
# Error Importing this Row: (34, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.998609
# Train r2                                                                  0.570653
# Val r2                                                                    0.561485
# Test r2                                                                   0.564565
# Train rmse                                                                0.193452
# Val rmse                                                                   0.19551
# Test rmse                                                                 0.194833
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                          86.0
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     35.0
# n_features                                                                    34.0
# Precedence                                                                    34.0
# Name: 34, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Disposal Efficiency %', 'Rebound 50s', 'Uncontested Marks', 'Frees For', 'Inside 50s', 'Turnovers', 'Bounces', 'Centre Clearances', 'Behinds', 'Uncontested Possessions', 'Clearances', 'Stoppage Clearances', 'Ineffective Disposals')
# Error Importing this Row: (35, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.999631
# Train r2                                                                  0.559589
# Val r2                                                                    0.548282
# Test r2                                                                     0.5471
# Train rmse                                                                0.195929
# Val rmse                                                                  0.198432
# Test rmse                                                                 0.198702
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         89.53
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     36.0
# n_features                                                                    35.0
# Precedence                                                                    35.0
# Name: 35, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Disposal Efficiency %', 'Rebound 50s', 'Uncontested Marks', 'Frees For', 'Inside 50s', 'Turnovers', 'Bounces', 'Centre Clearances', 'Behinds', 'Uncontested Possessions', 'Clearances', 'Stoppage Clearances', 'Ineffective Disposals', 'Winloss')
# Error Importing this Row: (36, n_estimators                                                                  50.0
# max_depth                                                                      4.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                                  1.0
# Train r2                                                                  0.542374
# Val r2                                                                    0.534338
# Test r2                                                                   0.531741
# Train rmse                                                                0.199722
# Val rmse                                                                  0.201471
# Test rmse                                                                 0.202043
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         89.59
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     37.0
# n_features                                                                    36.0
# Precedence                                                                    36.0
# Name: 36, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50')
# Error Importing this Row: (37, n_estimators                                                                  50.0
# max_depth                                                                      2.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.978626
# Train r2                                                                  0.322514
# Val r2                                                                    0.327335
# Test r2                                                                   0.315876
# Train rmse                                                                0.243008
# Val rmse                                                                  0.242146
# Test rmse                                                                 0.244212
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                         48.82
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     22.0
# n_features                                                                    21.0
# Precedence                                                                    37.0
# Name: 37, dtype: object)
# Error message: ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Hitouts', 'Score Involvements', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Tackles Outside 50', 'Contested Marks', 'Behind Assists', 'Metres Gained', 'Marks', 'Intercepts', 'Marks Inside 50', 'Frees Agains', 'Goal Assists', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50')
# Error Importing this Row: (38, n_estimators                                                                  50.0
# max_depth                                                                      8.0
# subsample                                                                      0.7
# colsample_bylevel                                                              0.7
# max_bin                                                                       64.0
# reg_lambda                                                                    0.01
# learning_rate                                                                 0.01
# features                         ['Effective Disposals', 'Disposals', 'Conteste...
# feature combo ningxiang score                                             0.978626
# Train r2                                                                  0.721101
# Val r2                                                                    0.697953
# Test r2                                                                   0.697025
# Train rmse                                                                0.155917
# Val rmse                                                                  0.162261
# Test rmse                                                                 0.162519
# Train mape                                                                     NaN
# Val mape                                                                       NaN
# Test mape                                                                      NaN
# Time                                                                        140.71
# random_state                                                            19260817.0
# verbose                                                                      False
# bootstrap_type                                                           Bernoulli
# n_columns                                                                     22.0
# n_features                                                                    21.0
# Precedence                                                                    38.0
# Name: 38, dtype: object)
# Successfully read in tuning result of 187 rows, for 152.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Default combo: [1, 1, 2, 2, 0, 0, 1, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 7)
#
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 0), which had val score of 0.3723
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 0) with val score 0.3723.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 1), which had val score of 0.4273
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 1) with val score 0.4273.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 2) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 2), which had val score of 0.5059
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 2) with val score 0.5059.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 3) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 3), which had val score of 0.5737
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 3) with val score 0.5737.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 4), which had val score of 0.5786
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 4) with val score 0.5786.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 5) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 5), which had val score of 0.5815
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 5) with val score 0.5815.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 6) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 6), which had val score of 0.6011
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 6) with val score 0.6011.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 7), which had val score of 0.5808
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 6) with val score 0.6011.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 8), which had val score of 0.5985
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 6) with val score 0.6011.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 9), which had val score of 0.567
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 6) with val score 0.6011.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 1, 2, 2, 0, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 10), which had val score of 0.6048
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 11), which had val score of 0.5853
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 12), which had val score of 0.5742
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 13), which had val score of 0.5718
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 14), which had val score of 0.5664
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 15), which had val score of 0.576
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 16), which had val score of 0.5851
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 17), which had val score of 0.5865
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 18), which had val score of 0.5867
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 19), which had val score of 0.5745
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 20), which had val score of 0.5622
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 21), which had val score of 0.5928
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 22), which had val score of 0.5794
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 23), which had val score of 0.558
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 24), which had val score of 0.5603
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 25), which had val score of 0.5572
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 26), which had val score of 0.5527
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 27), which had val score of 0.557
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 28), which had val score of 0.5546
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 29), which had val score of 0.5641
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 30), which had val score of 0.5325
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 31), which had val score of 0.5551
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 32), which had val score of 0.5593
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 33), which had val score of 0.5418
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 34), which had val score of 0.5647
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 35), which had val score of 0.5376
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 36), which had val score of 0.5576
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 0, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 0, 0, 1, 10), which had val score of 0.3481
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 0, 0, 1, 10), which had val score of 0.6048
#         Current best combo: (1, 1, 2, 2, 0, 0, 1, 10) with val score 0.6048.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 2, 2, 2, 0, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 0, 0, 1, 10), which had val score of 0.7191
#         Current best combo: (1, 2, 2, 2, 0, 0, 1, 10) with val score 0.7191.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 0, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_bin (index: 4)
#
# Already Trained and Tested combination (1, 2, 2, 2, 0, 0, 1, 10), which had val score of 0.7191
#         Current best combo: (1, 2, 2, 2, 0, 0, 1, 10) with val score 0.7191.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 2, 2, 2, 1, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 1, 0, 1, 10), which had val score of 0.7335
#         Current best combo: (1, 2, 2, 2, 1, 0, 1, 10) with val score 0.7335.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 1, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (1, 2, 2, 0, 1, 0, 1, 10), which had val score of 0.7239
#         Current best combo: (1, 2, 2, 2, 1, 0, 1, 10) with val score 0.7335.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 1, 1, 0, 1, 10), which had val score of 0.7243
#         Current best combo: (1, 2, 2, 2, 1, 0, 1, 10) with val score 0.7335.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 1, 0, 1, 10), which had val score of 0.7335
#         Current best combo: (1, 2, 2, 2, 1, 0, 1, 10) with val score 0.7335.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (1, 2, 2, 3, 1, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.734
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 4, 1, 0, 1, 10), which had val score of 0.7322
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 3, 1, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 2, 0, 3, 1, 0, 1, 10), which had val score of 0.728
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 1, 3, 1, 0, 1, 10), which had val score of 0.7309
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.734
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 3, 3, 1, 0, 1, 10), which had val score of 0.7325
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 4, 3, 1, 0, 1, 10), which had val score of 0.7322
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 3, 1, 0, 1, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.7039
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.734
#         Current best combo: (1, 2, 2, 3, 1, 0, 1, 10) with val score 0.734.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (2, 2, 2, 3, 1, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (2, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.7579
#         Current best combo: (2, 2, 2, 3, 1, 0, 1, 10) with val score 0.7579.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (3, 2, 2, 3, 1, 0, 1, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.7894
#         Current best combo: (3, 2, 2, 3, 1, 0, 1, 10) with val score 0.7894.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 2, 3, 1, 0, 1, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_lambda (index: 5)
#
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.7894
#         Current best combo: (3, 2, 2, 3, 1, 0, 1, 10) with val score 0.7894.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 1, 1, 10), which had val score of 0.7859
#         Current best combo: (3, 2, 2, 3, 1, 0, 1, 10) with val score 0.7894.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 2, 1, 10), which had val score of 0.7765
#         Current best combo: (3, 2, 2, 3, 1, 0, 1, 10) with val score 0.7894.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 2, 3, 1, 0, 1, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 6)
#
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 0, 10), which had val score of 0.7037
#         Current best combo: (3, 2, 2, 3, 1, 0, 1, 10) with val score 0.7894.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 1, 10), which had val score of 0.7894
#         Current best combo: (3, 2, 2, 3, 1, 0, 1, 10) with val score 0.7894.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (3, 2, 2, 3, 1, 0, 2, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 10), which had val score of 0.836
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 3, 10), which had val score of 0.3936
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 2, 3, 1, 0, 2, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 7)
#
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 0), which had val score of 0.3809
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 1), which had val score of 0.4304
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 2), which had val score of 0.537
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 3), which had val score of 0.6501
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 4), which had val score of 0.6649
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 5), which had val score of 0.7092
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 6), which had val score of 0.7407
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 7), which had val score of 0.7699
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 8), which had val score of 0.8043
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 9), which had val score of 0.8268
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 10), which had val score of 0.836
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 11), which had val score of 0.8349
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 12), which had val score of 0.8358
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 13), which had val score of 0.832
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 14), which had val score of 0.8292
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 15), which had val score of 0.835
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 16), which had val score of 0.8354
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 17), which had val score of 0.8339
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 18), which had val score of 0.8331
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 19), which had val score of 0.8342
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 20), which had val score of 0.8355
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 21), which had val score of 0.8333
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 22), which had val score of 0.8297
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 23), which had val score of 0.8293
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 24), which had val score of 0.8326
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 25), which had val score of 0.8291
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 26), which had val score of 0.8309
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 27), which had val score of 0.8295
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 28), which had val score of 0.8262
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 29), which had val score of 0.8245
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 30), which had val score of 0.83
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 31), which had val score of 0.8244
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 32), which had val score of 0.8236
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 33), which had val score of 0.8209
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 34), which had val score of 0.8229
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 35), which had val score of 0.8237
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 36), which had val score of 0.8236
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 2, 3, 1, 0, 2, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (3, 0, 2, 3, 1, 0, 2, 10), which had val score of 0.8149
#         Current best combo: (3, 2, 2, 3, 1, 0, 2, 10) with val score 0.836.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (3, 1, 2, 3, 1, 0, 2, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 1, 2, 3, 1, 0, 2, 10), which had val score of 0.8407
#         Current best combo: (3, 1, 2, 3, 1, 0, 2, 10) with val score 0.8407.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 1, 0, 2, 10), which had val score of 0.836
#         Current best combo: (3, 1, 2, 3, 1, 0, 2, 10) with val score 0.8407.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 3, 1, 0, 2, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_bin (index: 4)
#
# Already Trained and Tested combination (3, 1, 2, 3, 0, 0, 2, 10), which had val score of 0.8369
#         Current best combo: (3, 1, 2, 3, 1, 0, 2, 10) with val score 0.8407.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 3, 1, 0, 2, 10), which had val score of 0.8407
#         Current best combo: (3, 1, 2, 3, 1, 0, 2, 10) with val score 0.8407.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 3, 1, 0, 2, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bylevel (index: 3)
#
# As new Best Combo (3, 1, 2, 0, 1, 0, 2, 10) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.844
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 1, 0, 2, 10), which had val score of 0.8416
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 2, 1, 0, 2, 10), which had val score of 0.8416
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 3, 1, 0, 2, 10), which had val score of 0.8407
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 4, 1, 0, 2, 10), which had val score of 0.8438
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 10) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0, 1, 0, 2, 10), which had val score of 0.8396
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0, 1, 0, 2, 10), which had val score of 0.8414
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.844
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0, 1, 0, 2, 10), which had val score of 0.8429
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0, 1, 0, 2, 10), which had val score of 0.8439
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.6757
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.753
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (2, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.8082
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.844
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_lambda (index: 5)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.844
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 1, 2, 10), which had val score of 0.8426
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 2, 2, 10), which had val score of 0.8392
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 6)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 0, 10), which had val score of 0.5343
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 1, 10), which had val score of 0.6986
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.844
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 3, 10), which had val score of 0.4473
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 10) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 3
#
# Round 3
# Hyperparameter: features (index: 7)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 0), which had val score of 0.4162
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 1), which had val score of 0.4753
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 2), which had val score of 0.5699
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 3), which had val score of 0.6779
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 4), which had val score of 0.686
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 5), which had val score of 0.7312
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 6), which had val score of 0.7467
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 7), which had val score of 0.7707
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 8), which had val score of 0.8106
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 9), which had val score of 0.8367
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.844
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 11), which had val score of 0.8427
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 12), which had val score of 0.8409
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 10) with val score 0.844.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (3, 1, 2, 0, 1, 0, 2, 13) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 13), which had val score of 0.8444
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 13) with val score 0.8444.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 14), which had val score of 0.84
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 13) with val score 0.8444.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 15), which had val score of 0.8399
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 13) with val score 0.8444.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 16), which had val score of 0.8417
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 13) with val score 0.8444.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 17), which had val score of 0.841
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 13) with val score 0.8444.
#         Has trained 152 of 266400 combinations so far
# As new Best Combo (3, 1, 2, 0, 1, 0, 2, 18) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 19), which had val score of 0.843
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 20), which had val score of 0.8406
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 21), which had val score of 0.8419
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 22), which had val score of 0.8382
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 23), which had val score of 0.8373
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 24), which had val score of 0.8366
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 25), which had val score of 0.8394
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 26), which had val score of 0.8324
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 27), which had val score of 0.8308
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 28), which had val score of 0.8379
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 29), which had val score of 0.836
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 30), which had val score of 0.8351
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 31), which had val score of 0.8294
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 32), which had val score of 0.83
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 33), which had val score of 0.8288
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 34), which had val score of 0.8344
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 35), which had val score of 0.8328
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 36), which had val score of 0.8275
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (3, 0, 2, 0, 1, 0, 2, 18), which had val score of 0.8099
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 0, 1, 0, 2, 18), which had val score of 0.8358
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_bin (index: 4)
#
# Already Trained and Tested combination (3, 1, 2, 0, 0, 0, 2, 18), which had val score of 0.8412
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 1, 0, 2, 18), which had val score of 0.8426
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 2, 1, 0, 2, 18), which had val score of 0.8392
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 152 of 266400 combinations so far
# Trained and Tested combination 153 of 266400: (3, 1, 2, 3, 1, 0, 2, 18), taking 290.76 seconds to get val score of 0.8459
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Trained and Tested combination 154 of 266400: (3, 1, 2, 4, 1, 0, 2, 18), taking 315.9 seconds to get val score of 0.8448
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 155 of 266400: (3, 1, 0, 0, 1, 0, 2, 18), taking 183.99 seconds to get val score of 0.8365
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Trained and Tested combination 156 of 266400: (3, 1, 1, 0, 1, 0, 2, 18), taking 194.92 seconds to get val score of 0.8429
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 156 of 266400 combinations so far
# Trained and Tested combination 157 of 266400: (3, 1, 3, 0, 1, 0, 2, 18), taking 225.15 seconds to get val score of 0.8444
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Trained and Tested combination 158 of 266400: (3, 1, 4, 0, 1, 0, 2, 18), taking 253.6 seconds to get val score of 0.8445
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 159 of 266400: (0, 1, 2, 0, 1, 0, 2, 18), taking 26.5 seconds to get val score of 0.6797
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Trained and Tested combination 160 of 266400: (1, 1, 2, 0, 1, 0, 2, 18), taking 51.96 seconds to get val score of 0.7529
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Trained and Tested combination 161 of 266400: (2, 1, 2, 0, 1, 0, 2, 18), taking 103.81 seconds to get val score of 0.8082
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 161 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: reg_lambda (index: 5)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 161 of 266400 combinations so far
# Trained and Tested combination 162 of 266400: (3, 1, 2, 0, 1, 1, 2, 18), taking 209.11 seconds to get val score of 0.846
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Trained and Tested combination 163 of 266400: (3, 1, 2, 0, 1, 2, 2, 18), taking 206.14 seconds to get val score of 0.8417
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 6)
#
# Trained and Tested combination 164 of 266400: (3, 1, 2, 0, 1, 0, 0, 18), taking 209.86 seconds to get val score of 0.5335
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Trained and Tested combination 165 of 266400: (3, 1, 2, 0, 1, 0, 1, 18), taking 208.56 seconds to get val score of 0.6878
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 165 of 266400 combinations so far
# Trained and Tested combination 166 of 266400: (3, 1, 2, 0, 1, 0, 3, 18), taking 216.43 seconds to get val score of 0.2105
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 4
#
# Round 4
# Hyperparameter: features (index: 7)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 0), which had val score of 0.4162
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
# ...
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 2), which had val score of 0.5699
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 3), which had val score of 0.6779
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 4), which had val score of 0.686
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 5), which had val score of 0.7312
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 6), which had val score of 0.7467
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 7), which had val score of 0.7707
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 8), which had val score of 0.8106
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 9), which had val score of 0.8367
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 10), which had val score of 0.844
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 11), which had val score of 0.8427
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 12), which had val score of 0.8409
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 13), which had val score of 0.8444
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 14), which had val score of 0.84
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 15), which had val score of 0.8399
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 16), which had val score of 0.8417
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 17), which had val score of 0.841
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 19), which had val score of 0.843
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 20), which had val score of 0.8406
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 21), which had val score of 0.8419
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 22), which had val score of 0.8382
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 23), which had val score of 0.8373
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 24), which had val score of 0.8366
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 25), which had val score of 0.8394
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 26), which had val score of 0.8324
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 27), which had val score of 0.8308
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 28), which had val score of 0.8379
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 29), which had val score of 0.836
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 30), which had val score of 0.8351
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 31), which had val score of 0.8294
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 32), which had val score of 0.83
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 33), which had val score of 0.8288
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 34), which had val score of 0.8344
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 35), which had val score of 0.8328
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 36), which had val score of 0.8275
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (3, 0, 2, 0, 1, 0, 2, 18), which had val score of 0.8099
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 2, 2, 0, 1, 0, 2, 18), which had val score of 0.8358
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: max_bin (index: 4)
#
# Already Trained and Tested combination (3, 1, 2, 0, 0, 0, 2, 18), which had val score of 0.8412
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: colsample_bylevel (index: 3)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 1, 0, 2, 18), which had val score of 0.8426
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 2, 1, 0, 2, 18), which had val score of 0.8392
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 3, 1, 0, 2, 18), which had val score of 0.8459
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 4, 1, 0, 2, 18), which had val score of 0.8448
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 0, 1, 0, 2, 18), which had val score of 0.8365
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 1, 0, 1, 0, 2, 18), which had val score of 0.8429
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 3, 0, 1, 0, 2, 18), which had val score of 0.8444
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 4, 0, 1, 0, 2, 18), which had val score of 0.8445
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.6797
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (1, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.7529
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (2, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8082
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: reg_lambda (index: 5)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 1, 2, 18), which had val score of 0.846
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 2, 2, 18), which had val score of 0.8417
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 4
# Hyperparameter: learning_rate (index: 6)
#
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 0, 18), which had val score of 0.5335
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 1, 18), which had val score of 0.6878
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 2, 18), which had val score of 0.8469
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
# Already Trained and Tested combination (3, 1, 2, 0, 1, 0, 3, 18), which had val score of 0.2105
#         Current best combo: (3, 1, 2, 0, 1, 0, 2, 18) with val score 0.8469.
#         Has trained 166 of 266400 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 0, 1, 0, 2, 18) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Val Score:
#  0.846858
# Best Combo Test Score:
#  0.843923
# Best Combo Train Score:
#  0.859744
# Max Combo Index:
#  (3, 1, 2, 0, 1, 0, 2, 18) out of [4, 3, 5, 5, 2, 3, 4, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 200, 'max_depth': 4, 'subsample': 0.7, 'colsample_bylevel': 0.4, 'max_bin': 256, 'reg_lambda': 0.01, 'learning_rate': 0.1, 'features': 18}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains')
# % Combos Checked: 166 out of 266400 which is 0.062312%
