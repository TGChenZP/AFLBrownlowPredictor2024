# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'extrf'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.3.0-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 2.2 MB/s eta 0:00:00
# Downloading JXAutoML-0.3.0-py3-none-any.whl (34 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.3.0

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from sklearn.ensemble import ExtraTreesRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'max_samples': (0.4, 0.55, 0.7, 0.85, 1),
    'max_features': (0.4, 0.55, 0.7, 0.85, 1),
    'ccp_alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': SEED,
                                    'n_jobs': -1,
                                    'bootstrap': True
                                    }

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'sklearn.ensemble._forest.ExtraTreesRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 2772 rows, for 2772.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 1, 28), which had val score of 0.6044
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 1, 28), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 1, 28), which had val score of 0.7688
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 1, 28), which had val score of 0.874
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 28), which had val score of 0.769
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 2, 28), which had val score of 0.6642
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 27), which had val score of 0.776
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 29), which had val score of 0.7657
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 27), which had val score of 0.7755
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 0, 27), which had val score of 0.6142
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 27), which had val score of 0.8169
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 27), which had val score of 0.7763
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 27), which had val score of 0.8751
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 27), which had val score of 0.776
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 26), which had val score of 0.7751
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 28), which had val score of 0.769
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 0, 4, 0, 29), which had val score of 0.7665
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 0, 4, 0, 29), which had val score of 0.6047
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 0, 4, 0, 29), which had val score of 0.8094
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 4, 0, 29), which had val score of 0.7661
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 3, 0, 29), which had val score of 0.8746
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 1, 29), which had val score of 0.7657
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 28), which had val score of 0.769
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 0, 4, 0, 30), which had val score of 0.7608
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# % Combos Checked Thus Far: 2772 out of 194250 which is 1.427027%
# Cruising Coordrdinate 287 of 432
#
# Cruising Coordrdinate 288 of 432
#
# Cruising Coordrdinate 289 of 432
#
# Cruising Coordrdinate 290 of 432
#
# Cruising Coordrdinate 291 of 432
#
# Cruising Coordrdinate 292 of 432
#
# Cruising Coordrdinate 293 of 432
#
# Cruising Coordrdinate 294 of 432
#
# Cruising Coordrdinate 295 of 432
#
# Cruising Coordrdinate 296 of 432
#
# Cruising Coordrdinate 297 of 432
#
# Cruising Coordrdinate 298 of 432
#
# Cruising Coordrdinate 299 of 432
#
# Cruising Coordrdinate 300 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 41
#
# 	round 41 iteration:  0
#
# Already Trained and Tested combination (1, 6, 0, 0, 0, 24), which had val score of 0.8656
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 0, 24), which had val score of 0.8647
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 0, 24), which had val score of 0.8638
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 1, 24), which had val score of 0.861
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 23), which had val score of 0.8613
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 25), which had val score of 0.8595
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# 	round 41 iteration:  1
#
# Already Trained and Tested combination (0, 6, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (2, 6, 0, 0, 0, 24), which had val score of 0.8678
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 5, 0, 0, 0, 24), which had val score of 0.8656
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 1, 0, 0, 24), which had val score of 0.8682
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 1, 0, 24), which had val score of 0.8681
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 1, 24), which had val score of 0.8652
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 0, 23), which had val score of 0.8659
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 0, 25), which had val score of 0.8659
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 5, 0, 0, 0, 24), which had val score of 0.8656
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 1, 0, 0, 24), which had val score of 0.8647
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 1, 0, 24), which had val score of 0.8638
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 1, 24), which had val score of 0.861
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 23), which had val score of 0.8613
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 25), which had val score of 0.8595
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 1, 0, 0, 24), which had val score of 0.8682
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 1, 0, 0, 24), which had val score of 0.8647
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 2, 0, 0, 24), which had val score of 0.8634
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 1, 0, 24), which had val score of 0.8662
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 1, 24), which had val score of 0.8645
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 0, 23), which had val score of 0.8633
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 0, 25), which had val score of 0.8616
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 1, 0, 24), which had val score of 0.8681
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 1, 0, 24), which had val score of 0.8638
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 1, 0, 24), which had val score of 0.8662
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 2, 0, 24), which had val score of 0.8655
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 1, 24), which had val score of 0.8638
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 0, 23), which had val score of 0.8654
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 0, 25), which had val score of 0.8627
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 1, 24), which had val score of 0.8652
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 1, 24), which had val score of 0.861
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 1, 24), which had val score of 0.8645
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 1, 24), which had val score of 0.8638
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 2, 24), which had val score of 0.7764
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 1, 23), which had val score of 0.862
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 1, 25), which had val score of 0.8597
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 0, 23), which had val score of 0.8659
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 23), which had val score of 0.8613
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 0, 23), which had val score of 0.8633
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 0, 23), which had val score of 0.8654
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 1, 23), which had val score of 0.862
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 22), which had val score of 0.8631
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 0, 25), which had val score of 0.8659
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 25), which had val score of 0.8595
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 0, 25), which had val score of 0.8616
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 0, 25), which had val score of 0.8627
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 1, 25), which had val score of 0.8597
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 26), which had val score of 0.8567
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# % Combos Checked Thus Far: 2772 out of 194250 which is 1.427027%
# Cruising Coordrdinate 301 of 432
#
# Cruising Coordrdinate 302 of 432
#
# Cruising Coordrdinate 303 of 432
#
# Cruising Coordrdinate 304 of 432
#
# Cruising Coordrdinate 305 of 432
#
# Cruising Coordrdinate 306 of 432
#
# Cruising Coordrdinate 307 of 432
#
# Cruising Coordrdinate 308 of 432
#
# Cruising Coordrdinate 309 of 432
#
# Cruising Coordrdinate 310 of 432
#
# Cruising Coordrdinate 311 of 432
#
# Cruising Coordrdinate 312 of 432
#
# Cruising Coordrdinate 313 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 42
#
# 	round 42 iteration:  0
#
# Already Trained and Tested combination (1, 6, 0, 4, 0, 24), which had val score of 0.8184
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 0, 24), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 4, 0, 24), which had val score of 0.8117
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 0, 24), which had val score of 0.8671
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 1, 24), which had val score of 0.8112
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 23), which had val score of 0.8025
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 25), which had val score of 0.7958
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# 	round 42 iteration:  1
#
# Already Trained and Tested combination (0, 6, 0, 4, 0, 24), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (2, 6, 0, 4, 0, 24), which had val score of 0.8221
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 5, 0, 4, 0, 24), which had val score of 0.8184
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 1, 4, 0, 24), which had val score of 0.8193
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 3, 0, 24), which had val score of 0.8726
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 4, 1, 24), which had val score of 0.8175
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 4, 0, 23), which had val score of 0.8137
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 4, 0, 25), which had val score of 0.8077
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 5, 0, 4, 0, 24), which had val score of 0.8184
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 4, 0, 24), which had val score of 0.8113
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 24), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 1, 4, 0, 24), which had val score of 0.8117
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 3, 0, 24), which had val score of 0.8671
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 1, 24), which had val score of 0.8112
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 0, 23), which had val score of 0.8025
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 0, 25), which had val score of 0.7958
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 1, 4, 0, 24), which had val score of 0.8193
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 1, 4, 0, 24), which had val score of 0.8117
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 24), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 2, 4, 0, 24), which had val score of 0.8125
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 3, 0, 24), which had val score of 0.8697
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 4, 1, 24), which had val score of 0.8107
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 4, 0, 23), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 4, 0, 25), which had val score of 0.8085
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 3, 0, 24), which had val score of 0.8726
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 3, 0, 24), which had val score of 0.8671
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 3, 0, 24), which had val score of 0.8697
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 2, 0, 24), which had val score of 0.8655
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 24), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 1, 24), which had val score of 0.8676
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 0, 23), which had val score of 0.8695
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 0, 25), which had val score of 0.8669
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 4, 1, 24), which had val score of 0.8175
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 4, 1, 24), which had val score of 0.8112
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 4, 1, 24), which had val score of 0.8107
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 3, 1, 24), which had val score of 0.8676
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 0, 24), which had val score of 0.8114
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 2, 24), which had val score of 0.6779
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 1, 23), which had val score of 0.8029
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 4, 1, 25), which had val score of 0.7957
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# % Combos Checked Thus Far: 2772 out of 194250 which is 1.427027%
# Cruising Coordrdinate 314 of 432
#
# Cruising Coordrdinate 315 of 432
#
# Cruising Coordrdinate 316 of 432
#
# Cruising Coordrdinate 317 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 43
#
# 	round 43 iteration:  0
#
# Already Trained and Tested combination (1, 3, 0, 0, 0, 24), which had val score of 0.8658
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 0, 0, 24), which had val score of 0.8317
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 24), which had val score of 0.8609
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 0, 24), which had val score of 0.8625
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 0, 24), which had val score of 0.8639
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 24), which had val score of 0.8607
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 23), which had val score of 0.8616
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 25), which had val score of 0.8591
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# 	round 43 iteration:  1
#
# Already Trained and Tested combination (0, 3, 0, 0, 0, 24), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (2, 3, 0, 0, 0, 24), which had val score of 0.8674
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 2, 0, 0, 0, 24), which had val score of 0.8335
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 4, 0, 0, 0, 24), which had val score of 0.8656
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 1, 0, 0, 24), which had val score of 0.8672
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 1, 0, 24), which had val score of 0.8681
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 0, 1, 24), which had val score of 0.8652
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 0, 0, 23), which had val score of 0.8658
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 0, 0, 25), which had val score of 0.8645
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 1, 0, 0, 24), which had val score of 0.8672
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 0, 24), which had val score of 0.8314
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 1, 0, 0, 24), which had val score of 0.8647
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 24), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 2, 0, 0, 24), which had val score of 0.8652
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 1, 0, 24), which had val score of 0.8669
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 1, 24), which had val score of 0.8621
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 0, 23), which had val score of 0.8637
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 0, 25), which had val score of 0.8626
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 1, 0, 24), which had val score of 0.8681
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 1, 0, 24), which had val score of 0.8383
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 1, 0, 24), which had val score of 0.8638
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 1, 0, 24), which had val score of 0.8669
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 24), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 2, 0, 24), which had val score of 0.865
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 1, 24), which had val score of 0.8642
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 0, 23), which had val score of 0.864
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 0, 25), which had val score of 0.8645
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 0, 1, 24), which had val score of 0.8652
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 0, 1, 24), which had val score of 0.8318
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 1, 24), which had val score of 0.861
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 1, 24), which had val score of 0.8621
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 1, 24), which had val score of 0.8642
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 24), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 2, 24), which had val score of 0.7797
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 23), which had val score of 0.8618
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 25), which had val score of 0.8596
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 0, 0, 23), which had val score of 0.8658
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 0, 0, 23), which had val score of 0.8252
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 23), which had val score of 0.8613
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 0, 23), which had val score of 0.8637
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 0, 23), which had val score of 0.864
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 23), which had val score of 0.8618
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 22), which had val score of 0.8614
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 24), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 3, 0, 0, 0, 25), which had val score of 0.8645
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 2, 0, 0, 0, 25), which had val score of 0.8288
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 25), which had val score of 0.8595
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 0, 25), which had val score of 0.8626
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 1, 0, 25), which had val score of 0.8645
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 1, 25), which had val score of 0.8596
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 24), which had val score of 0.8608
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 3, 0, 0, 0, 26), which had val score of 0.8572
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# % Combos Checked Thus Far: 2772 out of 194250 which is 1.427027%
# Cruising Coordrdinate 318 of 432
#
# Cruising Coordrdinate 319 of 432
#
# Cruise suspended due to suspicious case
# Guidance: round 44
#
# 	round 44 iteration:  0
#
# Already Trained and Tested combination (1, 6, 0, 0, 0, 15), which had val score of 0.867
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 0, 0, 15), which had val score of 0.8623
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 1, 0, 0, 15), which had val score of 0.8647
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 1, 0, 15), which had val score of 0.8661
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 1, 15), which had val score of 0.8623
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 14), which had val score of 0.8619
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 16), which had val score of 0.8604
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# 	round 44 iteration:  1
#
# Already Trained and Tested combination (0, 6, 0, 0, 0, 15), which had val score of 0.8623
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (2, 6, 0, 0, 0, 15), which had val score of 0.8696
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 5, 0, 0, 0, 15), which had val score of 0.867
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 1, 0, 0, 15), which had val score of 0.8694
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 1, 0, 15), which had val score of 0.8699
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 1, 15), which had val score of 0.8664
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 0, 14), which had val score of 0.8677
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 6, 0, 0, 0, 16), which had val score of 0.8654
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (1, 5, 0, 0, 0, 15), which had val score of 0.867
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 4, 0, 0, 0, 15), which had val score of 0.8623
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 6, 0, 0, 0, 15), which had val score of 0.8623
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 1, 0, 0, 15), which had val score of 0.8647
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (0, 5, 0, 1, 0, 15), which had val score of 0.8661
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# ...
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 0, 19), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 0, 19), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 4, 3, 0, 19), which had val score of -0.0
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 0, 19), which had val score of 0.8808
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 4, 0, 19), which had val score of 0.7948
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1, 19), which had val score of 0.8798
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 0, 18), which had val score of 0.8815
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 0, 20), which had val score of 0.8812
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 4, 3, 3, 0, 19), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 19), which had val score of 0.8823
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 5, 3, 3, 0, 19), which had val score of 0.8821
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 2, 3, 0, 19), which had val score of 0.8812
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 4, 3, 0, 19), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 0, 19), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 4, 0, 19), which had val score of 0.8399
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 1, 19), which had val score of 0.8798
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 0, 18), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 0, 20), which had val score of 0.8815
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 0, 19), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 2, 3, 0, 19), which had val score of 0.8514
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 2, 3, 0, 19), which had val score of 0.8812
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 1, 3, 0, 19), which had val score of 0.8797
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 19), which had val score of 0.8823
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 0, 19), which had val score of 0.8801
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 4, 0, 19), which had val score of 0.796
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 1, 19), which had val score of 0.8795
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 0, 18), which had val score of 0.8807
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 0, 20), which had val score of 0.8806
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 2, 0, 19), which had val score of 0.8808
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 3, 2, 0, 19), which had val score of 0.848
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 2, 0, 19), which had val score of 0.8811
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 2, 0, 19), which had val score of 0.8801
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 4, 2, 0, 19), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 1, 0, 19), which had val score of 0.8795
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 19), which had val score of 0.8823
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 1, 19), which had val score of 0.8789
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 18), which had val score of 0.8806
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 20), which had val score of 0.8802
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 1, 19), which had val score of 0.8798
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 3, 3, 1, 19), which had val score of 0.8514
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 1, 19), which had val score of 0.8798
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 1, 19), which had val score of 0.8795
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 4, 3, 1, 19), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 1, 19), which had val score of 0.8789
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 4, 1, 19), which had val score of 0.7938
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 19), which had val score of 0.8823
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 2, 19), which had val score of 0.7904
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1, 18), which had val score of 0.8794
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1, 20), which had val score of 0.8792
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 0, 18), which had val score of 0.8815
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 3, 3, 0, 18), which had val score of 0.8509
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 0, 18), which had val score of 0.8818
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 0, 18), which had val score of 0.8807
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 4, 3, 0, 18), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 18), which had val score of 0.8806
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 4, 0, 18), which had val score of 0.7994
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1, 18), which had val score of 0.8794
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 17), which had val score of 0.8814
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 19), which had val score of 0.8823
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (4, 3, 3, 3, 0, 20), which had val score of 0.8812
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 2, 3, 3, 0, 20), which had val score of 0.851
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 4, 3, 3, 0, 20), which had val score of 0.8815
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 2, 3, 0, 20), which had val score of 0.8806
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 4, 3, 0, 20), which had val score of -0.0001
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 2, 0, 20), which had val score of 0.8802
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 4, 0, 20), which had val score of 0.7943
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 1, 20), which had val score of 0.8792
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 19), which had val score of 0.8823
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# Already Trained and Tested combination (5, 3, 3, 3, 0, 21), which had val score of 0.8812
#         Current best combo: (5, 3, 3, 3, 0, 19) with val score 0.8823.
#         Has trained 2772 of 194250 combinations so far
# % Combos Checked Thus Far: 2772 out of 194250 which is 1.427027%
# Max Val Score:
#  0.882255
# Best Combo Test Score:
#  0.883007
# Best Combo Train Score:
#  0.976862
# Max Combo Index:
#  (5, 3, 3, 3, 0, 19) out of [6, 7, 5, 5, 5, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 24, 'max_samples': 0.85, 'max_features': 0.85, 'ccp_alpha': 1e-08, 'features': 19}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains', 'Tackles Inside 50')
# % Combos Checked: 2772 out of 194250 which is 1.427027%
