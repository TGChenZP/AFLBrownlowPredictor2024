# %% [markdown]
# # Tuning Script

# %%
# Parameters subject to change in every script - involved in naming

MODEL = 'lgb'
TUNER = 'yangzhoub'

# %% [markdown]
# ---

# %%
# detect whether this is a google environment

COLAB_ENVIRONMENT = False

try:
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB_ENVIRONMENT = True
except:
    pass
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle

if COLAB_ENVIRONMENT:
    home_directory = './drive/MyDrive/LAB/AFLBrownlowPredictor2024/' # my home directory is stored in ./LAB of google drive
    if MODEL == 'ebr':
        # !pip install interpret==0.5.0
    elif MODEL == 'cbr':
        # !pip install catboost
    # !pip install JXAutoML
else:
    home_directory = '../../'

from JXAutoML.YangZhouB import YangZhouB as Tuner

import pandas as pd
# Out:
# Collecting JXAutoML
#   Downloading JXAutoML-0.2.6-py3-none-any.whl.metadata (910 bytes)
# Downloading JXAutoML-0.2.6-py3-none-any.whl (27 kB)
# Installing collected packages: JXAutoML
# Successfully installed JXAutoML-0.2.6

# %%
# Parameters that are same for every script
SEED = 42

TASK_TYPE = 'Regression'  # this task is a classification task

# we have decided to tune features as hp
TUNE_FEATURES_AS_HYPERPARAMETERS = True

# %% [markdown]
# ---

# %%
# model to use to tune
from lightgbm import LGBMRegressor as clf

# what values to try for each hyperparameter
parameter_choices = {
    'n_estimators': (25, 50, 100, 200, 400, 800),
    'max_depth': (3, 6, 12, 24, 48, 96, 192),
    'subsample': (0.4, 0.55, 0.7, 0.85, 1),
    'colsample_bytree': (0.4, 0.55, 0.7, 0.85, 1),
    'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
    'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)
}

# what values to set non-tuneable parameters/hyperparameters
non_tunable_hyperparameters_dict = {
                                    'random_state': 19260817,
                                    'n_jobs': -1,
                                    'warnings': 'none'
                                    }
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ---

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv(f'{home_directory}data/curated/modelling/train.csv')
val_data = pd.read_csv(f'{home_directory}data/curated/modelling/val.csv')
test_data = pd.read_csv(f'{home_directory}data/curated/modelling/test.csv')

train_X = train_data.drop(columns=['target'])
train_y = train_data['target']
val_X = val_data.drop(columns=['target'])
val_y = val_data['target']
test_X = test_data.drop(columns=['target'])
test_y = test_data['target']

# %%
# Import feature importance ordering

with open(f'{home_directory}models/feature_importance_ordering.pickle', 'rb') as f:
    feature_importance_ordering = pickle.load(f)

# %% [markdown]
# Set parameters

# %%
# initialisation
tuner = Tuner()

print('---')

# define what model we are tuning
tuner.read_in_model(clf, TASK_TYPE, pytorch_model=False, optimised_metric='r2')

print('---')

# read in the data for training and validation
tuner.read_in_data(train_X, train_y, val_X, val_y, test_X, test_y)

print('---')

# set what hp values to tune
tuner.set_hyperparameters(parameter_choices)
# WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

# set up hp values that need to be changed from default but NOT to be tuned
tuner.set_non_tuneable_hyperparameters(non_tunable_hyperparameters_dict)

print('---')

# set up feature importance ordering

if TUNE_FEATURES_AS_HYPERPARAMETERS:
    tuner.set_features(feature_importance_ordering)
    # WARNING: this may take a while if no. tuneable hyperparameters are large

print('---')

try:  # try to read in previous results to continue tuning ...
    tuner.read_in_tuning_result_df(
        f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')
except:
    print('No previous tuning data read in')

print('---')

# set up where to save the tuning result csv
tuner.set_tuning_result_saving_address(
    f'{home_directory}models/tuning/{TUNER}_{MODEL}.csv')

print('---')

# set up where to save the current best model
tuner.set_best_model_saving_address(
    f'{home_directory}models/tmp_models/{TUNER}_{MODEL}')
# Out:
# YangZhouB Initialised
# ---
# Successfully read in model <class 'lightgbm.sklearn.LGBMRegressor'>, which is a Regression model optimising for r2
# ---
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# ---
# Successfully recorded hyperparameter choices
# ---
# Successfully recorded non_tuneable_hyperparameter choices
# ---
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# ---
# Successfully read in tuning result of 1483 rows, for 1483.0 combos
# ---
# Successfully set tuning output address
# ---
# Successfully set best model output address

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# begin tuning ... (or continue training)

tuner.tune()
# Out:
# Streaming output truncated to the last 5000 lines.
# Already Trained and Tested combination (3, 3, 2, 1, 2, 4, 18), which had val score of 0.0266
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 3, 17), which had val score of 0.027
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 3, 19), which had val score of 0.0268
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (2, 3, 2, 3, 2, 3, 18), which had val score of 0.0142
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 3, 2, 3, 18), which had val score of 0.0555
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 3, 2, 3, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 3, 2, 3, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 3, 2, 3, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 3, 3, 2, 3, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 4, 2, 3, 18), which had val score of 0.0286
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 1, 3, 18), which had val score of 0.0003
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3, 18), which had val score of 0.8181
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 2, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 4, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 3, 17), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 3, 19), which had val score of 0.0283
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 3, 3, 18), which had val score of 0.6737
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 3, 3, 18), which had val score of 0.8784
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 3, 3, 18), which had val score of 0.8172
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 3, 3, 18), which had val score of 0.8172
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 3, 3, 18), which had val score of 0.8172
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 3, 3, 18), which had val score of 0.8172
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 3, 3, 18), which had val score of 0.8125
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 3, 3, 18), which had val score of 0.8181
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 4, 3, 18), which had val score of 0.8954
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 2, 18), which had val score of 0.8173
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 4, 18), which had val score of 0.8167
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 3, 17), which had val score of 0.8169
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 3, 19), which had val score of 0.8165
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 2, 2, 18), which had val score of 0.0139
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 2, 2, 18), which had val score of 0.0543
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 2, 2, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 2, 2, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 2, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 2, 2, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 2, 18), which had val score of 0.0266
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 2, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 2, 18), which had val score of 0.0003
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 2, 18), which had val score of 0.8173
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 1, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 2, 17), which had val score of 0.0279
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 2, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 2, 4, 18), which had val score of 0.0139
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 2, 4, 18), which had val score of 0.0542
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 2, 4, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 2, 4, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 4, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 2, 4, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 4, 18), which had val score of 0.0266
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 4, 18), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 4, 18), which had val score of 0.0003
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 4, 18), which had val score of 0.8167
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 5, 18), which had val score of 0.0271
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 4, 17), which had val score of 0.0278
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 4, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 2, 3, 17), which had val score of 0.0141
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 2, 3, 17), which had val score of 0.0547
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 2, 3, 17), which had val score of 0.0279
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 2, 3, 17), which had val score of 0.0279
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 3, 17), which had val score of 0.0279
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 2, 3, 17), which had val score of 0.0279
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 3, 17), which had val score of 0.027
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 3, 17), which had val score of 0.0282
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 3, 17), which had val score of 0.0003
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 3, 17), which had val score of 0.8169
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 2, 17), which had val score of 0.0279
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 4, 17), which had val score of 0.0278
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 16), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (2, 3, 2, 2, 2, 3, 19), which had val score of 0.014
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 3, 2, 2, 2, 3, 19), which had val score of 0.0545
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 2, 2, 2, 2, 3, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 4, 2, 2, 2, 3, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 1, 2, 2, 3, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 3, 2, 2, 3, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 1, 2, 3, 19), which had val score of 0.0268
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 3, 2, 3, 19), which had val score of 0.0283
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 1, 3, 19), which had val score of 0.0003
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 3, 3, 19), which had val score of 0.8165
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 2, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 4, 19), which had val score of 0.0277
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 18), which had val score of 0.0276
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (3, 3, 2, 2, 2, 3, 20), which had val score of 0.0278
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 3, 4, 0, 4, 0, 36), which had val score of 0.8991
#         Current best combo: (5, 3, 4, 0, 4, 0, 36) with val score 0.8991.
#         Has trained 1483 of 1165500 combinations so far
# As new Best Combo (5, 2, 4, 0, 4, 0, 36) was read in, best_clf is set to None
# Already Trained and Tested combination (5, 2, 4, 0, 4, 0, 36), which had val score of 0.8994
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 4, 4, 0, 4, 0, 36), which had val score of 0.8991
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 3, 0, 4, 0, 36), which had val score of 0.8991
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 1, 4, 0, 36), which had val score of 0.8988
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 3, 0, 36), which had val score of 0.8948
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 4, 1, 36), which had val score of 0.8991
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 4, 0, 35), which had val score of 0.8985
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 2, 4, 0, 4, 0, 36), which had val score of 0.8991
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 1, 4, 0, 4, 0, 36), which had val score of 0.8991
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 3, 4, 0, 4, 0, 36), which had val score of 0.8991
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 2, 3, 0, 4, 0, 36), which had val score of 0.8994
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 2, 4, 1, 4, 0, 36), which had val score of 0.8992
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 2, 4, 0, 3, 0, 36), which had val score of 0.8948
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 2, 4, 0, 4, 1, 36), which had val score of 0.8993
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 2, 4, 0, 4, 0, 35), which had val score of 0.8985
#         Current best combo: (5, 2, 4, 0, 4, 0, 36) with val score 0.8994.
#         Has trained 1483 of 1165500 combinations so far
# % Combos Checked Thus Far: 1483 out of 1165500 which is 0.127242%
# STAGE TWO: Begin Cruise system
#
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
#
# Cruising Coordrdinate 0 of 864
# ...
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 5, 0, 1, 4, 0, 35), which had val score of 0.8991
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 1, 1, 4, 0, 35), which had val score of 0.8991
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 0, 4, 0, 35), which had val score of 0.8978
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 2, 4, 0, 35), which had val score of 0.898
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 3, 0, 35), which had val score of 0.8773
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 4, 1, 35), which had val score of 0.8989
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 4, 0, 34), which had val score of 0.8979
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 4, 0, 36), which had val score of 0.8991
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 5, 0, 1, 4, 0, 35), which had val score of 0.8991
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 4, 0, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 1, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 0, 4, 0, 35), which had val score of 0.8985
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 2, 4, 0, 35), which had val score of 0.8978
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 3, 0, 35), which had val score of 0.8959
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 4, 1, 35), which had val score of 0.8987
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 4, 0, 34), which had val score of 0.8976
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 4, 0, 36), which had val score of 0.8988
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 1, 1, 4, 0, 35), which had val score of 0.8991
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 1, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 2, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 0, 4, 0, 35), which had val score of 0.8985
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 2, 4, 0, 35), which had val score of 0.8978
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 3, 0, 35), which had val score of 0.8959
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 4, 1, 35), which had val score of 0.8987
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 4, 0, 34), which had val score of 0.8976
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 4, 0, 36), which had val score of 0.8988
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 2, 4, 0, 35), which had val score of 0.898
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 2, 4, 0, 35), which had val score of 0.8978
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 2, 4, 0, 35), which had val score of 0.8978
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 3, 4, 0, 35), which had val score of 0.8975
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 3, 0, 35), which had val score of 0.8958
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 4, 1, 35), which had val score of 0.8981
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 4, 0, 34), which had val score of 0.8978
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 4, 0, 36), which had val score of 0.8983
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 3, 0, 35), which had val score of 0.8773
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 3, 0, 35), which had val score of 0.8959
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 3, 0, 35), which had val score of 0.8959
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 3, 0, 35), which had val score of 0.8935
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 3, 0, 35), which had val score of 0.8958
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 2, 0, 35), which had val score of 0.1031
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 3, 1, 35), which had val score of 0.8959
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 3, 0, 34), which had val score of 0.8956
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 3, 0, 36), which had val score of 0.8964
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 4, 1, 35), which had val score of 0.8989
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 4, 1, 35), which had val score of 0.8987
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 4, 1, 35), which had val score of 0.8987
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 4, 1, 35), which had val score of 0.8984
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 4, 1, 35), which had val score of 0.8981
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 3, 1, 35), which had val score of 0.8959
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 2, 35), which had val score of 0.8987
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 1, 34), which had val score of 0.8973
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 1, 36), which had val score of 0.899
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (4, 6, 0, 1, 4, 0, 34), which had val score of 0.8979
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 5, 0, 1, 4, 0, 34), which had val score of 0.8976
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 1, 1, 4, 0, 34), which had val score of 0.8976
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 0, 4, 0, 34), which had val score of 0.8972
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 2, 4, 0, 34), which had val score of 0.8978
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 3, 0, 34), which had val score of 0.8956
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 1, 34), which had val score of 0.8973
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 0, 33), which had val score of 0.8988
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# Already Trained and Tested combination (5, 6, 0, 1, 4, 0, 35), which had val score of 0.8995
#         Current best combo: (5, 6, 0, 1, 4, 0, 35) with val score 0.8995.
#         Has trained 1483 of 1165500 combinations so far
# % Combos Checked Thus Far: 1483 out of 1165500 which is 0.127242%
# Max Val Score:
#  0.899481
# Best Combo Test Score:
#  0.899031
# Best Combo Train Score:
#  0.95168
# Max Combo Index:
#  (5, 6, 0, 1, 4, 0, 35) out of [6, 7, 5, 5, 5, 6, 37] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 800, 'max_depth': 192, 'subsample': 0.4, 'colsample_bytree': 0.55, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 35}
# Max Combo Features:
#  ('Effective Disposals', 'Disposals', 'Contested Possessions', 'Goals', 'Score Involvements', 'Hitouts', 'Kicks', 'Tackles', 'One Percenters', 'Clangers', 'Contested Marks', 'Tackles Outside 50', 'Metres Gained', 'Marks', 'Behind Assists', 'Intercepts', 'Marks Inside 50', 'Goal Assists', 'Frees Agains', 'Tackles Inside 50', 'Handballs', 'Marks Outside 50', 'Time On Ground %', 'Rebound 50s', 'Disposal Efficiency %', 'Uncontested Marks', 'Frees For', 'Clearances', 'Inside 50s', 'Turnovers', 'Bounces', 'Uncontested Possessions', 'Centre Clearances', 'Behinds', 'Stoppage Clearances', 'Ineffective Disposals')
# % Combos Checked: 1483 out of 1165500 which is 0.127242%
